# %% [markdown]
# ### Case Study - Pinchout and Fault Scenarios
# #### Showcasing LoopStructural-Flopy to address Model Structure Uncertainty
#
# This notebook showcases how structural parameters, in this case CPz and fault_offset can be used to generate multiple structural models and address structural uncertainty in 3D groundwater models. This notebook contains the Pinchout and Fault Scenarios and use a synthetic example to explore uncertainty in pinchout location and fault geometry.

# %%
# %run ./loop_showcase_functions.ipynb
#load from MODFLOW_tools (clone repo https://github.com/JimMcCallum/MODFLOW_Tools)
# %run ../../MODFLOW_Tools/modelling_routines/modelling_routines.ipynb
# %run ../../MODFLOW_Tools/meshing_routines/meshing_routines.ipynb
# %run ../../MODFLOW_Tools/geomodel_routines/geomodel_routines.ipynb
# %run ../../MODFLOW_Tools/loop2flopy/loop2flopy.ipynb
# %run ../../MODFLOW_Tools/plotting_routines_USG/plotting_routines.ipynb
# Out:
# C:\Users\19904604\AppData\Local\Temp\ipykernel_9368\3209728366.py:21: DeprecationWarning: GeoPandas is set to use PyGEOS over Shapely. PyGEOS support is deprecatedand will be removed in GeoPandas 1.0, released in the Q1 of 2024. Please migrate to Shapely 2.0 (https://geopandas.org/en/stable/docs/user_guide/pygeos_to_shapely.html).
#   import geopandas as gpd
# Modelling routines loaded!
# Meshing routines loaded!
# Geomodel routines loaded!
# loop2flopy routines loaded!
# Plotting routines loaded!

# %%
P = Project('showcase', boundingbox = [0, 6000, 0, 6000, -500, 0]) # (x0, x1, y0, y1, z0, z1)

# Spatial information
P.crs = "epsg:28350" # Put in coordinate reference
P.xypumpbores = [] 
P.npump = len(P.xypumpbores)
P.idpumpbores = [] 
P.xyobsbores = [(1500,1000), (2500, 5000), (4000, 3000), (5000,1500)]
P.idobsbores = ['OB1', 'OB2', 'OB3', 'OB4'] 
#P.geo_coords=[(500,500), (1600, 2800), (5500,5500), (2800,1600)]
#P.geo_bores = ['P1', 'P2', 'P3', 'P4']

# Observation Points
P.nobs = len(P.xyobsbores)
obs_z = [-40, -50, -100, -200, -300]
P.nzobs = len(obs_z)
P.zobs = np.ones((P.nobs, P.nzobs))
for j in range(P.nzobs):
    P.zobs[:, j] = P.zobs[:, j] * obs_z[j] 

# Meshing parameters
P.triExeName = '../exe/triangle.exe'
P.fx1, P.fy1, P.fx2, P.fy2 = (2000, 4500, 3000, 1000) # fault end points
P.fault_buffer = 150.  # offset boundary from fault
P.r = 40               # refining factor for model boundary. High r has refined edges
P.w = 150              # interior boundary offset
P.boundmaxtri = 50000  # max triangle area in boundary area
P.modelmaxtri = 50000  # max triangle area in main model area
P.angle = 32           # minimum triangle angles
P.radius1 = 100        # radius of inner circle around pumping bores
P.radius2 = 200        # radius of outer circle around pumping bores
P.boremaxtri = 100000   # max triangle area within bore radius

# Flow model parameters
P.mfexe_name = '../exe/mf6.exe'
P.workspace = '../modelfiles/'
P.nlg = 4    # number of geological layers
P.nls = 3    # number sublayers for conformable
P.nlv  = 30  # number of layers for voxel transect grid

P.ss = [0.00001, 0.00001, 0.00001, 0.00001]
P.sy = [0.1, 0.1, 0.1, 0.1]
P.rch = 0.4/365 # 0.0027 m/d
P.strt = -20.
P.chfunc = lambda x,z: -(0.005*x) - (z * 0.02)-20 # horizontal gradient of 0.01 and vertical gradient of 0.02
P.xt3d = True
   
vtk_workspace = '../vtk_files'
if not os.path.isdir(vtk_workspace):
    os.makedirs(vtk_workspace, exist_ok=True)

# %%
P.cell2dtri, P.xcyctri, P.verticestri, P.tri, trinodes = createcell2d(P, grid = 'tri', fault = True)  
P.cell2dvor, P.xcycvor, P.verticesvor, P.vor, vornodes = createcell2d(P, grid = 'vor', fault = True)

# %%
figure2(P)

# %% [markdown]
# ### Faults - 6 simulations

# %%
P.hk = [1, 2, 0.01, 5] 
P.vk = [i/10 for i in P.hk]

options = np.linspace(0, 320, 6) # Fault displacement

data = pd.read_excel("../data/loop_showcase_data.xls",sheet_name = "fault_example")
strat = pd.read_excel("../data/loop_showcase_data.xls",sheet_name = "strat")

P.control_points = ([])
P.fault_max_disp = 100.    # Was 200
P.minor_axis = 1000        # Fault_influence - orthogonal to fault
P.fault_center = [P.fx1 + (P.fx2 - P.fx1)/2, P.fy1 + (P.fy2 - P.fy1)/2, -400]
P.fault_slip_vector=[0,0,1]
    
fault_modelnames, fault_models, fault_obs_heads = [],[],[]         

for i in range(len(options)):
    fault_modelnames.append(str('FD_'+str(options[i])))  
    fault_models.append(Model(fault_modelnames[i], P, plan = 'vor', transect = 'con')) # Create flow model  
    P.fault_max_disp = options[i] /2
    P.data, P.strat = prepare_geomodel_loopshowcase(P, data, strat, include_fault = True)   # Prepare geomodel inputs
    P.geomodel = create_geomodel_loopshowcase(P, include_fault = True) # Make geomodel
    M = fault_models[i]
    M.create_lith_dis_arrays(P)                                 # Create lith and dis arrays
    M.create_prop_arrays(P)                                     # Create K arrays
    M.create_flow_package_arrays(P)                             # Create flow packages
    M.gwf, M.head_ss, M.obs_ss, M.runtime_ss = M.write_run_model(P, period = 'Steady', ic_array = P.strt)   
    fault_obs_heads.append((process_obs_steady(P, M)))
    f = os.path.join(vtk_workspace, "faults", M.modelname)
    M.gwf.export(f, fmt="vtk")
# Out:
# C:\Users\19904604\Anaconda3\envs\loop3denvu\lib\site-packages\skimage\util\dtype.py:27: DeprecationWarning: `np.bool8` is a deprecated alias for `np.bool_`.  (Deprecated NumPy 1.24)
#   np.bool8: (False, True),
# WARNING: 2024-07-08 10:21:24,062: geological_model.py:609 -- deprecated method. Model data can now be set using the data attribute
# WARNING: 2024-07-08 10:21:24,101: geological_model.py:1359 -- Fault displacement is 0
# WARNING: 2024-07-08 10:21:24,153: _fault_builder.py:208 -- There is no slip vector data for the fault, using vertical slip vector
#                           projected onto fault surface estimating from fault normal
# WARNING: 2024-07-08 10:21:24,153: _fault_builder.py:239 -- Fault major axis using map length: 3640.0549446402592
# C:\Users\19904604\Anaconda3\envs\loop3denvu\lib\site-packages\LoopStructural\modelling\core\geological_model.py:647: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = cm.get_cmap(cmap, n_units)
# Fault included!
# {'upper': 0, 'upper_unconformity': 1, 'Fault': 2, 'lower': 3}
# Creating lithology and discretisation arrays for  FD_0.0  ...
# Time taken =  5.309803
# Creating property arrays for  FD_0.0  ...
# Time taken =  0.015635
# Adding flow packages to  FD_0.0  ...
# Time taken =  1.512862
# Writing simulation and gwf for  FD_0.0  ...
# FD_0.0
# WARNING: Unable to resolve dimension of ('gwf6', 'disu', 'cell2d', 'cell2d', 'icvert') based on shape "ncvert".
# Running simulation for  FD_0.0  ...
# Period =  Steady
# Model success =  True
# run_time =  36.462993
# WARNING: 2024-07-08 10:22:16,491: geological_model.py:609 -- deprecated method. Model data can now be set using the data attribute
# WARNING: 2024-07-08 10:22:16,524: _fault_builder.py:208 -- There is no slip vector data for the fault, using vertical slip vector
#                           projected onto fault surface estimating from fault normal
# WARNING: 2024-07-08 10:22:16,524: _fault_builder.py:239 -- Fault major axis using map length: 3640.0549446402592
# C:\Users\19904604\Anaconda3\envs\loop3denvu\lib\site-packages\LoopStructural\modelling\core\geological_model.py:647: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = cm.get_cmap(cmap, n_units)
# Fault included!
# {'upper': 0, 'upper_unconformity': 1, 'Fault': 2, 'lower': 3}
# Creating lithology and discretisation arrays for  FD_64.0  ...
# Time taken =  25.198237
# Creating property arrays for  FD_64.0  ...
# Time taken =  0.010238
# Adding flow packages to  FD_64.0  ...
# Time taken =  0.853997
# Writing simulation and gwf for  FD_64.0  ...
# FD_64.0
# WARNING: Unable to resolve dimension of ('gwf6', 'disu', 'cell2d', 'cell2d', 'icvert') based on shape "ncvert".
# Running simulation for  FD_64.0  ...
# Period =  Steady
# Model success =  True
# run_time =  25.937946
# WARNING: 2024-07-08 10:23:09,499: geological_model.py:609 -- deprecated method. Model data can now be set using the data attribute
# WARNING: 2024-07-08 10:23:09,537: _fault_builder.py:208 -- There is no slip vector data for the fault, using vertical slip vector
#                           projected onto fault surface estimating from fault normal
# WARNING: 2024-07-08 10:23:09,537: _fault_builder.py:239 -- Fault major axis using map length: 3640.0549446402592
# C:\Users\19904604\Anaconda3\envs\loop3denvu\lib\site-packages\LoopStructural\modelling\core\geological_model.py:647: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = cm.get_cmap(cmap, n_units)
# Fault included!
# {'upper': 0, 'upper_unconformity': 1, 'Fault': 2, 'lower': 3}
# Creating lithology and discretisation arrays for  FD_128.0  ...
# Time taken =  23.969609
# Creating property arrays for  FD_128.0  ...
# Time taken =  0.010194
# Adding flow packages to  FD_128.0  ...
# Time taken =  0.863224
# Writing simulation and gwf for  FD_128.0  ...
# FD_128.0
# WARNING: Unable to resolve dimension of ('gwf6', 'disu', 'cell2d', 'cell2d', 'icvert') based on shape "ncvert".
# Running simulation for  FD_128.0  ...
# Period =  Steady
# Model success =  True
# run_time =  28.827783
# WARNING: 2024-07-08 10:24:04,240: geological_model.py:609 -- deprecated method. Model data can now be set using the data attribute
# WARNING: 2024-07-08 10:24:04,274: _fault_builder.py:208 -- There is no slip vector data for the fault, using vertical slip vector
#                           projected onto fault surface estimating from fault normal
# WARNING: 2024-07-08 10:24:04,274: _fault_builder.py:239 -- Fault major axis using map length: 3640.0549446402592
# C:\Users\19904604\Anaconda3\envs\loop3denvu\lib\site-packages\LoopStructural\modelling\core\geological_model.py:647: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = cm.get_cmap(cmap, n_units)
# Fault included!
# {'upper': 0, 'upper_unconformity': 1, 'Fault': 2, 'lower': 3}
# Creating lithology and discretisation arrays for  FD_192.0  ...
# Time taken =  23.410856
# Creating property arrays for  FD_192.0  ...
# Time taken =  0.010018
# Adding flow packages to  FD_192.0  ...
# Time taken =  0.868973
# Writing simulation and gwf for  FD_192.0  ...
# FD_192.0
# WARNING: Unable to resolve dimension of ('gwf6', 'disu', 'cell2d', 'cell2d', 'icvert') based on shape "ncvert".
# Running simulation for  FD_192.0  ...
# Period =  Steady
# Model success =  True
# run_time =  31.627157
# WARNING: 2024-07-08 10:25:01,322: geological_model.py:609 -- deprecated method. Model data can now be set using the data attribute
# WARNING: 2024-07-08 10:25:01,353: _fault_builder.py:208 -- There is no slip vector data for the fault, using vertical slip vector
#                           projected onto fault surface estimating from fault normal
# WARNING: 2024-07-08 10:25:01,353: _fault_builder.py:239 -- Fault major axis using map length: 3640.0549446402592
# C:\Users\19904604\Anaconda3\envs\loop3denvu\lib\site-packages\LoopStructural\modelling\core\geological_model.py:647: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = cm.get_cmap(cmap, n_units)
# Fault included!
# {'upper': 0, 'upper_unconformity': 1, 'Fault': 2, 'lower': 3}
# Creating lithology and discretisation arrays for  FD_256.0  ...
# Time taken =  25.855224
# Creating property arrays for  FD_256.0  ...
# Time taken =  0.008141
# Adding flow packages to  FD_256.0  ...
# Time taken =  0.846768
# Writing simulation and gwf for  FD_256.0  ...
# FD_256.0
# WARNING: Unable to resolve dimension of ('gwf6', 'disu', 'cell2d', 'cell2d', 'icvert') based on shape "ncvert".
# Running simulation for  FD_256.0  ...
# Period =  Steady
# Model success =  True
# run_time =  33.919801
# WARNING: 2024-07-08 10:26:02,971: geological_model.py:609 -- deprecated method. Model data can now be set using the data attribute
# WARNING: 2024-07-08 10:26:03,001: _fault_builder.py:208 -- There is no slip vector data for the fault, using vertical slip vector
#                           projected onto fault surface estimating from fault normal
# WARNING: 2024-07-08 10:26:03,001: _fault_builder.py:239 -- Fault major axis using map length: 3640.0549446402592
# C:\Users\19904604\Anaconda3\envs\loop3denvu\lib\site-packages\LoopStructural\modelling\core\geological_model.py:647: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = cm.get_cmap(cmap, n_units)
# Fault included!
# {'upper': 0, 'upper_unconformity': 1, 'Fault': 2, 'lower': 3}
# Creating lithology and discretisation arrays for  FD_320.0  ...
# Time taken =  23.105176
# Creating property arrays for  FD_320.0  ...
# Time taken =  0.008171
# Adding flow packages to  FD_320.0  ...
# Time taken =  0.964268
# Writing simulation and gwf for  FD_320.0  ...
# FD_320.0
# WARNING: Unable to resolve dimension of ('gwf6', 'disu', 'cell2d', 'cell2d', 'icvert') based on shape "ncvert".
# Running simulation for  FD_320.0  ...
# Period =  Steady
# Model success =  True
# run_time =  39.541254

# %%
# PLOTS
#plot_bores(P)
#plot_observations(heads = fault_obs_heads, modelnames = fault_modelnames, ylim = [-40, -5])
#plot_bylayer(P, models = fault_models, layer = 2, vmin = -35, vmax = -10) 
#multiplot_vgrid_transect(P, models = fault_models, array = 'lith', X0 = P.x0, Y0 = P.y0, X1 = P.x1, Y1 = P.y1)
#multiplot_prop_transect(P, models = fault_models, array = 'head_ss', X0 = P.x0, Y0 = P.y0, X1 = P.x1, Y1 = P.y1,)

# %%
figure4(P, models = fault_models, X0 = P.x0, Y0 = P.y0, X1 = P.x1, Y1 = P.y1,)
# Out:
# C:\Users\19904604\AppData\Local\Temp\ipykernel_9368\3914122690.py:72: UserWarning: Warning: converting a masked element to nan.
#   if math.isnan(h) == False:
# C:\Users\19904604\AppData\Local\Temp\ipykernel_9368\3914122690.py:72: UserWarning: Warning: converting a masked element to nan.
#   if math.isnan(h) == False:
# C:\Users\19904604\AppData\Local\Temp\ipykernel_9368\3914122690.py:72: UserWarning: Warning: converting a masked element to nan.
#   if math.isnan(h) == False:
# C:\Users\19904604\AppData\Local\Temp\ipykernel_9368\3914122690.py:104: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()
# C:\Users\19904604\AppData\Local\Temp\ipykernel_9368\3914122690.py:104: UserWarning: tight_layout not applied: number of columns in subplot specifications must be multiples of one another.
#   plt.tight_layout()

# %% [markdown]
# ### Pinchout - 6 simulations

# %%
P.hk = [1, 0.1, 10, 0.1] 
P.vk = [i/10 for i in P.hk]

P.cell2dvor, P.xcycvor, P.verticesvor, P.vor, vornodes = createcell2d(P, grid = 'vor', fault = False)    
data = pd.read_excel("../data/loop_showcase_data.xls",sheet_name = "pinchout_example")
strat = pd.read_excel("../data/loop_showcase_data.xls",sheet_name = "strat")

options = np.linspace(-250, 0, 6) # control point z values

pinchout_modelnames, pinchout_models, pinchout_obs_heads = [],[],[]        
heads = []

for i in range(len(options)):
    pinchout_modelnames.append(str('PO_'+str(options[i])))  
    pinchout_models.append(Model(pinchout_modelnames[i], P, plan = 'vor', transect = 'con')) # Create flow model  
    P.control_points = (['CP1', 'control', 3000, 3000, options[i], -200, 'c', 'lower', np.nan, np.nan, np.nan],) 
    
    P.data, P.strat = prepare_geomodel_loopshowcase(P, data, strat, include_fault = False)   # Prepare geomodel inputs
    P.geomodel = create_geomodel_loopshowcase(P, include_fault = False) # Make geomodel
    M = pinchout_models[i]
    M.create_lith_dis_arrays(P)                                 # Create lith and dis arrays
    M.create_prop_arrays(P)                                     # Create K arrays
    M.create_flow_package_arrays(P)                             # Create flow packages
    M.gwf, M.head_ss, M.obs_ss, M.runtime_ss = M.write_run_model(P, period = 'Steady', ic_array = P.strt)   
    pinchout_obs_heads.append((process_obs_steady(P, M)))
    heads.append((M.head_ss))
    f = os.path.join(vtk_workspace, "pinchouts", M.modelname)
    M.gwf.export(f, fmt="vtk")
# Out:
# WARNING: 2024-07-08 10:27:14,781: geological_model.py:609 -- deprecated method. Model data can now be set using the data attribute
# C:\Users\19904604\Anaconda3\envs\loop3denvu\lib\site-packages\LoopStructural\modelling\core\geological_model.py:647: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = cm.get_cmap(cmap, n_units)
# {'upper': 0, 'upper_unconformity': 1, 'lower': 2}
# Creating lithology and discretisation arrays for  PO_-250.0  ...
# Time taken =  2.111638
# Creating property arrays for  PO_-250.0  ...
# Time taken =  0.0
# Adding flow packages to  PO_-250.0  ...
# Time taken =  0.612556
# Writing simulation and gwf for  PO_-250.0  ...
# PO_-250.0
# WARNING: Unable to resolve dimension of ('gwf6', 'disu', 'cell2d', 'cell2d', 'icvert') based on shape "ncvert".
# Running simulation for  PO_-250.0  ...
# Period =  Steady
# Model success =  True
# run_time =  16.013503
# WARNING: 2024-07-08 10:27:34,189: geological_model.py:609 -- deprecated method. Model data can now be set using the data attribute
# C:\Users\19904604\Anaconda3\envs\loop3denvu\lib\site-packages\LoopStructural\modelling\core\geological_model.py:647: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = cm.get_cmap(cmap, n_units)
# {'upper': 0, 'upper_unconformity': 1, 'lower': 2}
# Creating lithology and discretisation arrays for  PO_-200.0  ...
# Time taken =  1.948205
# Creating property arrays for  PO_-200.0  ...
# Time taken =  0.0
# Adding flow packages to  PO_-200.0  ...
# Time taken =  0.671863
# Writing simulation and gwf for  PO_-200.0  ...
# PO_-200.0
# WARNING: Unable to resolve dimension of ('gwf6', 'disu', 'cell2d', 'cell2d', 'icvert') based on shape "ncvert".
# Running simulation for  PO_-200.0  ...
# Period =  Steady
# Model success =  True
# run_time =  25.314136
# WARNING: 2024-07-08 10:28:02,781: geological_model.py:609 -- deprecated method. Model data can now be set using the data attribute
# C:\Users\19904604\Anaconda3\envs\loop3denvu\lib\site-packages\LoopStructural\modelling\core\geological_model.py:647: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = cm.get_cmap(cmap, n_units)
# {'upper': 0, 'upper_unconformity': 1, 'lower': 2}
# Creating lithology and discretisation arrays for  PO_-150.0  ...
# Time taken =  1.824866
# Creating property arrays for  PO_-150.0  ...
# Time taken =  0.008082
# Adding flow packages to  PO_-150.0  ...
# Time taken =  0.694798
# Writing simulation and gwf for  PO_-150.0  ...
# PO_-150.0
# WARNING: Unable to resolve dimension of ('gwf6', 'disu', 'cell2d', 'cell2d', 'icvert') based on shape "ncvert".
# Running simulation for  PO_-150.0  ...
# Period =  Steady
# Model success =  True
# run_time =  15.860393
# WARNING: 2024-07-08 10:28:21,750: geological_model.py:609 -- deprecated method. Model data can now be set using the data attribute
# C:\Users\19904604\Anaconda3\envs\loop3denvu\lib\site-packages\LoopStructural\modelling\core\geological_model.py:647: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = cm.get_cmap(cmap, n_units)
# {'upper': 0, 'upper_unconformity': 1, 'lower': 2}
# Creating lithology and discretisation arrays for  PO_-100.0  ...
# Time taken =  1.942748
# Creating property arrays for  PO_-100.0  ...
# Time taken =  0.00804
# Adding flow packages to  PO_-100.0  ...
# Time taken =  0.703698
# Writing simulation and gwf for  PO_-100.0  ...
# PO_-100.0
# WARNING: Unable to resolve dimension of ('gwf6', 'disu', 'cell2d', 'cell2d', 'icvert') based on shape "ncvert".
# Running simulation for  PO_-100.0  ...
# Period =  Steady
# Model success =  True
# run_time =  19.620363
# WARNING: 2024-07-08 10:28:44,588: geological_model.py:609 -- deprecated method. Model data can now be set using the data attribute
# C:\Users\19904604\Anaconda3\envs\loop3denvu\lib\site-packages\LoopStructural\modelling\core\geological_model.py:647: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = cm.get_cmap(cmap, n_units)
# {'upper': 0, 'upper_unconformity': 1, 'lower': 2}
# Creating lithology and discretisation arrays for  PO_-50.0  ...
# Time taken =  1.966406
# Creating property arrays for  PO_-50.0  ...
# Time taken =  0.008051
# Adding flow packages to  PO_-50.0  ...
# Time taken =  0.684451
# Writing simulation and gwf for  PO_-50.0  ...
# PO_-50.0
# WARNING: Unable to resolve dimension of ('gwf6', 'disu', 'cell2d', 'cell2d', 'icvert') based on shape "ncvert".
# Running simulation for  PO_-50.0  ...
# Period =  Steady
# Model success =  True
# run_time =  71.114617
# WARNING: 2024-07-08 10:29:59,045: geological_model.py:609 -- deprecated method. Model data can now be set using the data attribute
# C:\Users\19904604\Anaconda3\envs\loop3denvu\lib\site-packages\LoopStructural\modelling\core\geological_model.py:647: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = cm.get_cmap(cmap, n_units)
# {'upper': 0, 'upper_unconformity': 1, 'lower': 2}
# Creating lithology and discretisation arrays for  PO_0.0  ...
# Time taken =  1.978992
# Creating property arrays for  PO_0.0  ...
# Time taken =  0.010208
# Adding flow packages to  PO_0.0  ...
# Time taken =  0.711986
# Writing simulation and gwf for  PO_0.0  ...
# PO_0.0
# WARNING: Unable to resolve dimension of ('gwf6', 'disu', 'cell2d', 'cell2d', 'icvert') based on shape "ncvert".
# Running simulation for  PO_0.0  ...
# Period =  Steady
# Model success =  True
# run_time =  11.290352

# %%
#plot_bylayer(P, models = pinchout_models, layer = 1, vmin = -40, vmax = 20) 
#plot_observations(ylim = [-40, 20], modelnames = pinchout_modelnames, heads = pinchout_obs_heads)
#multiplot_vgrid_transect(P, models = pinchout_models, array = 'lith', X0 = P.x0, Y0 = P.y0, X1 = P.x1, Y1 = P.y1,)
#multiplot_prop_transect(P, models = pinchout_models, array = 'head_ss', 
                        #X0 = P.x0, Y0 = P.y0, X1 = P.x1, Y1 = P.y1, vmin = -45, vmax = 10)

# %%
# %run ./loop_showcase_functions.ipynb
figure3(P, models = pinchout_models, X0 = P.x0, Y0 = P.y0, X1 = P.x1, Y1 = P.y1,)
# Out:
# C:\Users\19904604\AppData\Local\Temp\ipykernel_9368\555634781.py:84: UserWarning: Warning: converting a masked element to nan.
#   if math.isnan(h) == False:
# C:\Users\19904604\AppData\Local\Temp\ipykernel_9368\555634781.py:84: UserWarning: Warning: converting a masked element to nan.
#   if math.isnan(h) == False:
# C:\Users\19904604\AppData\Local\Temp\ipykernel_9368\555634781.py:84: UserWarning: Warning: converting a masked element to nan.
#   if math.isnan(h) == False:
# C:\Users\19904604\AppData\Local\Temp\ipykernel_9368\555634781.py:116: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()
# C:\Users\19904604\AppData\Local\Temp\ipykernel_9368\555634781.py:116: UserWarning: tight_layout not applied: number of columns in subplot specifications must be multiples of one another.
#   plt.tight_layout()

# %% [markdown]
# ### Pinchout - 100 simulations

# %%
options = np.linspace(-250, 0, 100) # control point z values
    
heads_PO = []
for i in range(len(options)): 
    M = Model('PO', P, plan = 'vor', transect = 'con') # Create flow model  
    P.control_points = (['CP1', 'control', 3000, 3000, options[i], -200, 'c', 'lower', np.nan, np.nan, np.nan],) 
    P.data, P.strat = prepare_geomodel_loopshowcase(P, data, strat, include_fault = False)   # Prepare geomodel inputs
    P.geomodel = create_geomodel_loopshowcase(P, include_fault = False) # Make geomodel
    M.create_lith_dis_arrays(P)                                 # Create lith and dis arrays
    M.create_prop_arrays(P)                                     # Create K arrays
    M.create_flow_package_arrays(P)                             # Create flow packages
    M.gwf, M.head_ss, M.obs_ss, M.runtime_ss = M.write_run_model(P, period = 'Steady', ic_array = P.strt)   
    heads_PO.append((M.head_ss))
# Out:
# WARNING: 2024-07-08 10:30:18,832: geological_model.py:609 -- deprecated method. Model data can now be set using the data attribute
# C:\Users\19904604\Anaconda3\envs\loop3denvu\lib\site-packages\LoopStructural\modelling\core\geological_model.py:647: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = cm.get_cmap(cmap, n_units)
# {'upper': 0, 'upper_unconformity': 1, 'lower': 2}
# Creating lithology and discretisation arrays for  PO  ...
# Time taken =  1.881946
# Creating property arrays for  PO  ...
# Time taken =  0.008078
# Adding flow packages to  PO  ...
# Time taken =  0.682152
# Writing simulation and gwf for  PO  ...
# PO
# WARNING: Unable to resolve dimension of ('gwf6', 'disu', 'cell2d', 'cell2d', 'icvert') based on shape "ncvert".
# Running simulation for  PO  ...
# WARNING: 2024-07-08 10:30:38,704: geological_model.py:609 -- deprecated method. Model data can now be set using the data attribute
# Period =  Steady
# Model success =  True
# run_time =  17.255276
# {'upper': 0, 'upper_unconformity': 1, 'lower': 2}
# Creating lithology and discretisation arrays for  PO  ...
# C:\Users\19904604\Anaconda3\envs\loop3denvu\lib\site-packages\LoopStructural\modelling\core\geological_model.py:647: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = cm.get_cmap(cmap, n_units)
# Time taken =  1.881968
# Creating property arrays for  PO  ...
# Time taken =  0.008144
# Adding flow packages to  PO  ...
# Time taken =  0.663344
# Writing simulation and gwf for  PO  ...
# PO
# WARNING: Unable to resolve dimension of ('gwf6', 'disu', 'cell2d', 'cell2d', 'icvert') based on shape "ncvert".
# Running simulation for  PO  ...
# WARNING: 2024-07-08 10:30:57,519: geological_model.py:609 -- deprecated method. Model data can now be set using the data attribute
# Period =  Steady
# Model success =  True
# run_time =  16.219364
# {'upper': 0, 'upper_unconformity': 1, 'lower': 2}
# Creating lithology and discretisation arrays for  PO  ...
# C:\Users\19904604\Anaconda3\envs\loop3denvu\lib\site-packages\LoopStructural\modelling\core\geological_model.py:647: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = cm.get_cmap(cmap, n_units)
# Time taken =  1.887145
# Creating property arrays for  PO  ...
# Time taken =  0.008072
# Adding flow packages to  PO  ...
# Time taken =  0.732381
# Writing simulation and gwf for  PO  ...
# PO
# WARNING: Unable to resolve dimension of ('gwf6', 'disu', 'cell2d', 'cell2d', 'icvert') based on shape "ncvert".
# Running simulation for  PO  ...
# WARNING: 2024-07-08 10:31:15,178: geological_model.py:609 -- deprecated method. Model data can now be set using the data attribute
# Period =  Steady
# Model success =  True
# run_time =  14.998854
# {'upper': 0, 'upper_unconformity': 1, 'lower': 2}
# Creating lithology and discretisation arrays for  PO  ...
# C:\Users\19904604\Anaconda3\envs\loop3denvu\lib\site-packages\LoopStructural\modelling\core\geological_model.py:647: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = cm.get_cmap(cmap, n_units)
# Time taken =  1.844771
# Creating property arrays for  PO  ...
# Time taken =  0.010142
# Adding flow packages to  PO  ...
# Time taken =  0.76916
# Writing simulation and gwf for  PO  ...
# PO
# WARNING: Unable to resolve dimension of ('gwf6', 'disu', 'cell2d', 'cell2d', 'icvert') based on shape "ncvert".
# Running simulation for  PO  ...
# WARNING: 2024-07-08 10:31:32,436: geological_model.py:609 -- deprecated method. Model data can now be set using the data attribute
# Period =  Steady
# Model success =  True
# run_time =  14.588493
# {'upper': 0, 'upper_unconformity': 1, 'lower': 2}
# Creating lithology and discretisation arrays for  PO  ...
# C:\Users\19904604\Anaconda3\envs\loop3denvu\lib\site-packages\LoopStructural\modelling\core\geological_model.py:647: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = cm.get_cmap(cmap, n_units)
# Time taken =  2.031791
# Creating property arrays for  PO  ...
# Time taken =  0.008076
# Adding flow packages to  PO  ...
# Time taken =  0.673462
# Writing simulation and gwf for  PO  ...
# PO
# WARNING: Unable to resolve dimension of ('gwf6', 'disu', 'cell2d', 'cell2d', 'icvert') based on shape "ncvert".
# Running simulation for  PO  ...
# WARNING: 2024-07-08 10:31:50,724: geological_model.py:609 -- deprecated method. Model data can now be set using the data attribute
# Period =  Steady
# Model success =  True
# run_time =  15.536777
# {'upper': 0, 'upper_unconformity': 1, 'lower': 2}
# Creating lithology and discretisation arrays for  PO  ...
# C:\Users\19904604\Anaconda3\envs\loop3denvu\lib\site-packages\LoopStructural\modelling\core\geological_model.py:647: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = cm.get_cmap(cmap, n_units)
# Time taken =  1.979916
# Creating property arrays for  PO  ...
# Time taken =  0.008061
# Adding flow packages to  PO  ...
# Time taken =  0.701012
# Writing simulation and gwf for  PO  ...
# PO
# WARNING: Unable to resolve dimension of ('gwf6', 'disu', 'cell2d', 'cell2d', 'icvert') based on shape "ncvert".
# Running simulation for  PO  ...
# WARNING: 2024-07-08 10:32:08,124: geological_model.py:609 -- deprecated method. Model data can now be set using the data attribute
# Period =  Steady
# Model success =  True
# run_time =  14.662128
# {'upper': 0, 'upper_unconformity': 1, 'lower': 2}
# Creating lithology and discretisation arrays for  PO  ...
# C:\Users\19904604\Anaconda3\envs\loop3denvu\lib\site-packages\LoopStructural\modelling\core\geological_model.py:647: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = cm.get_cmap(cmap, n_units)
# Time taken =  1.894971
# Creating property arrays for  PO  ...
# Time taken =  0.010085
# Adding flow packages to  PO  ...
# Time taken =  0.672145
# Writing simulation and gwf for  PO  ...
# PO
# WARNING: Unable to resolve dimension of ('gwf6', 'disu', 'cell2d', 'cell2d', 'icvert') based on shape "ncvert".
# Running simulation for  PO  ...
# WARNING: 2024-07-08 10:32:26,273: geological_model.py:609 -- deprecated method. Model data can now be set using the data attribute
# Period =  Steady
# Model success =  True
# run_time =  15.531356
# {'upper': 0, 'upper_unconformity': 1, 'lower': 2}
# Creating lithology and discretisation arrays for  PO  ...
# C:\Users\19904604\Anaconda3\envs\loop3denvu\lib\site-packages\LoopStructural\modelling\core\geological_model.py:647: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = cm.get_cmap(cmap, n_units)
# Time taken =  1.836171
# Creating property arrays for  PO  ...
# Time taken =  0.010166
# Adding flow packages to  PO  ...
# Time taken =  0.680654
# Writing simulation and gwf for  PO  ...
# PO
# WARNING: Unable to resolve dimension of ('gwf6', 'disu', 'cell2d', 'cell2d', 'icvert') based on shape "ncvert".
# Running simulation for  PO  ...
# WARNING: 2024-07-08 10:32:44,370: geological_model.py:609 -- deprecated method. Model data can now be set using the data attribute
# Period =  Steady
# Model success =  True
# run_time =  15.533489
# {'upper': 0, 'upper_unconformity': 1, 'lower': 2}
# Creating lithology and discretisation arrays for  PO  ...
# C:\Users\19904604\Anaconda3\envs\loop3denvu\lib\site-packages\LoopStructural\modelling\core\geological_model.py:647: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = cm.get_cmap(cmap, n_units)
# Time taken =  1.872369
# Creating property arrays for  PO  ...
# Time taken =  0.010101
# Adding flow packages to  PO  ...
# Time taken =  0.692495
# Writing simulation and gwf for  PO  ...
# PO
# WARNING: Unable to resolve dimension of ('gwf6', 'disu', 'cell2d', 'cell2d', 'icvert') based on shape "ncvert".
# Running simulation for  PO  ...
# WARNING: 2024-07-08 10:33:09,169: geological_model.py:609 -- deprecated method. Model data can now be set using the data attribute
# Period =  Steady
# Model success =  True
# run_time =  22.186638
# {'upper': 0, 'upper_unconformity': 1, 'lower': 2}
# Creating lithology and discretisation arrays for  PO  ...
# C:\Users\19904604\Anaconda3\envs\loop3denvu\lib\site-packages\LoopStructural\modelling\core\geological_model.py:647: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = cm.get_cmap(cmap, n_units)
# Time taken =  1.993373
# Creating property arrays for  PO  ...
# Time taken =  0.010085
# Adding flow packages to  PO  ...
# Time taken =  0.673519
# Writing simulation and gwf for  PO  ...
# PO
# WARNING: Unable to resolve dimension of ('gwf6', 'disu', 'cell2d', 'cell2d', 'icvert') based on shape "ncvert".
# Running simulation for  PO  ...
# WARNING: 2024-07-08 10:33:35,167: geological_model.py:609 -- deprecated method. Model data can now be set using the data attribute
# Period =  Steady
# Model success =  True
# run_time =  23.285036
# {'upper': 0, 'upper_unconformity': 1, 'lower': 2}
# Creating lithology and discretisation arrays for  PO  ...
# C:\Users\19904604\Anaconda3\envs\loop3denvu\lib\site-packages\LoopStructural\modelling\core\geological_model.py:647: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = cm.get_cmap(cmap, n_units)
# Time taken =  1.873139
# Creating property arrays for  PO  ...
# Time taken =  0.008066
# Adding flow packages to  PO  ...
# Time taken =  0.694919
# Writing simulation and gwf for  PO  ...
# PO
# WARNING: Unable to resolve dimension of ('gwf6', 'disu', 'cell2d', 'cell2d', 'icvert') based on shape "ncvert".
# Running simulation for  PO  ...
# WARNING: 2024-07-08 10:34:00,873: geological_model.py:609 -- deprecated method. Model data can now be set using the data attribute
# Period =  Steady
# Model success =  True
# run_time =  23.085409
# {'upper': 0, 'upper_unconformity': 1, 'lower': 2}
# Creating lithology and discretisation arrays for  PO  ...
# C:\Users\19904604\Anaconda3\envs\loop3denvu\lib\site-packages\LoopStructural\modelling\core\geological_model.py:647: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = cm.get_cmap(cmap, n_units)
# Time taken =  1.960054
# Creating property arrays for  PO  ...
# Time taken =  0.01017
# Adding flow packages to  PO  ...
# Time taken =  0.671246
# Writing simulation and gwf for  PO  ...
# PO
# WARNING: Unable to resolve dimension of ('gwf6', 'disu', 'cell2d', 'cell2d', 'icvert') based on shape "ncvert".
# Running simulation for  PO  ...
# WARNING: 2024-07-08 10:34:18,548: geological_model.py:609 -- deprecated method. Model data can now be set using the data attribute
# Period =  Steady
# Model success =  True
# run_time =  14.998148
# {'upper': 0, 'upper_unconformity': 1, 'lower': 2}
# Creating lithology and discretisation arrays for  PO  ...
# C:\Users\19904604\Anaconda3\envs\loop3denvu\lib\site-packages\LoopStructural\modelling\core\geological_model.py:647: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = cm.get_cmap(cmap, n_units)
# Time taken =  1.859283
# Creating property arrays for  PO  ...
# Time taken =  0.002082
# Adding flow packages to  PO  ...
# Time taken =  0.671789
# Writing simulation and gwf for  PO  ...
# PO
# WARNING: Unable to resolve dimension of ('gwf6', 'disu', 'cell2d', 'cell2d', 'icvert') based on shape "ncvert".
# Running simulation for  PO  ...
# WARNING: 2024-07-08 10:34:45,874: geological_model.py:609 -- deprecated method. Model data can now be set using the data attribute
# Period =  Steady
# Model success =  True
# run_time =  24.754622
# {'upper': 0, 'upper_unconformity': 1, 'lower': 2}
# Creating lithology and discretisation arrays for  PO  ...
# C:\Users\19904604\Anaconda3\envs\loop3denvu\lib\site-packages\LoopStructural\modelling\core\geological_model.py:647: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = cm.get_cmap(cmap, n_units)
# Time taken =  2.065702
# Creating property arrays for  PO  ...
# Time taken =  0.002073
# Adding flow packages to  PO  ...
# Time taken =  0.681397
# Writing simulation and gwf for  PO  ...
# PO
# WARNING: Unable to resolve dimension of ('gwf6', 'disu', 'cell2d', 'cell2d', 'icvert') based on shape "ncvert".
# Running simulation for  PO  ...
# WARNING: 2024-07-08 10:35:12,443: geological_model.py:609 -- deprecated method. Model data can now be set using the data attribute
# Period =  Steady
# Model success =  True
# run_time =  23.769589
# {'upper': 0, 'upper_unconformity': 1, 'lower': 2}
# Creating lithology and discretisation arrays for  PO  ...
# C:\Users\19904604\Anaconda3\envs\loop3denvu\lib\site-packages\LoopStructural\modelling\core\geological_model.py:647: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = cm.get_cmap(cmap, n_units)
# Time taken =  2.842237
# Creating property arrays for  PO  ...
# Time taken =  0.0
# Adding flow packages to  PO  ...
# Time taken =  1.895583
# Writing simulation and gwf for  PO  ...
# PO
# WARNING: Unable to resolve dimension of ('gwf6', 'disu', 'cell2d', 'cell2d', 'icvert') based on shape "ncvert".
# Running simulation for  PO  ...
# WARNING: 2024-07-08 10:35:42,475: geological_model.py:609 -- deprecated method. Model data can now be set using the data attribute
# Period =  Steady
# Model success =  True
# run_time =  25.246229
# {'upper': 0, 'upper_unconformity': 1, 'lower': 2}
# Creating lithology and discretisation arrays for  PO  ...
# C:\Users\19904604\Anaconda3\envs\loop3denvu\lib\site-packages\LoopStructural\modelling\core\geological_model.py:647: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = cm.get_cmap(cmap, n_units)
# Time taken =  1.901876
# Creating property arrays for  PO  ...
# Time taken =  0.010143
# Adding flow packages to  PO  ...
# Time taken =  0.639244
# Writing simulation and gwf for  PO  ...
# PO
# WARNING: Unable to resolve dimension of ('gwf6', 'disu', 'cell2d', 'cell2d', 'icvert') based on shape "ncvert".
# Running simulation for  PO  ...
# WARNING: 2024-07-08 10:36:03,490: geological_model.py:609 -- deprecated method. Model data can now be set using the data attribute
# Period =  Steady
# Model success =  True
# run_time =  18.420427
# {'upper': 0, 'upper_unconformity': 1, 'lower': 2}
# Creating lithology and discretisation arrays for  PO  ...
# C:\Users\19904604\Anaconda3\envs\loop3denvu\lib\site-packages\LoopStructural\modelling\core\geological_model.py:647: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = cm.get_cmap(cmap, n_units)
# Time taken =  1.887797
# Creating property arrays for  PO  ...
# Time taken =  0.002104
# Adding flow packages to  PO  ...
# Time taken =  0.651727
# Writing simulation and gwf for  PO  ...
# PO
# WARNING: Unable to resolve dimension of ('gwf6', 'disu', 'cell2d', 'cell2d', 'icvert') based on shape "ncvert".
# Running simulation for  PO  ...
# WARNING: 2024-07-08 10:38:21,689: geological_model.py:609 -- deprecated method. Model data can now be set using the data attribute
# Period =  Steady
# Model success =  True
# run_time =  135.611488
# {'upper': 0, 'upper_unconformity': 1, 'lower': 2}
# Creating lithology and discretisation arrays for  PO  ...
# C:\Users\19904604\Anaconda3\envs\loop3denvu\lib\site-packages\LoopStructural\modelling\core\geological_model.py:647: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = cm.get_cmap(cmap, n_units)
# Time taken =  1.937168
# Creating property arrays for  PO  ...
# Time taken =  0.01563
# Adding flow packages to  PO  ...
# Time taken =  0.686654
# Writing simulation and gwf for  PO  ...
# PO
# WARNING: Unable to resolve dimension of ('gwf6', 'disu', 'cell2d', 'cell2d', 'icvert') based on shape "ncvert".
# Running simulation for  PO  ...
# WARNING: 2024-07-08 10:38:47,652: geological_model.py:609 -- deprecated method. Model data can now be set using the data attribute
# Period =  Steady
# Model success =  True
# run_time =  23.286211
# {'upper': 0, 'upper_unconformity': 1, 'lower': 2}
# Creating lithology and discretisation arrays for  PO  ...
# C:\Users\19904604\Anaconda3\envs\loop3denvu\lib\site-packages\LoopStructural\modelling\core\geological_model.py:647: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = cm.get_cmap(cmap, n_units)
# Time taken =  1.926212
# Creating property arrays for  PO  ...
# Time taken =  0.008053
# Adding flow packages to  PO  ...
# Time taken =  0.633194
# Writing simulation and gwf for  PO  ...
# PO
# WARNING: Unable to resolve dimension of ('gwf6', 'disu', 'cell2d', 'cell2d', 'icvert') based on shape "ncvert".
# Running simulation for  PO  ...
# WARNING: 2024-07-08 10:39:12,560: geological_model.py:609 -- deprecated method. Model data can now be set using the data attribute
# Period =  Steady
# Model success =  True
# run_time =  22.297867
# {'upper': 0, 'upper_unconformity': 1, 'lower': 2}
# Creating lithology and discretisation arrays for  PO  ...
# C:\Users\19904604\Anaconda3\envs\loop3denvu\lib\site-packages\LoopStructural\modelling\core\geological_model.py:647: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = cm.get_cmap(cmap, n_units)
# Time taken =  1.852545
# Creating property arrays for  PO  ...
# Time taken =  0.002075
# Adding flow packages to  PO  ...
# Time taken =  0.739692
# Writing simulation and gwf for  PO  ...
# PO
# WARNING: Unable to resolve dimension of ('gwf6', 'disu', 'cell2d', 'cell2d', 'icvert') based on shape "ncvert".
# Running simulation for  PO  ...
# WARNING: 2024-07-08 10:39:37,749: geological_model.py:609 -- deprecated method. Model data can now be set using the data attribute
# Period =  Steady
# Model success =  True
# run_time =  22.552053
# {'upper': 0, 'upper_unconformity': 1, 'lower': 2}
# Creating lithology and discretisation arrays for  PO  ...
# C:\Users\19904604\Anaconda3\envs\loop3denvu\lib\site-packages\LoopStructural\modelling\core\geological_model.py:647: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = cm.get_cmap(cmap, n_units)
# Time taken =  1.96148
# Creating property arrays for  PO  ...
# Time taken =  0.0
# Adding flow packages to  PO  ...
# Time taken =  0.66401
# Writing simulation and gwf for  PO  ...
# PO
# WARNING: Unable to resolve dimension of ('gwf6', 'disu', 'cell2d', 'cell2d', 'icvert') based on shape "ncvert".
# Running simulation for  PO  ...
# WARNING: 2024-07-08 10:39:56,966: geological_model.py:609 -- deprecated method. Model data can now be set using the data attribute
# Period =  Steady
# Model success =  True
# run_time =  16.561188
# {'upper': 0, 'upper_unconformity': 1, 'lower': 2}
# Creating lithology and discretisation arrays for  PO  ...
# C:\Users\19904604\Anaconda3\envs\loop3denvu\lib\site-packages\LoopStructural\modelling\core\geological_model.py:647: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = cm.get_cmap(cmap, n_units)
# Time taken =  1.812864
# Creating property arrays for  PO  ...
# Time taken =  0.010289
# Adding flow packages to  PO  ...
# Time taken =  0.64229
# Writing simulation and gwf for  PO  ...
# PO
# WARNING: Unable to resolve dimension of ('gwf6', 'disu', 'cell2d', 'cell2d', 'icvert') based on shape "ncvert".
# Running simulation for  PO  ...
# WARNING: 2024-07-08 10:40:19,565: geological_model.py:609 -- deprecated method. Model data can now be set using the data attribute
# Period =  Steady
# Model success =  True
# run_time =  20.098981
# {'upper': 0, 'upper_unconformity': 1, 'lower': 2}
# Creating lithology and discretisation arrays for  PO  ...
# C:\Users\19904604\Anaconda3\envs\loop3denvu\lib\site-packages\LoopStructural\modelling\core\geological_model.py:647: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = cm.get_cmap(cmap, n_units)
# Time taken =  1.950728
# Creating property arrays for  PO  ...
# Time taken =  0.008125
# Adding flow packages to  PO  ...
# Time taken =  0.641501
# Writing simulation and gwf for  PO  ...
# PO
# WARNING: Unable to resolve dimension of ('gwf6', 'disu', 'cell2d', 'cell2d', 'icvert') based on shape "ncvert".
# Running simulation for  PO  ...
# WARNING: 2024-07-08 10:42:42,880: geological_model.py:609 -- deprecated method. Model data can now be set using the data attribute
# Period =  Steady
# Model success =  True
# run_time =  140.663289
# {'upper': 0, 'upper_unconformity': 1, 'lower': 2}
# Creating lithology and discretisation arrays for  PO  ...
# C:\Users\19904604\Anaconda3\envs\loop3denvu\lib\site-packages\LoopStructural\modelling\core\geological_model.py:647: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = cm.get_cmap(cmap, n_units)
# Time taken =  2.367252
# Creating property arrays for  PO  ...
# Time taken =  0.002137
# Adding flow packages to  PO  ...
# Time taken =  0.69035
# Writing simulation and gwf for  PO  ...
# PO
# WARNING: Unable to resolve dimension of ('gwf6', 'disu', 'cell2d', 'cell2d', 'icvert') based on shape "ncvert".
# Running simulation for  PO  ...
# WARNING: 2024-07-08 10:43:05,304: geological_model.py:609 -- deprecated method. Model data can now be set using the data attribute
# Period =  Steady
# Model success =  True
# run_time =  19.322297
# {'upper': 0, 'upper_unconformity': 1, 'lower': 2}
# Creating lithology and discretisation arrays for  PO  ...
# C:\Users\19904604\Anaconda3\envs\loop3denvu\lib\site-packages\LoopStructural\modelling\core\geological_model.py:647: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = cm.get_cmap(cmap, n_units)
# Time taken =  1.782085
# Creating property arrays for  PO  ...
# Time taken =  0.010207
# Adding flow packages to  PO  ...
# Time taken =  0.651422
# Writing simulation and gwf for  PO  ...
# PO
# WARNING: Unable to resolve dimension of ('gwf6', 'disu', 'cell2d', 'cell2d', 'icvert') based on shape "ncvert".
# Running simulation for  PO  ...
# WARNING: 2024-07-08 10:43:24,727: geological_model.py:609 -- deprecated method. Model data can now be set using the data attribute
# Period =  Steady
# Model success =  True
# run_time =  16.944347
# {'upper': 0, 'upper_unconformity': 1, 'lower': 2}
# Creating lithology and discretisation arrays for  PO  ...
# C:\Users\19904604\Anaconda3\envs\loop3denvu\lib\site-packages\LoopStructural\modelling\core\geological_model.py:647: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = cm.get_cmap(cmap, n_units)
# Time taken =  1.944678
# Creating property arrays for  PO  ...
# Time taken =  0.010104
# Adding flow packages to  PO  ...
# Time taken =  0.68091
# Writing simulation and gwf for  PO  ...
# PO
# WARNING: Unable to resolve dimension of ('gwf6', 'disu', 'cell2d', 'cell2d', 'icvert') based on shape "ncvert".
# Running simulation for  PO  ...
# WARNING: 2024-07-08 10:43:45,605: geological_model.py:609 -- deprecated method. Model data can now be set using the data attribute
# Period =  Steady
# Model success =  True
# run_time =  18.201307
# {'upper': 0, 'upper_unconformity': 1, 'lower': 2}
# Creating lithology and discretisation arrays for  PO  ...
# C:\Users\19904604\Anaconda3\envs\loop3denvu\lib\site-packages\LoopStructural\modelling\core\geological_model.py:647: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = cm.get_cmap(cmap, n_units)
# Time taken =  1.932598
# Creating property arrays for  PO  ...
# Time taken =  0.01027
# Adding flow packages to  PO  ...
# Time taken =  0.652715
# Writing simulation and gwf for  PO  ...
# PO
# WARNING: Unable to resolve dimension of ('gwf6', 'disu', 'cell2d', 'cell2d', 'icvert') based on shape "ncvert".
# Running simulation for  PO  ...
# WARNING: 2024-07-08 10:44:09,751: geological_model.py:609 -- deprecated method. Model data can now be set using the data attribute
# Period =  Steady
# Model success =  True
# run_time =  21.507879
# {'upper': 0, 'upper_unconformity': 1, 'lower': 2}
# Creating lithology and discretisation arrays for  PO  ...
# C:\Users\19904604\Anaconda3\envs\loop3denvu\lib\site-packages\LoopStructural\modelling\core\geological_model.py:647: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = cm.get_cmap(cmap, n_units)
# Time taken =  1.788217
# Creating property arrays for  PO  ...
# Time taken =  0.002061
# Adding flow packages to  PO  ...
# Time taken =  0.660964
# Writing simulation and gwf for  PO  ...
# PO
# WARNING: Unable to resolve dimension of ('gwf6', 'disu', 'cell2d', 'cell2d', 'icvert') based on shape "ncvert".
# Running simulation for  PO  ...
# WARNING: 2024-07-08 10:44:31,325: geological_model.py:609 -- deprecated method. Model data can now be set using the data attribute
# Period =  Steady
# Model success =  True
# run_time =  19.080867
# {'upper': 0, 'upper_unconformity': 1, 'lower': 2}
# Creating lithology and discretisation arrays for  PO  ...
# C:\Users\19904604\Anaconda3\envs\loop3denvu\lib\site-packages\LoopStructural\modelling\core\geological_model.py:647: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = cm.get_cmap(cmap, n_units)
# Time taken =  1.935068
# Creating property arrays for  PO  ...
# Time taken =  0.010227
# Adding flow packages to  PO  ...
# Time taken =  0.692652
# Writing simulation and gwf for  PO  ...
# PO
# WARNING: Unable to resolve dimension of ('gwf6', 'disu', 'cell2d', 'cell2d', 'icvert') based on shape "ncvert".
# Running simulation for  PO  ...
# WARNING: 2024-07-08 10:44:53,525: geological_model.py:609 -- deprecated method. Model data can now be set using the data attribute
# Period =  Steady
# Model success =  True
# run_time =  19.520872
# {'upper': 0, 'upper_unconformity': 1, 'lower': 2}
# Creating lithology and discretisation arrays for  PO  ...
# C:\Users\19904604\Anaconda3\envs\loop3denvu\lib\site-packages\LoopStructural\modelling\core\geological_model.py:647: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = cm.get_cmap(cmap, n_units)
# Time taken =  1.782936
# Creating property arrays for  PO  ...
# Time taken =  0.010222
# Adding flow packages to  PO  ...
# Time taken =  0.642293
# Writing simulation and gwf for  PO  ...
# PO
# WARNING: Unable to resolve dimension of ('gwf6', 'disu', 'cell2d', 'cell2d', 'icvert') based on shape "ncvert".
# Running simulation for  PO  ...
# WARNING: 2024-07-08 10:45:18,030: geological_model.py:609 -- deprecated method. Model data can now be set using the data attribute
# Period =  Steady
# Model success =  True
# run_time =  22.028697
# {'upper': 0, 'upper_unconformity': 1, 'lower': 2}
# Creating lithology and discretisation arrays for  PO  ...
# C:\Users\19904604\Anaconda3\envs\loop3denvu\lib\site-packages\LoopStructural\modelling\core\geological_model.py:647: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = cm.get_cmap(cmap, n_units)
# Time taken =  1.938149
# Creating property arrays for  PO  ...
# Time taken =  0.010136
# Adding flow packages to  PO  ...
# Time taken =  0.700361
# Writing simulation and gwf for  PO  ...
# PO
# WARNING: Unable to resolve dimension of ('gwf6', 'disu', 'cell2d', 'cell2d', 'icvert') based on shape "ncvert".
# Running simulation for  PO  ...
# WARNING: 2024-07-08 10:45:38,352: geological_model.py:609 -- deprecated method. Model data can now be set using the data attribute
# Period =  Steady
# Model success =  True
# run_time =  17.643403
# {'upper': 0, 'upper_unconformity': 1, 'lower': 2}
# Creating lithology and discretisation arrays for  PO  ...
# C:\Users\19904604\Anaconda3\envs\loop3denvu\lib\site-packages\LoopStructural\modelling\core\geological_model.py:647: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = cm.get_cmap(cmap, n_units)
# Time taken =  1.986189
# Creating property arrays for  PO  ...
# Time taken =  0.002044
# Adding flow packages to  PO  ...
# Time taken =  0.692982
# Writing simulation and gwf for  PO  ...
# PO
# WARNING: Unable to resolve dimension of ('gwf6', 'disu', 'cell2d', 'cell2d', 'icvert') based on shape "ncvert".
# Running simulation for  PO  ...
# WARNING: 2024-07-08 10:45:58,465: geological_model.py:609 -- deprecated method. Model data can now be set using the data attribute
# Period =  Steady
# Model success =  True
# run_time =  17.388708
# {'upper': 0, 'upper_unconformity': 1, 'lower': 2}
# Creating lithology and discretisation arrays for  PO  ...
# C:\Users\19904604\Anaconda3\envs\loop3denvu\lib\site-packages\LoopStructural\modelling\core\geological_model.py:647: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = cm.get_cmap(cmap, n_units)
# Time taken =  2.035168
# Creating property arrays for  PO  ...
# Time taken =  0.002055
# Adding flow packages to  PO  ...
# Time taken =  0.726673
# Writing simulation and gwf for  PO  ...
# PO
# WARNING: Unable to resolve dimension of ('gwf6', 'disu', 'cell2d', 'cell2d', 'icvert') based on shape "ncvert".
# Running simulation for  PO  ...
# WARNING: 2024-07-08 10:46:20,798: geological_model.py:609 -- deprecated method. Model data can now be set using the data attribute
# Period =  Steady
# Model success =  True
# run_time =  19.521288
# {'upper': 0, 'upper_unconformity': 1, 'lower': 2}
# Creating lithology and discretisation arrays for  PO  ...
# C:\Users\19904604\Anaconda3\envs\loop3denvu\lib\site-packages\LoopStructural\modelling\core\geological_model.py:647: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = cm.get_cmap(cmap, n_units)
# Time taken =  1.954518
# Creating property arrays for  PO  ...
# Time taken =  0.008033
# Adding flow packages to  PO  ...
# Time taken =  0.651836
# Writing simulation and gwf for  PO  ...
# PO
# WARNING: Unable to resolve dimension of ('gwf6', 'disu', 'cell2d', 'cell2d', 'icvert') based on shape "ncvert".
# Running simulation for  PO  ...
# WARNING: 2024-07-08 10:46:44,534: geological_model.py:609 -- deprecated method. Model data can now be set using the data attribute
# Period =  Steady
# Model success =  True
# run_time =  21.08928
# {'upper': 0, 'upper_unconformity': 1, 'lower': 2}
# Creating lithology and discretisation arrays for  PO  ...
# C:\Users\19904604\Anaconda3\envs\loop3denvu\lib\site-packages\LoopStructural\modelling\core\geological_model.py:647: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = cm.get_cmap(cmap, n_units)
# Time taken =  1.967091
# Creating property arrays for  PO  ...
# Time taken =  0.008128
# Adding flow packages to  PO  ...
# Time taken =  0.655763
# Writing simulation and gwf for  PO  ...
# PO
# WARNING: Unable to resolve dimension of ('gwf6', 'disu', 'cell2d', 'cell2d', 'icvert') based on shape "ncvert".
# Running simulation for  PO  ...
# WARNING: 2024-07-08 10:47:04,837: geological_model.py:609 -- deprecated method. Model data can now be set using the data attribute
# Period =  Steady
# Model success =  True
# run_time =  17.639434
# {'upper': 0, 'upper_unconformity': 1, 'lower': 2}
# Creating lithology and discretisation arrays for  PO  ...
# C:\Users\19904604\Anaconda3\envs\loop3denvu\lib\site-packages\LoopStructural\modelling\core\geological_model.py:647: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = cm.get_cmap(cmap, n_units)
# Time taken =  2.077189
# Creating property arrays for  PO  ...
# Time taken =  0.002136
# Adding flow packages to  PO  ...
# Time taken =  0.780898
# Writing simulation and gwf for  PO  ...
# PO
# WARNING: Unable to resolve dimension of ('gwf6', 'disu', 'cell2d', 'cell2d', 'icvert') based on shape "ncvert".
# Running simulation for  PO  ...
# WARNING: 2024-07-08 10:47:26,292: geological_model.py:609 -- deprecated method. Model data can now be set using the data attribute
# Period =  Steady
# Model success =  True
# run_time =  18.551681
# {'upper': 0, 'upper_unconformity': 1, 'lower': 2}
# Creating lithology and discretisation arrays for  PO  ...
# C:\Users\19904604\Anaconda3\envs\loop3denvu\lib\site-packages\LoopStructural\modelling\core\geological_model.py:647: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = cm.get_cmap(cmap, n_units)
# Time taken =  1.773189
# Creating property arrays for  PO  ...
# Time taken =  0.010086
# Adding flow packages to  PO  ...
# Time taken =  0.652561
# Writing simulation and gwf for  PO  ...
# PO
# WARNING: Unable to resolve dimension of ('gwf6', 'disu', 'cell2d', 'cell2d', 'icvert') based on shape "ncvert".
# Running simulation for  PO  ...
# WARNING: 2024-07-08 10:47:45,599: geological_model.py:609 -- deprecated method. Model data can now be set using the data attribute
# Period =  Steady
# Model success =  True
# run_time =  16.8307
# {'upper': 0, 'upper_unconformity': 1, 'lower': 2}
# Creating lithology and discretisation arrays for  PO  ...
# C:\Users\19904604\Anaconda3\envs\loop3denvu\lib\site-packages\LoopStructural\modelling\core\geological_model.py:647: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = cm.get_cmap(cmap, n_units)
# Time taken =  1.954284
# Creating property arrays for  PO  ...
# Time taken =  0.008064
# Adding flow packages to  PO  ...
# Time taken =  0.663381
# Writing simulation and gwf for  PO  ...
# PO
# WARNING: Unable to resolve dimension of ('gwf6', 'disu', 'cell2d', 'cell2d', 'icvert') based on shape "ncvert".
# Running simulation for  PO  ...
# WARNING: 2024-07-08 10:48:07,666: geological_model.py:609 -- deprecated method. Model data can now be set using the data attribute
# Period =  Steady
# Model success =  True
# run_time =  19.409242
# {'upper': 0, 'upper_unconformity': 1, 'lower': 2}
# Creating lithology and discretisation arrays for  PO  ...
# C:\Users\19904604\Anaconda3\envs\loop3denvu\lib\site-packages\LoopStructural\modelling\core\geological_model.py:647: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = cm.get_cmap(cmap, n_units)
# Time taken =  1.794325
# Creating property arrays for  PO  ...
# Time taken =  0.010157
# Adding flow packages to  PO  ...
# Time taken =  0.772667
# Writing simulation and gwf for  PO  ...
# PO
# WARNING: Unable to resolve dimension of ('gwf6', 'disu', 'cell2d', 'cell2d', 'icvert') based on shape "ncvert".
# Running simulation for  PO  ...
# WARNING: 2024-07-08 10:48:24,488: geological_model.py:609 -- deprecated method. Model data can now be set using the data attribute
# Period =  Steady
# Model success =  True
# run_time =  14.213979
# {'upper': 0, 'upper_unconformity': 1, 'lower': 2}
# Creating lithology and discretisation arrays for  PO  ...
# C:\Users\19904604\Anaconda3\envs\loop3denvu\lib\site-packages\LoopStructural\modelling\core\geological_model.py:647: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = cm.get_cmap(cmap, n_units)
# Time taken =  1.818035
# Creating property arrays for  PO  ...
# Time taken =  0.010311
# Adding flow packages to  PO  ...
# Time taken =  0.690673
# Writing simulation and gwf for  PO  ...
# PO
# WARNING: Unable to resolve dimension of ('gwf6', 'disu', 'cell2d', 'cell2d', 'icvert') based on shape "ncvert".
# Running simulation for  PO  ...
# WARNING: 2024-07-08 10:48:44,243: geological_model.py:609 -- deprecated method. Model data can now be set using the data attribute
# Period =  Steady
# Model success =  True
# run_time =  17.197489
# {'upper': 0, 'upper_unconformity': 1, 'lower': 2}
# Creating lithology and discretisation arrays for  PO  ...
# C:\Users\19904604\Anaconda3\envs\loop3denvu\lib\site-packages\LoopStructural\modelling\core\geological_model.py:647: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = cm.get_cmap(cmap, n_units)
# Time taken =  1.803216
# Creating property arrays for  PO  ...
# Time taken =  0.010077
# Adding flow packages to  PO  ...
# Time taken =  0.771868
# Writing simulation and gwf for  PO  ...
# PO
# WARNING: Unable to resolve dimension of ('gwf6', 'disu', 'cell2d', 'cell2d', 'icvert') based on shape "ncvert".
# Running simulation for  PO  ...
# WARNING: 2024-07-08 10:49:03,752: geological_model.py:609 -- deprecated method. Model data can now be set using the data attribute
# Period =  Steady
# Model success =  True
# run_time =  16.881103
# {'upper': 0, 'upper_unconformity': 1, 'lower': 2}
# Creating lithology and discretisation arrays for  PO  ...
# C:\Users\19904604\Anaconda3\envs\loop3denvu\lib\site-packages\LoopStructural\modelling\core\geological_model.py:647: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = cm.get_cmap(cmap, n_units)
# Time taken =  1.793258
# Creating property arrays for  PO  ...
# Time taken =  0.010096
# Adding flow packages to  PO  ...
# Time taken =  0.632104
# Writing simulation and gwf for  PO  ...
# PO
# WARNING: Unable to resolve dimension of ('gwf6', 'disu', 'cell2d', 'cell2d', 'icvert') based on shape "ncvert".
# Running simulation for  PO  ...
# WARNING: 2024-07-08 10:49:24,407: geological_model.py:609 -- deprecated method. Model data can now be set using the data attribute
# Period =  Steady
# Model success =  True
# run_time =  18.189462
# {'upper': 0, 'upper_unconformity': 1, 'lower': 2}
# Creating lithology and discretisation arrays for  PO  ...
# C:\Users\19904604\Anaconda3\envs\loop3denvu\lib\site-packages\LoopStructural\modelling\core\geological_model.py:647: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = cm.get_cmap(cmap, n_units)
# Time taken =  1.930984
# Creating property arrays for  PO  ...
# Time taken =  0.015675
# Adding flow packages to  PO  ...
# Time taken =  0.648692
# Writing simulation and gwf for  PO  ...
# PO
# WARNING: Unable to resolve dimension of ('gwf6', 'disu', 'cell2d', 'cell2d', 'icvert') based on shape "ncvert".
# Running simulation for  PO  ...
# WARNING: 2024-07-08 10:49:41,118: geological_model.py:609 -- deprecated method. Model data can now be set using the data attribute
# Period =  Steady
# Model success =  True
# run_time =  14.081072
# {'upper': 0, 'upper_unconformity': 1, 'lower': 2}
# Creating lithology and discretisation arrays for  PO  ...
# C:\Users\19904604\Anaconda3\envs\loop3denvu\lib\site-packages\LoopStructural\modelling\core\geological_model.py:647: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = cm.get_cmap(cmap, n_units)
# Time taken =  1.77647
# Creating property arrays for  PO  ...
# Time taken =  0.002097
# Adding flow packages to  PO  ...
# Time taken =  0.642066
# Writing simulation and gwf for  PO  ...
# PO
# WARNING: Unable to resolve dimension of ('gwf6', 'disu', 'cell2d', 'cell2d', 'icvert') based on shape "ncvert".
# Running simulation for  PO  ...
# WARNING: 2024-07-08 10:49:59,764: geological_model.py:609 -- deprecated method. Model data can now be set using the data attribute
# Period =  Steady
# Model success =  True
# run_time =  16.170807
# {'upper': 0, 'upper_unconformity': 1, 'lower': 2}
# Creating lithology and discretisation arrays for  PO  ...
# C:\Users\19904604\Anaconda3\envs\loop3denvu\lib\site-packages\LoopStructural\modelling\core\geological_model.py:647: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = cm.get_cmap(cmap, n_units)
# Time taken =  2.122281
# Creating property arrays for  PO  ...
# Time taken =  0.0
# Adding flow packages to  PO  ...
# Time taken =  0.665701
# Writing simulation and gwf for  PO  ...
# PO
# WARNING: Unable to resolve dimension of ('gwf6', 'disu', 'cell2d', 'cell2d', 'icvert') based on shape "ncvert".
# Running simulation for  PO  ...
# WARNING: 2024-07-08 10:50:21,336: geological_model.py:609 -- deprecated method. Model data can now be set using the data attribute
# Period =  Steady
# Model success =  True
# run_time =  18.746091
# {'upper': 0, 'upper_unconformity': 1, 'lower': 2}
# Creating lithology and discretisation arrays for  PO  ...
# C:\Users\19904604\Anaconda3\envs\loop3denvu\lib\site-packages\LoopStructural\modelling\core\geological_model.py:647: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = cm.get_cmap(cmap, n_units)
# Time taken =  2.149109
# Creating property arrays for  PO  ...
# Time taken =  0.002068
# Adding flow packages to  PO  ...
# Time taken =  0.958821
# Writing simulation and gwf for  PO  ...
# PO
# WARNING: Unable to resolve dimension of ('gwf6', 'disu', 'cell2d', 'cell2d', 'icvert') based on shape "ncvert".
# Running simulation for  PO  ...
# WARNING: 2024-07-08 10:50:44,182: geological_model.py:609 -- deprecated method. Model data can now be set using the data attribute
# Period =  Steady
# Model success =  True
# run_time =  19.696353
# {'upper': 0, 'upper_unconformity': 1, 'lower': 2}
# Creating lithology and discretisation arrays for  PO  ...
# C:\Users\19904604\Anaconda3\envs\loop3denvu\lib\site-packages\LoopStructural\modelling\core\geological_model.py:647: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = cm.get_cmap(cmap, n_units)
# Time taken =  1.91433
# Creating property arrays for  PO  ...
# Time taken =  0.008099
# Adding flow packages to  PO  ...
# Time taken =  0.642154
# Writing simulation and gwf for  PO  ...
# PO
# WARNING: Unable to resolve dimension of ('gwf6', 'disu', 'cell2d', 'cell2d', 'icvert') based on shape "ncvert".
# Running simulation for  PO  ...
# WARNING: 2024-07-08 10:51:05,382: geological_model.py:609 -- deprecated method. Model data can now be set using the data attribute
# Period =  Steady
# Model success =  True
# run_time =  18.601848
# {'upper': 0, 'upper_unconformity': 1, 'lower': 2}
# Creating lithology and discretisation arrays for  PO  ...
# C:\Users\19904604\Anaconda3\envs\loop3denvu\lib\site-packages\LoopStructural\modelling\core\geological_model.py:647: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = cm.get_cmap(cmap, n_units)
# Time taken =  1.938183
# Creating property arrays for  PO  ...
# Time taken =  0.00815
# Adding flow packages to  PO  ...
# Time taken =  0.64153
# Writing simulation and gwf for  PO  ...
# PO
# WARNING: Unable to resolve dimension of ('gwf6', 'disu', 'cell2d', 'cell2d', 'icvert') based on shape "ncvert".
# Running simulation for  PO  ...
# WARNING: 2024-07-08 10:51:22,855: geological_model.py:609 -- deprecated method. Model data can now be set using the data attribute
# Period =  Steady
# Model success =  True
# ...
# Period =  Steady
# Model success =  True
# run_time =  16.245849
# {'upper': 0, 'upper_unconformity': 1, 'lower': 2}
# Creating lithology and discretisation arrays for  PO  ...
# C:\Users\19904604\Anaconda3\envs\loop3denvu\lib\site-packages\LoopStructural\modelling\core\geological_model.py:647: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = cm.get_cmap(cmap, n_units)
# Time taken =  1.826075
# Creating property arrays for  PO  ...
# Time taken =  0.010244
# Adding flow packages to  PO  ...
# Time taken =  0.650713
# Writing simulation and gwf for  PO  ...
# PO
# WARNING: Unable to resolve dimension of ('gwf6', 'disu', 'cell2d', 'cell2d', 'icvert') based on shape "ncvert".
# Running simulation for  PO  ...
# WARNING: 2024-07-08 11:08:19,151: geological_model.py:609 -- deprecated method. Model data can now be set using the data attribute
# Period =  Steady
# Model success =  True
# run_time =  14.711257
# {'upper': 0, 'upper_unconformity': 1, 'lower': 2}
# Creating lithology and discretisation arrays for  PO  ...
# C:\Users\19904604\Anaconda3\envs\loop3denvu\lib\site-packages\LoopStructural\modelling\core\geological_model.py:647: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = cm.get_cmap(cmap, n_units)
# Time taken =  1.827515
# Creating property arrays for  PO  ...
# Time taken =  0.008125
# Adding flow packages to  PO  ...
# Time taken =  0.650975
# Writing simulation and gwf for  PO  ...
# PO
# WARNING: Unable to resolve dimension of ('gwf6', 'disu', 'cell2d', 'cell2d', 'icvert') based on shape "ncvert".
# Running simulation for  PO  ...
# WARNING: 2024-07-08 11:08:34,323: geological_model.py:609 -- deprecated method. Model data can now be set using the data attribute
# Period =  Steady
# Model success =  True
# run_time =  12.667685
# {'upper': 0, 'upper_unconformity': 1, 'lower': 2}
# Creating lithology and discretisation arrays for  PO  ...
# C:\Users\19904604\Anaconda3\envs\loop3denvu\lib\site-packages\LoopStructural\modelling\core\geological_model.py:647: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = cm.get_cmap(cmap, n_units)
# Time taken =  1.890523
# Creating property arrays for  PO  ...
# Time taken =  0.002092
# Adding flow packages to  PO  ...
# Time taken =  0.671778
# Writing simulation and gwf for  PO  ...
# PO
# WARNING: Unable to resolve dimension of ('gwf6', 'disu', 'cell2d', 'cell2d', 'icvert') based on shape "ncvert".
# Running simulation for  PO  ...
# WARNING: 2024-07-08 11:08:51,571: geological_model.py:609 -- deprecated method. Model data can now be set using the data attribute
# Period =  Steady
# Model success =  True
# run_time =  14.65171
# {'upper': 0, 'upper_unconformity': 1, 'lower': 2}
# Creating lithology and discretisation arrays for  PO  ...
# C:\Users\19904604\Anaconda3\envs\loop3denvu\lib\site-packages\LoopStructural\modelling\core\geological_model.py:647: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = cm.get_cmap(cmap, n_units)
# Time taken =  2.027985
# Creating property arrays for  PO  ...
# Time taken =  0.0
# Adding flow packages to  PO  ...
# Time taken =  0.657903
# Writing simulation and gwf for  PO  ...
# PO
# WARNING: Unable to resolve dimension of ('gwf6', 'disu', 'cell2d', 'cell2d', 'icvert') based on shape "ncvert".
# Running simulation for  PO  ...
# WARNING: 2024-07-08 11:09:09,999: geological_model.py:609 -- deprecated method. Model data can now be set using the data attribute
# Period =  Steady
# Model success =  True
# run_time =  15.714551
# {'upper': 0, 'upper_unconformity': 1, 'lower': 2}
# Creating lithology and discretisation arrays for  PO  ...
# C:\Users\19904604\Anaconda3\envs\loop3denvu\lib\site-packages\LoopStructural\modelling\core\geological_model.py:647: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = cm.get_cmap(cmap, n_units)
# Time taken =  1.935793
# Creating property arrays for  PO  ...
# Time taken =  0.002226
# Adding flow packages to  PO  ...
# Time taken =  0.641168
# Writing simulation and gwf for  PO  ...
# PO
# WARNING: Unable to resolve dimension of ('gwf6', 'disu', 'cell2d', 'cell2d', 'icvert') based on shape "ncvert".
# Running simulation for  PO  ...
# WARNING: 2024-07-08 11:09:27,388: geological_model.py:609 -- deprecated method. Model data can now be set using the data attribute
# Period =  Steady
# Model success =  True
# run_time =  14.76866
# {'upper': 0, 'upper_unconformity': 1, 'lower': 2}
# Creating lithology and discretisation arrays for  PO  ...
# C:\Users\19904604\Anaconda3\envs\loop3denvu\lib\site-packages\LoopStructural\modelling\core\geological_model.py:647: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = cm.get_cmap(cmap, n_units)
# Time taken =  1.793946
# Creating property arrays for  PO  ...
# Time taken =  0.010105
# Adding flow packages to  PO  ...
# Time taken =  0.650928
# Writing simulation and gwf for  PO  ...
# PO
# WARNING: Unable to resolve dimension of ('gwf6', 'disu', 'cell2d', 'cell2d', 'icvert') based on shape "ncvert".
# Running simulation for  PO  ...
# WARNING: 2024-07-08 11:09:43,856: geological_model.py:609 -- deprecated method. Model data can now be set using the data attribute
# Period =  Steady
# Model success =  True
# run_time =  13.979332
# {'upper': 0, 'upper_unconformity': 1, 'lower': 2}
# Creating lithology and discretisation arrays for  PO  ...
# C:\Users\19904604\Anaconda3\envs\loop3denvu\lib\site-packages\LoopStructural\modelling\core\geological_model.py:647: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = cm.get_cmap(cmap, n_units)
# Time taken =  1.878697
# Creating property arrays for  PO  ...
# Time taken =  0.010131
# Adding flow packages to  PO  ...
# Time taken =  0.648584
# Writing simulation and gwf for  PO  ...
# PO
# WARNING: Unable to resolve dimension of ('gwf6', 'disu', 'cell2d', 'cell2d', 'icvert') based on shape "ncvert".
# Running simulation for  PO  ...
# WARNING: 2024-07-08 11:10:45,968: geological_model.py:609 -- deprecated method. Model data can now be set using the data attribute
# Period =  Steady
# Model success =  True
# run_time =  59.549435
# {'upper': 0, 'upper_unconformity': 1, 'lower': 2}
# Creating lithology and discretisation arrays for  PO  ...
# C:\Users\19904604\Anaconda3\envs\loop3denvu\lib\site-packages\LoopStructural\modelling\core\geological_model.py:647: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = cm.get_cmap(cmap, n_units)
# Time taken =  1.830159
# Creating property arrays for  PO  ...
# Time taken =  0.008079
# Adding flow packages to  PO  ...
# Time taken =  0.802801
# Writing simulation and gwf for  PO  ...
# PO
# WARNING: Unable to resolve dimension of ('gwf6', 'disu', 'cell2d', 'cell2d', 'icvert') based on shape "ncvert".
# Running simulation for  PO  ...
# WARNING: 2024-07-08 11:11:51,610: geological_model.py:609 -- deprecated method. Model data can now be set using the data attribute
# Period =  Steady
# Model success =  True
# run_time =  62.962716
# {'upper': 0, 'upper_unconformity': 1, 'lower': 2}
# Creating lithology and discretisation arrays for  PO  ...
# C:\Users\19904604\Anaconda3\envs\loop3denvu\lib\site-packages\LoopStructural\modelling\core\geological_model.py:647: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = cm.get_cmap(cmap, n_units)
# Time taken =  1.795749
# Creating property arrays for  PO  ...
# Time taken =  0.008061
# Adding flow packages to  PO  ...
# Time taken =  0.782136
# Writing simulation and gwf for  PO  ...
# PO
# WARNING: Unable to resolve dimension of ('gwf6', 'disu', 'cell2d', 'cell2d', 'icvert') based on shape "ncvert".
# Running simulation for  PO  ...
# WARNING: 2024-07-08 11:12:58,112: geological_model.py:609 -- deprecated method. Model data can now be set using the data attribute
# Period =  Steady
# Model success =  True
# run_time =  63.87583
# {'upper': 0, 'upper_unconformity': 1, 'lower': 2}
# Creating lithology and discretisation arrays for  PO  ...
# C:\Users\19904604\Anaconda3\envs\loop3denvu\lib\site-packages\LoopStructural\modelling\core\geological_model.py:647: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = cm.get_cmap(cmap, n_units)
# Time taken =  2.008455
# Creating property arrays for  PO  ...
# Time taken =  0.002063
# Adding flow packages to  PO  ...
# Time taken =  0.669813
# Writing simulation and gwf for  PO  ...
# PO
# WARNING: Unable to resolve dimension of ('gwf6', 'disu', 'cell2d', 'cell2d', 'icvert') based on shape "ncvert".
# Running simulation for  PO  ...
# WARNING: 2024-07-08 11:13:17,444: geological_model.py:609 -- deprecated method. Model data can now be set using the data attribute
# Period =  Steady
# Model success =  True
# run_time =  16.609852
# {'upper': 0, 'upper_unconformity': 1, 'lower': 2}
# Creating lithology and discretisation arrays for  PO  ...
# C:\Users\19904604\Anaconda3\envs\loop3denvu\lib\site-packages\LoopStructural\modelling\core\geological_model.py:647: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = cm.get_cmap(cmap, n_units)
# Time taken =  1.836464
# Creating property arrays for  PO  ...
# Time taken =  0.0
# Adding flow packages to  PO  ...
# Time taken =  0.802579
# Writing simulation and gwf for  PO  ...
# PO
# WARNING: Unable to resolve dimension of ('gwf6', 'disu', 'cell2d', 'cell2d', 'icvert') based on shape "ncvert".
# Running simulation for  PO  ...
# WARNING: 2024-07-08 11:13:36,469: geological_model.py:609 -- deprecated method. Model data can now be set using the data attribute
# Period =  Steady
# Model success =  True
# run_time =  16.347729
# {'upper': 0, 'upper_unconformity': 1, 'lower': 2}
# Creating lithology and discretisation arrays for  PO  ...
# C:\Users\19904604\Anaconda3\envs\loop3denvu\lib\site-packages\LoopStructural\modelling\core\geological_model.py:647: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = cm.get_cmap(cmap, n_units)
# Time taken =  1.947811
# Creating property arrays for  PO  ...
# Time taken =  0.010114
# Adding flow packages to  PO  ...
# Time taken =  0.671831
# Writing simulation and gwf for  PO  ...
# PO
# WARNING: Unable to resolve dimension of ('gwf6', 'disu', 'cell2d', 'cell2d', 'icvert') based on shape "ncvert".
# Running simulation for  PO  ...
# WARNING: 2024-07-08 11:14:28,351: geological_model.py:609 -- deprecated method. Model data can now be set using the data attribute
# Period =  Steady
# Model success =  True
# run_time =  49.215815
# {'upper': 0, 'upper_unconformity': 1, 'lower': 2}
# Creating lithology and discretisation arrays for  PO  ...
# C:\Users\19904604\Anaconda3\envs\loop3denvu\lib\site-packages\LoopStructural\modelling\core\geological_model.py:647: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = cm.get_cmap(cmap, n_units)
# Time taken =  1.795854
# Creating property arrays for  PO  ...
# Time taken =  0.002097
# Adding flow packages to  PO  ...
# Time taken =  0.652198
# Writing simulation and gwf for  PO  ...
# PO
# WARNING: Unable to resolve dimension of ('gwf6', 'disu', 'cell2d', 'cell2d', 'icvert') based on shape "ncvert".
# Running simulation for  PO  ...
# WARNING: 2024-07-08 11:14:46,872: geological_model.py:609 -- deprecated method. Model data can now be set using the data attribute
# Period =  Steady
# Model success =  True
# run_time =  16.025034
# {'upper': 0, 'upper_unconformity': 1, 'lower': 2}
# Creating lithology and discretisation arrays for  PO  ...
# C:\Users\19904604\Anaconda3\envs\loop3denvu\lib\site-packages\LoopStructural\modelling\core\geological_model.py:647: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = cm.get_cmap(cmap, n_units)
# Time taken =  1.843577
# Creating property arrays for  PO  ...
# Time taken =  0.015645
# Adding flow packages to  PO  ...
# Time taken =  0.66445
# Writing simulation and gwf for  PO  ...
# PO
# WARNING: Unable to resolve dimension of ('gwf6', 'disu', 'cell2d', 'cell2d', 'icvert') based on shape "ncvert".
# Running simulation for  PO  ...
# WARNING: 2024-07-08 11:15:02,618: geological_model.py:609 -- deprecated method. Model data can now be set using the data attribute
# Period =  Steady
# Model success =  True
# run_time =  13.18489
# {'upper': 0, 'upper_unconformity': 1, 'lower': 2}
# Creating lithology and discretisation arrays for  PO  ...
# C:\Users\19904604\Anaconda3\envs\loop3denvu\lib\site-packages\LoopStructural\modelling\core\geological_model.py:647: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = cm.get_cmap(cmap, n_units)
# Time taken =  1.810226
# Creating property arrays for  PO  ...
# Time taken =  0.0
# Adding flow packages to  PO  ...
# Time taken =  0.671815
# Writing simulation and gwf for  PO  ...
# PO
# WARNING: Unable to resolve dimension of ('gwf6', 'disu', 'cell2d', 'cell2d', 'icvert') based on shape "ncvert".
# Running simulation for  PO  ...
# WARNING: 2024-07-08 11:15:16,947: geological_model.py:609 -- deprecated method. Model data can now be set using the data attribute
# Period =  Steady
# Model success =  True
# run_time =  11.812087
# {'upper': 0, 'upper_unconformity': 1, 'lower': 2}
# Creating lithology and discretisation arrays for  PO  ...
# C:\Users\19904604\Anaconda3\envs\loop3denvu\lib\site-packages\LoopStructural\modelling\core\geological_model.py:647: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = cm.get_cmap(cmap, n_units)
# Time taken =  1.771483
# Creating property arrays for  PO  ...
# Time taken =  0.010112
# Adding flow packages to  PO  ...
# Time taken =  0.791481
# Writing simulation and gwf for  PO  ...
# PO
# WARNING: Unable to resolve dimension of ('gwf6', 'disu', 'cell2d', 'cell2d', 'icvert') based on shape "ncvert".
# Running simulation for  PO  ...
# Period =  Steady
# Model success =  True
# run_time =  10.844337

# %%
layer = 2

stacked = []
for n in range(100):
    heads_disv = -1e30 * np.ones_like(M.idomain, dtype=float) 
    for i, h in enumerate(heads_PO[n][0][0]):
        if math.isnan(h) == False: 
            heads_disv[M.cellid_disu==i] = h        
    stacked.append(heads_disv[layer])
var_PO = np.var(np.array(stacked), axis = 0)

# %% [markdown]
# ### Fault - 100 realisations

# %%
P.cell2dvor, P.xcycvor, P.verticesvor, P.vor, vornodes = createcell2d(P, grid = 'vor', fault = True)  
P.hk = [1, 2, 0.01, 5] 
P.vk = [i/10 for i in P.hk]

options = np.linspace(0, 320, 2) # Fault displacement

data = pd.read_excel("../data/loop_showcase_data.xls",sheet_name = "fault_example")
strat = pd.read_excel("../data/loop_showcase_data.xls",sheet_name = "strat")

P.control_points = ([])
P.fault_max_disp = 100.    # Was 200
P.minor_axis = 1000        # Fault_influence - orthogonal to fault
P.fault_center = [P.fx1 + (P.fx2 - P.fx1)/2, P.fy1 + (P.fy2 - P.fy1)/2, -400]
P.fault_slip_vector=[0,0,1]
        
heads_FD = []
for i in range(len(options)):

    N = Model('FD', P, plan = 'vor', transect = 'con') # Create flow model  
    P.fault_max_disp = options[i] /2
    P.data, P.strat = prepare_geomodel_loopshowcase(P, data, strat, include_fault = True)   # Prepare geomodel inputs
    P.geomodel = create_geomodel_loopshowcase(P, include_fault = True) # Make geomodel
    N.create_lith_dis_arrays(P)                                 # Create lith and dis arrays
    N.create_prop_arrays(P)                                     # Create K arrays
    N.create_flow_package_arrays(P)                             # Create flow packages
    N.gwf, N.head_ss, N.obs_ss, N.runtime_ss = N.write_run_model(P, period = 'Steady', ic_array = P.strt)   
    heads_FD.append(N.head_ss)
# Out:
# WARNING: 2024-07-08 11:15:35,669: geological_model.py:609 -- deprecated method. Model data can now be set using the data attribute
# WARNING: 2024-07-08 11:15:35,700: geological_model.py:1359 -- Fault displacement is 0
# WARNING: 2024-07-08 11:15:35,722: _fault_builder.py:208 -- There is no slip vector data for the fault, using vertical slip vector
#                           projected onto fault surface estimating from fault normal
# WARNING: 2024-07-08 11:15:35,722: _fault_builder.py:239 -- Fault major axis using map length: 3640.0549446402592
# C:\Users\19904604\Anaconda3\envs\loop3denvu\lib\site-packages\LoopStructural\modelling\core\geological_model.py:647: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = cm.get_cmap(cmap, n_units)
# Fault included!
# {'upper': 0, 'upper_unconformity': 1, 'Fault': 2, 'lower': 3}
# Creating lithology and discretisation arrays for  FD  ...
# Time taken =  2.28873
# Creating property arrays for  FD  ...
# Time taken =  0.0101
# Adding flow packages to  FD  ...
# Time taken =  0.833077
# Writing simulation and gwf for  FD  ...
# FD
# WARNING: Unable to resolve dimension of ('gwf6', 'disu', 'cell2d', 'cell2d', 'icvert') based on shape "ncvert".
# Running simulation for  FD  ...
# WARNING: 2024-07-08 11:16:06,980: geological_model.py:609 -- deprecated method. Model data can now be set using the data attribute
# WARNING: 2024-07-08 11:16:07,010: _fault_builder.py:208 -- There is no slip vector data for the fault, using vertical slip vector
#                           projected onto fault surface estimating from fault normal
# WARNING: 2024-07-08 11:16:07,010: _fault_builder.py:239 -- Fault major axis using map length: 3640.0549446402592
# Period =  Steady
# Model success =  True
# run_time =  27.998898
# Fault included!
# {'upper': 0, 'upper_unconformity': 1, 'Fault': 2, 'lower': 3}
# Creating lithology and discretisation arrays for  FD  ...
# C:\Users\19904604\Anaconda3\envs\loop3denvu\lib\site-packages\LoopStructural\modelling\core\geological_model.py:647: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = cm.get_cmap(cmap, n_units)
# Time taken =  22.144226
# Creating property arrays for  FD  ...
# Time taken =  0.010114
# Adding flow packages to  FD  ...
# Time taken =  0.823021
# Writing simulation and gwf for  FD  ...
# FD
# WARNING: Unable to resolve dimension of ('gwf6', 'disu', 'cell2d', 'cell2d', 'icvert') based on shape "ncvert".
# Running simulation for  FD  ...
# Period =  Steady
# Model success =  True
# run_time =  32.843444

# %%
len(heads_FD[0][0][0])
# Out:
# 13152

# %%
# FAULT
stacked = []
for n in range(2):
    heads_disv = -1e30 * np.ones_like(N.idomain, dtype=float) 
    for i, h in enumerate(heads_FD[n][0][0]):
        if math.isnan(h) == False: 
            heads_disv[N.cellid_disu==i] = h        
    stacked.append(heads_disv[layer])
var_FD = np.var(np.array(stacked), axis = 0)

# %%
help(flopy.plot.PlotMapView)
# Out:
# Help on class PlotMapView in module flopy.plot.map:
#
# class PlotMapView(builtins.object)
#  |  PlotMapView(model=None, modelgrid=None, ax=None, layer=0, extent=None)
#  |
#  |  Class to create a map of the model. Delegates plotting
#  |  functionality based on model grid type.
#  |
#  |  Parameters
#  |  ----------
#  |  modelgrid : flopy.discretization.Grid
#  |      The modelgrid class can be StructuredGrid, VertexGrid,
#  |      or UnstructuredGrid (Default is None)
#  |  ax : matplotlib.pyplot axis
#  |      The plot axis.  If not provided it, plt.gca() will be used.
#  |      If there is not a current axis then a new one will be created.
#  |  model : flopy.modflow object
#  |      flopy model object. (Default is None)
#  |  layer : int
#  |      Layer to plot.  Default is 0.  Must be between 0 and nlay - 1.
#  |  extent : tuple of floats
#  |      (xmin, xmax, ymin, ymax) will be used to specify axes limits.  If None
#  |      then these will be calculated based on grid, coordinates, and rotation.
#  |
#  |  Notes
#  |  -----
#  |
#  |  Methods defined here:
#  |
#  |  __init__(self, model=None, modelgrid=None, ax=None, layer=0, extent=None)
#  |      Initialize self.  See help(type(self)) for accurate signature.
#  |
#  |  contour_array(self, a, masked_values=None, **kwargs)
#  |      Contour an array.  If the array is three-dimensional, then the method
#  |      will contour the layer tied to this class (self.layer).
#  |
#  |      Parameters
#  |      ----------
#  |      a : numpy.ndarray
#  |          Array to plot.
#  |      masked_values : iterable of floats, ints
#  |          Values to mask.
#  |      **kwargs : dictionary
#  |          keyword arguments passed to matplotlib.pyplot.pcolormesh
#  |
#  |      Returns
#  |      -------
#  |      contour_set : matplotlib.pyplot.contour
#  |
#  |  plot_array(self, a, masked_values=None, **kwargs)
#  |      Plot an array.  If the array is three-dimensional, then the method
#  |      will plot the layer tied to this class (self.layer).
#  |
#  |      Parameters
#  |      ----------
#  |      a : numpy.ndarray
#  |          Array to plot.
#  |      masked_values : iterable of floats, ints
#  |          Values to mask.
#  |      **kwargs : dictionary
#  |          keyword arguments passed to matplotlib.pyplot.pcolormesh
#  |
#  |      Returns
#  |      -------
#  |      quadmesh : matplotlib.collections.QuadMesh or
#  |          matplotlib.collections.PatchCollection
#  |
#  |  plot_bc(self, name=None, package=None, kper=0, color=None, plotAll=False, **kwargs)
#  |      Plot boundary conditions locations for a specific boundary
#  |      type from a flopy model
#  |
#  |      Parameters
#  |      ----------
#  |      name : string
#  |          Package name string ('WEL', 'GHB', etc.). (Default is None)
#  |      package : flopy.modflow.Modflow package class instance
#  |          flopy package class instance. (Default is None)
#  |      kper : int
#  |          Stress period to plot
#  |      color : string
#  |          matplotlib color string. (Default is None)
#  |      plotAll : bool
#  |          Boolean used to specify that boundary condition locations for all
#  |          layers will be plotted on the current ModelMap layer.
#  |          (Default is False)
#  |      **kwargs : dictionary
#  |          keyword arguments passed to matplotlib.collections.PatchCollection
#  |
#  |      Returns
#  |      -------
#  |      quadmesh : matplotlib.collections.QuadMesh
#  |
#  |  plot_endpoint(self, ep, direction='ending', selection=None, selection_direction=None, **kwargs)
#  |      Plot the MODPATH endpoints.
#  |
#  |      Parameters
#  |      ----------
#  |      ep : rec array
#  |          A numpy recarray with the endpoint particle data from the
#  |          MODPATH 6 endpoint file
#  |      direction : str
#  |          String defining if starting or ending particle locations should be
#  |          considered. (default is 'ending')
#  |      selection : tuple
#  |          tuple that defines the zero-base layer, row, column location
#  |          (l, r, c) to use to make a selection of particle endpoints.
#  |          The selection could be a well location to determine capture zone
#  |          for the well. If selection is None, all particle endpoints for
#  |          the user-sepcified direction will be plotted. (default is None)
#  |      selection_direction : str
#  |          String defining is a selection should be made on starting or
#  |          ending particle locations. If selection is not None and
#  |          selection_direction is None, the selection direction will be set
#  |          to the opposite of direction. (default is None)
#  |
#  |      kwargs : ax, c, s or size, colorbar, colorbar_label, shrink. The
#  |          remaining kwargs are passed into the matplotlib scatter
#  |          method. If colorbar is True a colorbar will be added to the plot.
#  |          If colorbar_label is passed in and colorbar is True then
#  |          colorbar_label will be passed to the colorbar set_label()
#  |          method. If shrink is passed in and colorbar is True then
#  |          the colorbar size will be set using shrink.
#  |
#  |      Returns
#  |      -------
#  |      sp : matplotlib.pyplot.scatter
#  |
#  |  plot_grid(self, **kwargs)
#  |      Plot the grid lines.
#  |
#  |      Parameters
#  |      ----------
#  |      kwargs : ax, colors.  The remaining kwargs are passed into the
#  |          the LineCollection constructor.
#  |
#  |      Returns
#  |      -------
#  |      lc : matplotlib.collections.LineCollection
#  |
#  |  plot_ibound(self, ibound=None, color_noflow='black', color_ch='blue', color_vpt='red', **kwargs)
#  |      Make a plot of ibound.  If not specified, then pull ibound from the
#  |      self.ml
#  |
#  |      Parameters
#  |      ----------
#  |      ibound : numpy.ndarray
#  |          ibound array to plot.  (Default is ibound in the modelgrid)
#  |      color_noflow : string
#  |          (Default is 'black')
#  |      color_ch : string
#  |          Color for constant heads (Default is 'blue'.)
#  |      color_vpt: string
#  |          Color for vertical pass through cells (Default is 'red')
#  |
#  |      Returns
#  |      -------
#  |      quadmesh : matplotlib.collections.QuadMesh
#  |
#  |  plot_inactive(self, ibound=None, color_noflow='black', **kwargs)
#  |      Make a plot of inactive cells.  If not specified, then pull ibound
#  |      from the self.ml
#  |
#  |      Parameters
#  |      ----------
#  |      ibound : numpy.ndarray
#  |          ibound array to plot.  (Default is ibound in 'BAS6' package.)
#  |
#  |      color_noflow : string
#  |          (Default is 'black')
#  |
#  |      Returns
#  |      -------
#  |      quadmesh : matplotlib.collections.QuadMesh
#  |
#  |  plot_pathline(self, pl, travel_time=None, **kwargs)
#  |      Plot the MODPATH pathlines.
#  |
#  |      Parameters
#  |      ----------
#  |      pl : list of rec arrays or a single rec array
#  |          rec array or list of rec arrays is data returned from
#  |          modpathfile PathlineFile get_data() or get_alldata()
#  |          methods. Data in rec array is 'x', 'y', 'z', 'time',
#  |          'k', and 'particleid'.
#  |      travel_time : float or str
#  |          travel_time is a travel time selection for the displayed
#  |          pathlines. If a float is passed then pathlines with times
#  |          less than or equal to the passed time are plotted. If a
#  |          string is passed a variety logical constraints can be added
#  |          in front of a time value to select pathlines for a select
#  |          period of time. Valid logical constraints are <=, <, >=, and
#  |          >. For example, to select all pathlines less than 10000 days
#  |          travel_time='< 10000' would be passed to plot_pathline.
#  |          (default is None)
#  |      kwargs : layer, ax, colors.  The remaining kwargs are passed
#  |          into the LineCollection constructor. If layer='all',
#  |          pathlines are output for all layers
#  |
#  |      Returns
#  |      -------
#  |      lc : matplotlib.collections.LineCollection
#  |
#  |  plot_shapefile(self, shp, **kwargs)
#  |      Plot a shapefile.  The shapefile must be in the same coordinates as
#  |      the rotated and offset grid.
#  |
#  |      Parameters
#  |      ----------
#  |      shp : string or pyshp shapefile object
#  |          Name of the shapefile to plot
#  |
#  |      kwargs : dictionary
#  |          Keyword arguments passed to plotutil.plot_shapefile()
#  |
#  |  plot_shapes(self, obj, **kwargs)
#  |      Plot shapes is a method that facilitates plotting a collection
#  |      of geospatial objects
#  |
#  |      Parameters
#  |      ----------
#  |      obj : collection object
#  |          obj can accept the following types
#  |
#  |          str : shapefile name
#  |          shapefile.Reader object
#  |          list of [shapefile.Shape, shapefile.Shape,]
#  |          shapefile.Shapes object
#  |          flopy.utils.geometry.Collection object
#  |          list of [flopy.utils.geometry, ...] objects
#  |          geojson.GeometryCollection object
#  |          geojson.FeatureCollection object
#  |          shapely.GeometryCollection object
#  |          list of [[vertices], ...]
#  |      kwargs : dictionary
#  |          keyword arguments passed to plotutil.plot_shapefile()
#  |
#  |      Returns
#  |      -------
#  |          matplotlib.Collection object
#  |
#  |  plot_timeseries(self, ts, travel_time=None, **kwargs)
#  |      Plot the MODPATH timeseries.
#  |
#  |      Parameters
#  |      ----------
#  |      ts : list of rec arrays or a single rec array
#  |          rec array or list of rec arrays is data returned from
#  |          modpathfile TimeseriesFile get_data() or get_alldata()
#  |          methods. Data in rec array is 'x', 'y', 'z', 'time',
#  |          'k', and 'particleid'.
#  |      travel_time : float or str
#  |          travel_time is a travel time selection for the displayed
#  |          pathlines. If a float is passed then pathlines with times
#  |          less than or equal to the passed time are plotted. If a
#  |          string is passed a variety logical constraints can be added
#  |          in front of a time value to select pathlines for a select
#  |          period of time. Valid logical constraints are <=, <, >=, and
#  |          >. For example, to select all pathlines less than 10000 days
#  |          travel_time='< 10000' would be passed to plot_pathline.
#  |          (default is None)
#  |      kwargs : layer, ax, colors.  The remaining kwargs are passed
#  |          into the LineCollection constructor. If layer='all',
#  |          pathlines are output for all layers
#  |
#  |      Returns
#  |      -------
#  |          lo : list of Line2D objects
#  |
#  |  plot_vector(self, vx, vy, istep=1, jstep=1, normalize=False, masked_values=None, **kwargs)
#  |      Plot a vector.
#  |
#  |      Parameters
#  |      ----------
#  |      vx : np.ndarray
#  |          x component of the vector to be plotted (non-rotated)
#  |          array shape must be (nlay, nrow, ncol) for a structured grid
#  |          array shape must be (nlay, ncpl) for a unstructured grid
#  |      vy : np.ndarray
#  |          y component of the vector to be plotted (non-rotated)
#  |          array shape must be (nlay, nrow, ncol) for a structured grid
#  |          array shape must be (nlay, ncpl) for a unstructured grid
#  |      istep : int
#  |          row frequency to plot (default is 1)
#  |      jstep : int
#  |          column frequency to plot (default is 1)
#  |      normalize : bool
#  |          boolean flag used to determine if vectors should be normalized
#  |          using the vector magnitude in each cell (default is False)
#  |      masked_values : iterable of floats
#  |          values to mask
#  |      kwargs : matplotlib.pyplot keyword arguments for the
#  |          plt.quiver method
#  |
#  |      Returns
#  |      -------
#  |      quiver : matplotlib.pyplot.quiver
#  |          result of the quiver function
#  |
#  |  ----------------------------------------------------------------------
#  |  Readonly properties defined here:
#  |
#  |  extent
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors defined here:
#  |
#  |  __dict__
#  |      dictionary for instance variables (if defined)
#  |
#  |  __weakref__
#  |      list of weak references to the object (if defined)

# %%
def figure6(P, var_PO, var_FD):
    
    fig = plt.figure(figsize=(12,5))
    fig.suptitle('Variance in head due to alternative structural models')
    ax = plt.subplot(1, 2, 1, aspect='equal')
    #P.vor.plot(ax=ax, edgecolor='black', lw = 0.2)
    pmv = flopy.plot.PlotMapView(model=M.gwf)
    pmv.plot_grid(edgecolor='black', lw = 0.2)
    A = pmv.plot_array(var_PO, cmap = 'Spectral', alpha = 0.6)#vmin = vmin, vmax = vmax, 
    ax.set_xlabel('X (m)')
    ax.set_ylabel('Y (m)')
    ax.set_title('Pinchout Scenario')
    plt.colorbar(A, ax=ax, shrink = 0.4)
    
    ax = plt.subplot(1, 2, 2, aspect='equal')
    #P.vor.plot(ax=ax, edgecolor='black', lw = 0.2)
    grid = N.gwf.modelgrid
    pmv = flopy.plot.PlotMapView(model=N.gwf)
    pmv.plot_grid(edgecolor='black', lw = 0.2)
    B = pmv.plot_array(var_FD, cmap = 'Spectral', alpha = 0.6)#vmin = vmin, vmax = vmax, 
    
    ax.set_xlabel('X (m)')
    ax.set_yticks([])
    ax.set_yticklabels([])
    ax.set_title('Fault Scenario')
    plt.colorbar(B, ax=ax, shrink = 0.4)
    
    plt.subplots_adjust(wspace=0.05, hspace=0.1)    
    plt.tight_layout()  
    plt.show()   
    fig.savefig('../figures/fig6.tif', dpi=300)

figure6(P, var_PO, var_FD)
