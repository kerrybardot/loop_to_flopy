# %% [markdown]
# ### Case Study - Pinchout and Fault Scenarios
# #### Showcasing LoopStructural-Flopy to address Model Structure Uncertainty
#
# This notebook showcases how structural parameters, in this case CPz and fault_offset can be used to generate multiple structural models and address structural uncertainty in 3D groundwater models. This notebook contains the Pinchout and Fault Scenarios and use a synthetic example to explore uncertainty in pinchout location and fault geometry.

# %%
# %run ./loop_showcase_functions.ipynb
#load from MODFLOW_tools (clone repo https://github.com/JimMcCallum/MODFLOW_Tools)
# %run ../../MODFLOW_Tools/modelling_routines/modelling_routines.ipynb
# %run ../../MODFLOW_Tools/meshing_routines/meshing_routines.ipynb
# %run ../../MODFLOW_Tools/geomodel_routines/geomodel_routines.ipynb
# %run ../../MODFLOW_Tools/loop2flopy/loop2flopy.ipynb
# %run ../../MODFLOW_Tools/plotting_routines_USG/plotting_routines.ipynb
# Out:
# C:\Users\19904604\AppData\Local\Temp\ipykernel_24456\3209728366.py:21: DeprecationWarning: GeoPandas is set to use PyGEOS over Shapely. PyGEOS support is deprecatedand will be removed in GeoPandas 1.0, released in the Q1 of 2024. Please migrate to Shapely 2.0 (https://geopandas.org/en/stable/docs/user_guide/pygeos_to_shapely.html).
#   import geopandas as gpd
# Modelling routines loaded!
# Meshing routines loaded!
# Geomodel routines loaded!
# loop2flopy routines loaded!
# Plotting routines loaded!

# %%
P = Project('showcase', boundingbox = [0, 6000, 0, 6000, -500, 0]) # (x0, x1, y0, y1, z0, z1)

# Spatial information
P.crs = "epsg:28350" # Put in coordinate reference
P.xypumpbores = [] 
P.npump = len(P.xypumpbores)
P.idpumpbores = [] 
P.xyobsbores = [(1500,1000), (2500, 5000), (4000, 3000), (5000,1500)]
P.idobsbores = ['OB1', 'OB2', 'OB3', 'OB4'] 
#P.geo_coords=[(500,500), (1600, 2800), (5500,5500), (2800,1600)]
#P.geo_bores = ['P1', 'P2', 'P3', 'P4']

# Observation Points
P.nobs = len(P.xyobsbores)
obs_z = [-40, -50, -100, -200, -300]
P.nzobs = len(obs_z)
P.zobs = np.ones((P.nobs, P.nzobs))
for j in range(P.nzobs):
    P.zobs[:, j] = P.zobs[:, j] * obs_z[j] 

# Meshing parameters
P.triExeName = '../exe/triangle.exe'
P.fx1, P.fy1, P.fx2, P.fy2 = (2000, 4500, 3000, 1000) # fault end points
P.fault_buffer = 150.  # offset boundary from fault
P.r = 40               # refining factor for model boundary. High r has refined edges
P.w = 150              # interior boundary offset
P.boundmaxtri = 50000  # max triangle area in boundary area
P.modelmaxtri = 50000  # max triangle area in main model area
P.angle = 32           # minimum triangle angles
P.radius1 = 100        # radius of inner circle around pumping bores
P.radius2 = 200        # radius of outer circle around pumping bores
P.boremaxtri = 100000   # max triangle area within bore radius

# Flow model parameters
P.mfexe_name = '../exe/mf6.exe'
P.workspace = '../modelfiles/'
P.nlg = 4    # number of geological layers
P.nls = 3    # number sublayers for conformable
P.nlv  = 30  # number of layers for voxel transect grid

P.ss = [0.00001, 0.00001, 0.00001, 0.00001]
P.sy = [0.1, 0.1, 0.1, 0.1]
P.rch = 0.4/365 # 0.0027 m/d
P.strt = -20.
P.chfunc = lambda x,z: -(0.005*x) - (z * 0.02)-20 # horizontal gradient of 0.01 and vertical gradient of 0.02
P.xt3d = True
   
vtk_workspace = '../vtk_files'
if not os.path.isdir(vtk_workspace):
    os.makedirs(vtk_workspace, exist_ok=True)

# %%
P.cell2dtri, P.xcyctri, P.verticestri, P.tri, trinodes = createcell2d(P, grid = 'tri', fault = True)  
P.cell2dvor, P.xcycvor, P.verticesvor, P.vor, vornodes = createcell2d(P, grid = 'vor', fault = True)

# %%
figure2(P)

# %% [markdown]
# ### Faults - 6 simulations

# %%
P.hk = [1, 2, 0.01, 5] 
P.vk = [i/10 for i in P.hk]

options = np.linspace(0, 320, 6) # Fault displacement

data = pd.read_excel("../data/loop_showcase_data.xls",sheet_name = "fault_example")
strat = pd.read_excel("../data/loop_showcase_data.xls",sheet_name = "strat")

P.control_points = ([])
P.fault_max_disp = 100.    # Was 200
P.minor_axis = 1000        # Fault_influence - orthogonal to fault
P.fault_center = [P.fx1 + (P.fx2 - P.fx1)/2, P.fy1 + (P.fy2 - P.fy1)/2, -400]
P.fault_slip_vector=[0,0,1]
    
fault_modelnames, fault_models, fault_obs_heads = [],[],[]         

for i in range(len(options)):
    fault_modelnames.append(str('FD_'+str(options[i])))  
    fault_models.append(Model(fault_modelnames[i], P, plan = 'vor', transect = 'con')) # Create flow model  
    P.fault_max_disp = options[i] /2
    P.data, P.strat = prepare_geomodel_loopshowcase(P, data, strat, include_fault = True)   # Prepare geomodel inputs
    P.geomodel = create_geomodel_loopshowcase(P, include_fault = True) # Make geomodel
    M = fault_models[i]
    M.create_lith_dis_arrays(P)                                 # Create lith and dis arrays
    M.create_prop_arrays(P)                                     # Create K arrays
    M.create_flow_package_arrays(P)                             # Create flow packages
    M.gwf, M.head_ss, M.obs_ss, M.runtime_ss = M.write_run_model(P, period = 'Steady', ic_array = P.strt)   
    fault_obs_heads.append((process_obs_steady(P, M)))
    f = os.path.join(vtk_workspace, "faults", M.modelname)
    M.gwf.export(f, fmt="vtk")
# Out:
# WARNING: 2024-07-18 09:27:40,801: geological_model.py:609 -- deprecated method. Model data can now be set using the data attribute
# WARNING: 2024-07-18 09:27:40,816: geological_model.py:1359 -- Fault displacement is 0
# WARNING: 2024-07-18 09:27:40,845: _fault_builder.py:208 -- There is no slip vector data for the fault, using vertical slip vector
#                           projected onto fault surface estimating from fault normal
# WARNING: 2024-07-18 09:27:40,848: _fault_builder.py:239 -- Fault major axis using map length: 3640.0549446402592
# C:\Users\19904604\Anaconda3\envs\loop3denvu\lib\site-packages\LoopStructural\modelling\core\geological_model.py:647: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = cm.get_cmap(cmap, n_units)
# Fault included!
# {'upper': 0, 'upper_unconformity': 1, 'Fault': 2, 'lower': 3}
# Creating lithology and discretisation arrays for  FD_0.0  ...
# Time taken =  2.193419
# Creating property arrays for  FD_0.0  ...
# Time taken =  0.002163
# Adding flow packages to  FD_0.0  ...
# Time taken =  0.623876
# Writing simulation and gwf for  FD_0.0  ...
# FD_0.0
# WARNING: Unable to resolve dimension of ('gwf6', 'disu', 'cell2d', 'cell2d', 'icvert') based on shape "ncvert".
# Running simulation for  FD_0.0  ...
# Period =  Steady
# Model success =  True
# run_time =  16.603771
# WARNING: 2024-07-18 09:28:01,359: geological_model.py:609 -- deprecated method. Model data can now be set using the data attribute
# WARNING: 2024-07-18 09:28:01,375: _fault_builder.py:208 -- There is no slip vector data for the fault, using vertical slip vector
#                           projected onto fault surface estimating from fault normal
# WARNING: 2024-07-18 09:28:01,375: _fault_builder.py:239 -- Fault major axis using map length: 3640.0549446402592
# C:\Users\19904604\Anaconda3\envs\loop3denvu\lib\site-packages\LoopStructural\modelling\core\geological_model.py:647: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = cm.get_cmap(cmap, n_units)
# Fault included!
# {'upper': 0, 'upper_unconformity': 1, 'Fault': 2, 'lower': 3}
# Creating lithology and discretisation arrays for  FD_64.0  ...
# Time taken =  22.341435
# Creating property arrays for  FD_64.0  ...
# Time taken =  0.009217
# Adding flow packages to  FD_64.0  ...
# Time taken =  0.75672
# Writing simulation and gwf for  FD_64.0  ...
# FD_64.0
# WARNING: Unable to resolve dimension of ('gwf6', 'disu', 'cell2d', 'cell2d', 'icvert') based on shape "ncvert".
# Running simulation for  FD_64.0  ...
# Period =  Steady
# Model success =  True
# run_time =  16.343941
# WARNING: 2024-07-18 09:28:41,710: geological_model.py:609 -- deprecated method. Model data can now be set using the data attribute
# WARNING: 2024-07-18 09:28:41,741: _fault_builder.py:208 -- There is no slip vector data for the fault, using vertical slip vector
#                           projected onto fault surface estimating from fault normal
# WARNING: 2024-07-18 09:28:41,741: _fault_builder.py:239 -- Fault major axis using map length: 3640.0549446402592
# C:\Users\19904604\Anaconda3\envs\loop3denvu\lib\site-packages\LoopStructural\modelling\core\geological_model.py:647: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = cm.get_cmap(cmap, n_units)
# Fault included!
# {'upper': 0, 'upper_unconformity': 1, 'Fault': 2, 'lower': 3}
# Creating lithology and discretisation arrays for  FD_128.0  ...
# Time taken =  19.55766
# Creating property arrays for  FD_128.0  ...
# Time taken =  0.009295
# Adding flow packages to  FD_128.0  ...
# Time taken =  0.70541
# Writing simulation and gwf for  FD_128.0  ...
# FD_128.0
# WARNING: Unable to resolve dimension of ('gwf6', 'disu', 'cell2d', 'cell2d', 'icvert') based on shape "ncvert".
# Running simulation for  FD_128.0  ...
# Period =  Steady
# Model success =  True
# run_time =  17.143353
# WARNING: 2024-07-18 09:29:20,015: geological_model.py:609 -- deprecated method. Model data can now be set using the data attribute
# WARNING: 2024-07-18 09:29:20,035: _fault_builder.py:208 -- There is no slip vector data for the fault, using vertical slip vector
#                           projected onto fault surface estimating from fault normal
# WARNING: 2024-07-18 09:29:20,035: _fault_builder.py:239 -- Fault major axis using map length: 3640.0549446402592
# C:\Users\19904604\Anaconda3\envs\loop3denvu\lib\site-packages\LoopStructural\modelling\core\geological_model.py:647: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = cm.get_cmap(cmap, n_units)
# Fault included!
# {'upper': 0, 'upper_unconformity': 1, 'Fault': 2, 'lower': 3}
# Creating lithology and discretisation arrays for  FD_192.0  ...
# Time taken =  19.15112
# Creating property arrays for  FD_192.0  ...
# Time taken =  0.012208
# Adding flow packages to  FD_192.0  ...
# Time taken =  0.682764
# Writing simulation and gwf for  FD_192.0  ...
# FD_192.0
# WARNING: Unable to resolve dimension of ('gwf6', 'disu', 'cell2d', 'cell2d', 'icvert') based on shape "ncvert".
# Running simulation for  FD_192.0  ...
# Period =  Steady
# Model success =  True
# run_time =  18.454641
# WARNING: 2024-07-18 09:29:59,271: geological_model.py:609 -- deprecated method. Model data can now be set using the data attribute
# WARNING: 2024-07-18 09:29:59,296: _fault_builder.py:208 -- There is no slip vector data for the fault, using vertical slip vector
#                           projected onto fault surface estimating from fault normal
# WARNING: 2024-07-18 09:29:59,299: _fault_builder.py:239 -- Fault major axis using map length: 3640.0549446402592
# C:\Users\19904604\Anaconda3\envs\loop3denvu\lib\site-packages\LoopStructural\modelling\core\geological_model.py:647: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = cm.get_cmap(cmap, n_units)
# Fault included!
# {'upper': 0, 'upper_unconformity': 1, 'Fault': 2, 'lower': 3}
# Creating lithology and discretisation arrays for  FD_256.0  ...
# Time taken =  22.182842
# Creating property arrays for  FD_256.0  ...
# Time taken =  0.005122
# Adding flow packages to  FD_256.0  ...
# Time taken =  0.861893
# Writing simulation and gwf for  FD_256.0  ...
# FD_256.0
# WARNING: Unable to resolve dimension of ('gwf6', 'disu', 'cell2d', 'cell2d', 'icvert') based on shape "ncvert".
# Running simulation for  FD_256.0  ...
# Period =  Steady
# Model success =  True
# run_time =  19.250509
# WARNING: 2024-07-18 09:30:42,371: geological_model.py:609 -- deprecated method. Model data can now be set using the data attribute
# WARNING: 2024-07-18 09:30:42,395: _fault_builder.py:208 -- There is no slip vector data for the fault, using vertical slip vector
#                           projected onto fault surface estimating from fault normal
# WARNING: 2024-07-18 09:30:42,398: _fault_builder.py:239 -- Fault major axis using map length: 3640.0549446402592
# C:\Users\19904604\Anaconda3\envs\loop3denvu\lib\site-packages\LoopStructural\modelling\core\geological_model.py:647: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = cm.get_cmap(cmap, n_units)
# Fault included!
# {'upper': 0, 'upper_unconformity': 1, 'Fault': 2, 'lower': 3}
# Creating lithology and discretisation arrays for  FD_320.0  ...
# Time taken =  22.857628
# Creating property arrays for  FD_320.0  ...
# Time taken =  0.032894
# Adding flow packages to  FD_320.0  ...
# Time taken =  1.753279
# Writing simulation and gwf for  FD_320.0  ...
# FD_320.0
# WARNING: Unable to resolve dimension of ('gwf6', 'disu', 'cell2d', 'cell2d', 'icvert') based on shape "ncvert".
# Running simulation for  FD_320.0  ...
# Period =  Steady
# Model success =  True
# run_time =  18.995073

# %%
# PLOTS
#plot_bores(P)
#plot_observations(heads = fault_obs_heads, modelnames = fault_modelnames, ylim = [-40, -5])
#plot_bylayer(P, models = fault_models, layer = 2, vmin = -35, vmax = -10) 
#multiplot_vgrid_transect(P, models = fault_models, array = 'lith', X0 = P.x0, Y0 = P.y0, X1 = P.x1, Y1 = P.y1)
#multiplot_prop_transect(P, models = fault_models, array = 'head_ss', X0 = P.x0, Y0 = P.y0, X1 = P.x1, Y1 = P.y1,)

# %%
# %run ./loop_showcase_functions.ipynb
figure5(P, models = fault_models, X0 = P.x0, Y0 = P.y0, X1 = P.x1, Y1 = P.y1,vmin = -45, vmax = -5)
# Out:
# C:\Users\19904604\AppData\Local\Temp\ipykernel_24456\2520930060.py:114: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()
# C:\Users\19904604\AppData\Local\Temp\ipykernel_24456\2520930060.py:114: UserWarning: tight_layout not applied: number of columns in subplot specifications must be multiples of one another.
#   plt.tight_layout()

# %% [markdown]
# ### Pinchout - 6 simulations

# %%
P.hk = [1, 0.1, 10, 0.1] 
P.vk = [i/10 for i in P.hk]

P.cell2dvor, P.xcycvor, P.verticesvor, P.vor, vornodes = createcell2d(P, grid = 'vor', fault = False)    
data = pd.read_excel("../data/loop_showcase_data.xls",sheet_name = "pinchout_example")
strat = pd.read_excel("../data/loop_showcase_data.xls",sheet_name = "strat")

options = np.linspace(-250, 0, 6) # control point z values

pinchout_modelnames, pinchout_models, pinchout_obs_heads = [],[],[]        
heads = []

for i in range(len(options)):
    pinchout_modelnames.append(str('PO_'+str(options[i])))  
    pinchout_models.append(Model(pinchout_modelnames[i], P, plan = 'vor', transect = 'con')) # Create flow model  
    P.control_points = (['CP1', 'control', 3000, 3000, options[i], -200, 'c', 'lower', np.nan, np.nan, np.nan],) 
    
    P.data, P.strat = prepare_geomodel_loopshowcase(P, data, strat, include_fault = False)   # Prepare geomodel inputs
    P.geomodel = create_geomodel_loopshowcase(P, include_fault = False) # Make geomodel
    M = pinchout_models[i]
    M.create_lith_dis_arrays(P)                                 # Create lith and dis arrays
    M.create_prop_arrays(P)                                     # Create K arrays
    M.create_flow_package_arrays(P)                             # Create flow packages
    M.gwf, M.head_ss, M.obs_ss, M.runtime_ss = M.write_run_model(P, period = 'Steady', ic_array = P.strt)   
    pinchout_obs_heads.append((process_obs_steady(P, M)))
    heads.append((M.head_ss))
    f = os.path.join(vtk_workspace, "pinchouts", M.modelname)
    M.gwf.export(f, fmt="vtk")
# Out:
# WARNING: 2024-07-18 09:31:33,028: geological_model.py:609 -- deprecated method. Model data can now be set using the data attribute
# C:\Users\19904604\Anaconda3\envs\loop3denvu\lib\site-packages\LoopStructural\modelling\core\geological_model.py:647: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = cm.get_cmap(cmap, n_units)
# {'upper': 0, 'upper_unconformity': 1, 'lower': 2}
# Creating lithology and discretisation arrays for  PO_-250.0  ...
# Time taken =  1.971636
# Creating property arrays for  PO_-250.0  ...
# Time taken =  0.007651
# Adding flow packages to  PO_-250.0  ...
# Time taken =  0.635151
# Writing simulation and gwf for  PO_-250.0  ...
# PO_-250.0
# WARNING: Unable to resolve dimension of ('gwf6', 'disu', 'cell2d', 'cell2d', 'icvert') based on shape "ncvert".
# Running simulation for  PO_-250.0  ...
# Period =  Steady
# Model success =  True
# run_time =  12.899996
# WARNING: 2024-07-18 09:31:49,220: geological_model.py:609 -- deprecated method. Model data can now be set using the data attribute
# C:\Users\19904604\Anaconda3\envs\loop3denvu\lib\site-packages\LoopStructural\modelling\core\geological_model.py:647: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = cm.get_cmap(cmap, n_units)
# {'upper': 0, 'upper_unconformity': 1, 'lower': 2}
# Creating lithology and discretisation arrays for  PO_-200.0  ...
# Time taken =  1.509814
# Creating property arrays for  PO_-200.0  ...
# Time taken =  0.009732
# Adding flow packages to  PO_-200.0  ...
# Time taken =  0.538201
# Writing simulation and gwf for  PO_-200.0  ...
# PO_-200.0
# WARNING: Unable to resolve dimension of ('gwf6', 'disu', 'cell2d', 'cell2d', 'icvert') based on shape "ncvert".
# Running simulation for  PO_-200.0  ...
# Period =  Steady
# Model success =  True
# run_time =  12.733253
# WARNING: 2024-07-18 09:32:04,546: geological_model.py:609 -- deprecated method. Model data can now be set using the data attribute
# C:\Users\19904604\Anaconda3\envs\loop3denvu\lib\site-packages\LoopStructural\modelling\core\geological_model.py:647: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = cm.get_cmap(cmap, n_units)
# {'upper': 0, 'upper_unconformity': 1, 'lower': 2}
# Creating lithology and discretisation arrays for  PO_-150.0  ...
# Time taken =  1.488325
# Creating property arrays for  PO_-150.0  ...
# Time taken =  0.006819
# Adding flow packages to  PO_-150.0  ...
# Time taken =  0.547667
# Writing simulation and gwf for  PO_-150.0  ...
# PO_-150.0
# WARNING: Unable to resolve dimension of ('gwf6', 'disu', 'cell2d', 'cell2d', 'icvert') based on shape "ncvert".
# Running simulation for  PO_-150.0  ...
# Period =  Steady
# Model success =  True
# run_time =  9.870373
# WARNING: 2024-07-18 09:32:16,950: geological_model.py:609 -- deprecated method. Model data can now be set using the data attribute
# C:\Users\19904604\Anaconda3\envs\loop3denvu\lib\site-packages\LoopStructural\modelling\core\geological_model.py:647: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = cm.get_cmap(cmap, n_units)
# {'upper': 0, 'upper_unconformity': 1, 'lower': 2}
# Creating lithology and discretisation arrays for  PO_-100.0  ...
# Time taken =  1.495371
# Creating property arrays for  PO_-100.0  ...
# Time taken =  0.005774
# Adding flow packages to  PO_-100.0  ...
# Time taken =  0.543917
# Writing simulation and gwf for  PO_-100.0  ...
# PO_-100.0
# WARNING: Unable to resolve dimension of ('gwf6', 'disu', 'cell2d', 'cell2d', 'icvert') based on shape "ncvert".
# Running simulation for  PO_-100.0  ...
# Period =  Steady
# Model success =  True
# run_time =  10.360379
# WARNING: 2024-07-18 09:32:29,833: geological_model.py:609 -- deprecated method. Model data can now be set using the data attribute
# C:\Users\19904604\Anaconda3\envs\loop3denvu\lib\site-packages\LoopStructural\modelling\core\geological_model.py:647: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = cm.get_cmap(cmap, n_units)
# {'upper': 0, 'upper_unconformity': 1, 'lower': 2}
# Creating lithology and discretisation arrays for  PO_-50.0  ...
# Time taken =  1.547017
# Creating property arrays for  PO_-50.0  ...
# Time taken =  0.006715
# Adding flow packages to  PO_-50.0  ...
# Time taken =  0.557424
# Writing simulation and gwf for  PO_-50.0  ...
# PO_-50.0
# WARNING: Unable to resolve dimension of ('gwf6', 'disu', 'cell2d', 'cell2d', 'icvert') based on shape "ncvert".
# Running simulation for  PO_-50.0  ...
# Period =  Steady
# Model success =  True
# run_time =  8.918184
# WARNING: 2024-07-18 09:32:41,337: geological_model.py:609 -- deprecated method. Model data can now be set using the data attribute
# C:\Users\19904604\Anaconda3\envs\loop3denvu\lib\site-packages\LoopStructural\modelling\core\geological_model.py:647: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = cm.get_cmap(cmap, n_units)
# {'upper': 0, 'upper_unconformity': 1, 'lower': 2}
# Creating lithology and discretisation arrays for  PO_0.0  ...
# Time taken =  1.505336
# Creating property arrays for  PO_0.0  ...
# Time taken =  0.007037
# Adding flow packages to  PO_0.0  ...
# Time taken =  0.538049
# Writing simulation and gwf for  PO_0.0  ...
# PO_0.0
# WARNING: Unable to resolve dimension of ('gwf6', 'disu', 'cell2d', 'cell2d', 'icvert') based on shape "ncvert".
# Running simulation for  PO_0.0  ...
# Period =  Steady
# Model success =  True
# run_time =  8.574391

# %%
#plot_bylayer(P, models = pinchout_models, layer = 1, vmin = -40, vmax = 20) 
#plot_observations(ylim = [-40, 20], modelnames = pinchout_modelnames, heads = pinchout_obs_heads)
#multiplot_vgrid_transect(P, models = pinchout_models, array = 'lith', X0 = P.x0, Y0 = P.y0, X1 = P.x1, Y1 = P.y1,)
#multiplot_prop_transect(P, models = pinchout_models, array = 'head_ss', 
                        #X0 = P.x0, Y0 = P.y0, X1 = P.x1, Y1 = P.y1, vmin = -45, vmax = 10)

# %%
# %run ./loop_showcase_functions.ipynb
figure4(P, models = pinchout_models, X0 = P.x0, Y0 = P.y0, X1 = P.x1, Y1 = P.y1,)
# Out:
# C:\Users\19904604\AppData\Local\Temp\ipykernel_24456\2396756865.py:127: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()
# C:\Users\19904604\AppData\Local\Temp\ipykernel_24456\2396756865.py:127: UserWarning: tight_layout not applied: number of columns in subplot specifications must be multiples of one another.
#   plt.tight_layout()

# %% [markdown]
# ### Pinchout - 100 simulations

# %%
options = np.linspace(-250, 0, 100) # control point z values
    
heads_PO = []
for i in range(len(options)): 
    M = Model('PO', P, plan = 'vor', transect = 'con') # Create flow model  
    P.control_points = (['CP1', 'control', 3000, 3000, options[i], -200, 'c', 'lower', np.nan, np.nan, np.nan],) 
    P.data, P.strat = prepare_geomodel_loopshowcase(P, data, strat, include_fault = False)   # Prepare geomodel inputs
    P.geomodel = create_geomodel_loopshowcase(P, include_fault = False) # Make geomodel
    M.create_lith_dis_arrays(P)                                 # Create lith and dis arrays
    M.create_prop_arrays(P)                                     # Create K arrays
    M.create_flow_package_arrays(P)                             # Create flow packages
    M.gwf, M.head_ss, M.obs_ss, M.runtime_ss = M.write_run_model(P, period = 'Steady', ic_array = P.strt)   
    heads_PO.append((M.head_ss))
# Out:
# WARNING: 2024-07-17 16:31:40,677: geological_model.py:609 -- deprecated method. Model data can now be set using the data attribute
# C:\Users\19904604\Anaconda3\envs\loop3denvu\lib\site-packages\LoopStructural\modelling\core\geological_model.py:647: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = cm.get_cmap(cmap, n_units)
# {'upper': 0, 'upper_unconformity': 1, 'lower': 2}
# Creating lithology and discretisation arrays for  PO  ...
# Time taken =  1.656087
# Creating property arrays for  PO  ...
# Time taken =  0.0
# Adding flow packages to  PO  ...
# Time taken =  0.655148
# Writing simulation and gwf for  PO  ...
# PO
# WARNING: Unable to resolve dimension of ('gwf6', 'disu', 'cell2d', 'cell2d', 'icvert') based on shape "ncvert".
# Running simulation for  PO  ...
# WARNING: 2024-07-17 16:31:56,048: geological_model.py:609 -- deprecated method. Model data can now be set using the data attribute
# Period =  Steady
# Model success =  True
# run_time =  13.029509
# {'upper': 0, 'upper_unconformity': 1, 'lower': 2}
# Creating lithology and discretisation arrays for  PO  ...
# C:\Users\19904604\Anaconda3\envs\loop3denvu\lib\site-packages\LoopStructural\modelling\core\geological_model.py:647: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = cm.get_cmap(cmap, n_units)
# Time taken =  1.622431
# Creating property arrays for  PO  ...
# Time taken =  0.002062
# Adding flow packages to  PO  ...
# Time taken =  0.540522
# Writing simulation and gwf for  PO  ...
# PO
# WARNING: Unable to resolve dimension of ('gwf6', 'disu', 'cell2d', 'cell2d', 'icvert') based on shape "ncvert".
# Running simulation for  PO  ...
# WARNING: 2024-07-17 16:32:12,543: geological_model.py:609 -- deprecated method. Model data can now be set using the data attribute
# Period =  Steady
# Model success =  True
# run_time =  14.290076
# {'upper': 0, 'upper_unconformity': 1, 'lower': 2}
# Creating lithology and discretisation arrays for  PO  ...
# C:\Users\19904604\Anaconda3\envs\loop3denvu\lib\site-packages\LoopStructural\modelling\core\geological_model.py:647: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = cm.get_cmap(cmap, n_units)
# Time taken =  1.689775
# Creating property arrays for  PO  ...
# Time taken =  0.008075
# Adding flow packages to  PO  ...
# Time taken =  0.592245
# Writing simulation and gwf for  PO  ...
# PO
# WARNING: Unable to resolve dimension of ('gwf6', 'disu', 'cell2d', 'cell2d', 'icvert') based on shape "ncvert".
# Running simulation for  PO  ...
# WARNING: 2024-07-17 16:32:27,924: geological_model.py:609 -- deprecated method. Model data can now be set using the data attribute
# Period =  Steady
# Model success =  True
# run_time =  13.059919
# {'upper': 0, 'upper_unconformity': 1, 'lower': 2}
# Creating lithology and discretisation arrays for  PO  ...
# C:\Users\19904604\Anaconda3\envs\loop3denvu\lib\site-packages\LoopStructural\modelling\core\geological_model.py:647: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = cm.get_cmap(cmap, n_units)
# Time taken =  1.519158
# Creating property arrays for  PO  ...
# Time taken =  0.0
# Adding flow packages to  PO  ...
# Time taken =  0.561804
# Writing simulation and gwf for  PO  ...
# PO
# WARNING: Unable to resolve dimension of ('gwf6', 'disu', 'cell2d', 'cell2d', 'icvert') based on shape "ncvert".
# Running simulation for  PO  ...
# WARNING: 2024-07-17 16:32:43,790: geological_model.py:609 -- deprecated method. Model data can now be set using the data attribute
# Period =  Steady
# Model success =  True
# run_time =  13.73619
# {'upper': 0, 'upper_unconformity': 1, 'lower': 2}
# Creating lithology and discretisation arrays for  PO  ...
# C:\Users\19904604\Anaconda3\envs\loop3denvu\lib\site-packages\LoopStructural\modelling\core\geological_model.py:647: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = cm.get_cmap(cmap, n_units)
# Time taken =  1.60505
# Creating property arrays for  PO  ...
# Time taken =  0.015651
# Adding flow packages to  PO  ...
# Time taken =  0.545547
# Writing simulation and gwf for  PO  ...
# PO
# WARNING: Unable to resolve dimension of ('gwf6', 'disu', 'cell2d', 'cell2d', 'icvert') based on shape "ncvert".
# Running simulation for  PO  ...
# WARNING: 2024-07-17 16:33:00,740: geological_model.py:609 -- deprecated method. Model data can now be set using the data attribute
# Period =  Steady
# Model success =  True
# run_time =  14.751537
# {'upper': 0, 'upper_unconformity': 1, 'lower': 2}
# Creating lithology and discretisation arrays for  PO  ...
# C:\Users\19904604\Anaconda3\envs\loop3denvu\lib\site-packages\LoopStructural\modelling\core\geological_model.py:647: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = cm.get_cmap(cmap, n_units)
# Time taken =  1.632868
# Creating property arrays for  PO  ...
# Time taken =  0.01026
# Adding flow packages to  PO  ...
# Time taken =  0.571424
# Writing simulation and gwf for  PO  ...
# PO
# WARNING: Unable to resolve dimension of ('gwf6', 'disu', 'cell2d', 'cell2d', 'icvert') based on shape "ncvert".
# Running simulation for  PO  ...
# WARNING: 2024-07-17 16:33:15,936: geological_model.py:609 -- deprecated method. Model data can now be set using the data attribute
# Period =  Steady
# Model success =  True
# run_time =  12.949559
# {'upper': 0, 'upper_unconformity': 1, 'lower': 2}
# Creating lithology and discretisation arrays for  PO  ...
# C:\Users\19904604\Anaconda3\envs\loop3denvu\lib\site-packages\LoopStructural\modelling\core\geological_model.py:647: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = cm.get_cmap(cmap, n_units)
# Time taken =  1.539415
# Creating property arrays for  PO  ...
# Time taken =  0.002146
# Adding flow packages to  PO  ...
# Time taken =  0.561247
# Writing simulation and gwf for  PO  ...
# PO
# WARNING: Unable to resolve dimension of ('gwf6', 'disu', 'cell2d', 'cell2d', 'icvert') based on shape "ncvert".
# Running simulation for  PO  ...
# WARNING: 2024-07-17 16:33:31,839: geological_model.py:609 -- deprecated method. Model data can now be set using the data attribute
# Period =  Steady
# Model success =  True
# run_time =  13.760596
# {'upper': 0, 'upper_unconformity': 1, 'lower': 2}
# Creating lithology and discretisation arrays for  PO  ...
# C:\Users\19904604\Anaconda3\envs\loop3denvu\lib\site-packages\LoopStructural\modelling\core\geological_model.py:647: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = cm.get_cmap(cmap, n_units)
# Time taken =  1.605938
# Creating property arrays for  PO  ...
# Time taken =  0.008044
# Adding flow packages to  PO  ...
# Time taken =  0.550748
# Writing simulation and gwf for  PO  ...
# PO
# WARNING: Unable to resolve dimension of ('gwf6', 'disu', 'cell2d', 'cell2d', 'icvert') based on shape "ncvert".
# Running simulation for  PO  ...
# WARNING: 2024-07-17 16:33:48,404: geological_model.py:609 -- deprecated method. Model data can now be set using the data attribute
# Period =  Steady
# Model success =  True
# run_time =  14.358824
# {'upper': 0, 'upper_unconformity': 1, 'lower': 2}
# Creating lithology and discretisation arrays for  PO  ...
# C:\Users\19904604\Anaconda3\envs\loop3denvu\lib\site-packages\LoopStructural\modelling\core\geological_model.py:647: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = cm.get_cmap(cmap, n_units)
# Time taken =  1.654309
# Creating property arrays for  PO  ...
# Time taken =  0.008063
# Adding flow packages to  PO  ...
# Time taken =  0.55074
# Writing simulation and gwf for  PO  ...
# PO
# WARNING: Unable to resolve dimension of ('gwf6', 'disu', 'cell2d', 'cell2d', 'icvert') based on shape "ncvert".
# Running simulation for  PO  ...
# WARNING: 2024-07-17 16:34:04,235: geological_model.py:609 -- deprecated method. Model data can now be set using the data attribute
# Period =  Steady
# Model success =  True
# run_time =  13.592387
# {'upper': 0, 'upper_unconformity': 1, 'lower': 2}
# Creating lithology and discretisation arrays for  PO  ...
# C:\Users\19904604\Anaconda3\envs\loop3denvu\lib\site-packages\LoopStructural\modelling\core\geological_model.py:647: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = cm.get_cmap(cmap, n_units)
# Time taken =  1.558512
# Creating property arrays for  PO  ...
# Time taken =  0.002095
# Adding flow packages to  PO  ...
# Time taken =  0.571009
# Writing simulation and gwf for  PO  ...
# PO
# WARNING: Unable to resolve dimension of ('gwf6', 'disu', 'cell2d', 'cell2d', 'icvert') based on shape "ncvert".
# Running simulation for  PO  ...
# WARNING: 2024-07-17 16:34:19,834: geological_model.py:609 -- deprecated method. Model data can now be set using the data attribute
# Period =  Steady
# Model success =  True
# run_time =  13.42375
# {'upper': 0, 'upper_unconformity': 1, 'lower': 2}
# Creating lithology and discretisation arrays for  PO  ...
# C:\Users\19904604\Anaconda3\envs\loop3denvu\lib\site-packages\LoopStructural\modelling\core\geological_model.py:647: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = cm.get_cmap(cmap, n_units)
# Time taken =  1.774351
# Creating property arrays for  PO  ...
# Time taken =  0.008054
# Adding flow packages to  PO  ...
# Time taken =  0.543182
# Writing simulation and gwf for  PO  ...
# PO
# WARNING: Unable to resolve dimension of ('gwf6', 'disu', 'cell2d', 'cell2d', 'icvert') based on shape "ncvert".
# Running simulation for  PO  ...
# WARNING: 2024-07-17 16:34:36,584: geological_model.py:609 -- deprecated method. Model data can now be set using the data attribute
# Period =  Steady
# Model success =  True
# run_time =  14.393289
# {'upper': 0, 'upper_unconformity': 1, 'lower': 2}
# Creating lithology and discretisation arrays for  PO  ...
# C:\Users\19904604\Anaconda3\envs\loop3denvu\lib\site-packages\LoopStructural\modelling\core\geological_model.py:647: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = cm.get_cmap(cmap, n_units)
# Time taken =  1.610244
# Creating property arrays for  PO  ...
# Time taken =  0.0
# Adding flow packages to  PO  ...
# Time taken =  0.604629
# Writing simulation and gwf for  PO  ...
# PO
# WARNING: Unable to resolve dimension of ('gwf6', 'disu', 'cell2d', 'cell2d', 'icvert') based on shape "ncvert".
# Running simulation for  PO  ...
# WARNING: 2024-07-17 16:34:52,708: geological_model.py:609 -- deprecated method. Model data can now be set using the data attribute
# Period =  Steady
# Model success =  True
# run_time =  13.871308
# {'upper': 0, 'upper_unconformity': 1, 'lower': 2}
# Creating lithology and discretisation arrays for  PO  ...
# C:\Users\19904604\Anaconda3\envs\loop3denvu\lib\site-packages\LoopStructural\modelling\core\geological_model.py:647: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = cm.get_cmap(cmap, n_units)
# Time taken =  1.551976
# Creating property arrays for  PO  ...
# Time taken =  0.010235
# Adding flow packages to  PO  ...
# Time taken =  0.552028
# Writing simulation and gwf for  PO  ...
# PO
# WARNING: Unable to resolve dimension of ('gwf6', 'disu', 'cell2d', 'cell2d', 'icvert') based on shape "ncvert".
# Running simulation for  PO  ...
# WARNING: 2024-07-17 16:35:07,465: geological_model.py:609 -- deprecated method. Model data can now be set using the data attribute
# Period =  Steady
# Model success =  True
# run_time =  12.633387
# {'upper': 0, 'upper_unconformity': 1, 'lower': 2}
# Creating lithology and discretisation arrays for  PO  ...
# C:\Users\19904604\Anaconda3\envs\loop3denvu\lib\site-packages\LoopStructural\modelling\core\geological_model.py:647: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = cm.get_cmap(cmap, n_units)
# Time taken =  1.513608
# Creating property arrays for  PO  ...
# Time taken =  0.0
# Adding flow packages to  PO  ...
# Time taken =  0.540736
# Writing simulation and gwf for  PO  ...
# PO
# WARNING: Unable to resolve dimension of ('gwf6', 'disu', 'cell2d', 'cell2d', 'icvert') based on shape "ncvert".
# Running simulation for  PO  ...
# WARNING: 2024-07-17 16:35:22,377: geological_model.py:609 -- deprecated method. Model data can now be set using the data attribute
# Period =  Steady
# Model success =  True
# run_time =  12.813585
# {'upper': 0, 'upper_unconformity': 1, 'lower': 2}
# Creating lithology and discretisation arrays for  PO  ...
# C:\Users\19904604\Anaconda3\envs\loop3denvu\lib\site-packages\LoopStructural\modelling\core\geological_model.py:647: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = cm.get_cmap(cmap, n_units)
# Time taken =  1.703131
# Creating property arrays for  PO  ...
# Time taken =  0.0
# Adding flow packages to  PO  ...
# Time taken =  0.63323
# Writing simulation and gwf for  PO  ...
# PO
# WARNING: Unable to resolve dimension of ('gwf6', 'disu', 'cell2d', 'cell2d', 'icvert') based on shape "ncvert".
# Running simulation for  PO  ...
# WARNING: 2024-07-17 16:35:39,393: geological_model.py:609 -- deprecated method. Model data can now be set using the data attribute
# Period =  Steady
# Model success =  True
# run_time =  14.632831
# {'upper': 0, 'upper_unconformity': 1, 'lower': 2}
# Creating lithology and discretisation arrays for  PO  ...
# C:\Users\19904604\Anaconda3\envs\loop3denvu\lib\site-packages\LoopStructural\modelling\core\geological_model.py:647: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = cm.get_cmap(cmap, n_units)
# Time taken =  1.97062
# Creating property arrays for  PO  ...
# Time taken =  0.008038
# Adding flow packages to  PO  ...
# Time taken =  0.594488
# Writing simulation and gwf for  PO  ...
# PO
# WARNING: Unable to resolve dimension of ('gwf6', 'disu', 'cell2d', 'cell2d', 'icvert') based on shape "ncvert".
# Running simulation for  PO  ...
# WARNING: 2024-07-17 16:35:54,119: geological_model.py:609 -- deprecated method. Model data can now be set using the data attribute
# Period =  Steady
# Model success =  True
# run_time =  12.10453
# {'upper': 0, 'upper_unconformity': 1, 'lower': 2}
# Creating lithology and discretisation arrays for  PO  ...
# C:\Users\19904604\Anaconda3\envs\loop3denvu\lib\site-packages\LoopStructural\modelling\core\geological_model.py:647: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = cm.get_cmap(cmap, n_units)
# Time taken =  1.731444
# Creating property arrays for  PO  ...
# Time taken =  0.010132
# Adding flow packages to  PO  ...
# Time taken =  0.608065
# Writing simulation and gwf for  PO  ...
# PO
# WARNING: Unable to resolve dimension of ('gwf6', 'disu', 'cell2d', 'cell2d', 'icvert') based on shape "ncvert".
# Running simulation for  PO  ...
# WARNING: 2024-07-17 16:36:08,164: geological_model.py:609 -- deprecated method. Model data can now be set using the data attribute
# Period =  Steady
# Model success =  True
# run_time =  11.663518
# {'upper': 0, 'upper_unconformity': 1, 'lower': 2}
# Creating lithology and discretisation arrays for  PO  ...
# C:\Users\19904604\Anaconda3\envs\loop3denvu\lib\site-packages\LoopStructural\modelling\core\geological_model.py:647: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = cm.get_cmap(cmap, n_units)
# Time taken =  1.524483
# Creating property arrays for  PO  ...
# Time taken =  0.002142
# Adding flow packages to  PO  ...
# Time taken =  0.547107
# Writing simulation and gwf for  PO  ...
# PO
# WARNING: Unable to resolve dimension of ('gwf6', 'disu', 'cell2d', 'cell2d', 'icvert') based on shape "ncvert".
# Running simulation for  PO  ...
# WARNING: 2024-07-17 16:36:21,973: geological_model.py:609 -- deprecated method. Model data can now be set using the data attribute
# Period =  Steady
# Model success =  True
# run_time =  11.701546
# {'upper': 0, 'upper_unconformity': 1, 'lower': 2}
# Creating lithology and discretisation arrays for  PO  ...
# C:\Users\19904604\Anaconda3\envs\loop3denvu\lib\site-packages\LoopStructural\modelling\core\geological_model.py:647: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = cm.get_cmap(cmap, n_units)
# Time taken =  1.644308
# Creating property arrays for  PO  ...
# Time taken =  0.010185
# Adding flow packages to  PO  ...
# Time taken =  0.538785
# Writing simulation and gwf for  PO  ...
# PO
# WARNING: Unable to resolve dimension of ('gwf6', 'disu', 'cell2d', 'cell2d', 'icvert') based on shape "ncvert".
# Running simulation for  PO  ...
# WARNING: 2024-07-17 16:36:36,182: geological_model.py:609 -- deprecated method. Model data can now be set using the data attribute
# Period =  Steady
# Model success =  True
# run_time =  11.974588
# {'upper': 0, 'upper_unconformity': 1, 'lower': 2}
# Creating lithology and discretisation arrays for  PO  ...
# C:\Users\19904604\Anaconda3\envs\loop3denvu\lib\site-packages\LoopStructural\modelling\core\geological_model.py:647: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = cm.get_cmap(cmap, n_units)
# Time taken =  1.617017
# Creating property arrays for  PO  ...
# Time taken =  0.002133
# Adding flow packages to  PO  ...
# Time taken =  0.552095
# Writing simulation and gwf for  PO  ...
# PO
# WARNING: Unable to resolve dimension of ('gwf6', 'disu', 'cell2d', 'cell2d', 'icvert') based on shape "ncvert".
# Running simulation for  PO  ...
# WARNING: 2024-07-17 16:36:51,574: geological_model.py:609 -- deprecated method. Model data can now be set using the data attribute
# Period =  Steady
# Model success =  True
# run_time =  13.210464
# {'upper': 0, 'upper_unconformity': 1, 'lower': 2}
# Creating lithology and discretisation arrays for  PO  ...
# C:\Users\19904604\Anaconda3\envs\loop3denvu\lib\site-packages\LoopStructural\modelling\core\geological_model.py:647: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = cm.get_cmap(cmap, n_units)
# Time taken =  1.645194
# Creating property arrays for  PO  ...
# Time taken =  0.010095
# Adding flow packages to  PO  ...
# Time taken =  0.735812
# Writing simulation and gwf for  PO  ...
# PO
# WARNING: Unable to resolve dimension of ('gwf6', 'disu', 'cell2d', 'cell2d', 'icvert') based on shape "ncvert".
# Running simulation for  PO  ...
# WARNING: 2024-07-17 16:37:06,872: geological_model.py:609 -- deprecated method. Model data can now be set using the data attribute
# Period =  Steady
# Model success =  True
# run_time =  12.863537
# {'upper': 0, 'upper_unconformity': 1, 'lower': 2}
# Creating lithology and discretisation arrays for  PO  ...
# C:\Users\19904604\Anaconda3\envs\loop3denvu\lib\site-packages\LoopStructural\modelling\core\geological_model.py:647: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = cm.get_cmap(cmap, n_units)
# Time taken =  1.91193
# Creating property arrays for  PO  ...
# Time taken =  0.008044
# Adding flow packages to  PO  ...
# Time taken =  0.689965
# Writing simulation and gwf for  PO  ...
# PO
# WARNING: Unable to resolve dimension of ('gwf6', 'disu', 'cell2d', 'cell2d', 'icvert') based on shape "ncvert".
# Running simulation for  PO  ...
# WARNING: 2024-07-17 16:37:21,757: geological_model.py:609 -- deprecated method. Model data can now be set using the data attribute
# Period =  Steady
# Model success =  True
# run_time =  12.24392
# {'upper': 0, 'upper_unconformity': 1, 'lower': 2}
# Creating lithology and discretisation arrays for  PO  ...
# C:\Users\19904604\Anaconda3\envs\loop3denvu\lib\site-packages\LoopStructural\modelling\core\geological_model.py:647: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = cm.get_cmap(cmap, n_units)
# Time taken =  1.673876
# Creating property arrays for  PO  ...
# Time taken =  0.008075
# Adding flow packages to  PO  ...
# Time taken =  0.553128
# Writing simulation and gwf for  PO  ...
# PO
# WARNING: Unable to resolve dimension of ('gwf6', 'disu', 'cell2d', 'cell2d', 'icvert') based on shape "ncvert".
# Running simulation for  PO  ...
# WARNING: 2024-07-17 16:37:36,370: geological_model.py:609 -- deprecated method. Model data can now be set using the data attribute
# Period =  Steady
# Model success =  True
# run_time =  12.351943
# {'upper': 0, 'upper_unconformity': 1, 'lower': 2}
# Creating lithology and discretisation arrays for  PO  ...
# C:\Users\19904604\Anaconda3\envs\loop3denvu\lib\site-packages\LoopStructural\modelling\core\geological_model.py:647: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = cm.get_cmap(cmap, n_units)
# Time taken =  1.815706
# Creating property arrays for  PO  ...
# Time taken =  0.008088
# Adding flow packages to  PO  ...
# Time taken =  0.708892
# Writing simulation and gwf for  PO  ...
# PO
# WARNING: Unable to resolve dimension of ('gwf6', 'disu', 'cell2d', 'cell2d', 'icvert') based on shape "ncvert".
# Running simulation for  PO  ...
# WARNING: 2024-07-17 16:37:50,917: geological_model.py:609 -- deprecated method. Model data can now be set using the data attribute
# Period =  Steady
# Model success =  True
# run_time =  11.989215
# {'upper': 0, 'upper_unconformity': 1, 'lower': 2}
# Creating lithology and discretisation arrays for  PO  ...
# C:\Users\19904604\Anaconda3\envs\loop3denvu\lib\site-packages\LoopStructural\modelling\core\geological_model.py:647: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = cm.get_cmap(cmap, n_units)
# Time taken =  1.886248
# Creating property arrays for  PO  ...
# Time taken =  0.010198
# Adding flow packages to  PO  ...
# Time taken =  0.620433
# Writing simulation and gwf for  PO  ...
# PO
# WARNING: Unable to resolve dimension of ('gwf6', 'disu', 'cell2d', 'cell2d', 'icvert') based on shape "ncvert".
# Running simulation for  PO  ...
# WARNING: 2024-07-17 16:38:04,512: geological_model.py:609 -- deprecated method. Model data can now be set using the data attribute
# Period =  Steady
# Model success =  True
# run_time =  11.052456
# {'upper': 0, 'upper_unconformity': 1, 'lower': 2}
# Creating lithology and discretisation arrays for  PO  ...
# C:\Users\19904604\Anaconda3\envs\loop3denvu\lib\site-packages\LoopStructural\modelling\core\geological_model.py:647: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = cm.get_cmap(cmap, n_units)
# Time taken =  1.670915
# Creating property arrays for  PO  ...
# Time taken =  0.010192
# Adding flow packages to  PO  ...
# Time taken =  0.549681
# Writing simulation and gwf for  PO  ...
# PO
# WARNING: Unable to resolve dimension of ('gwf6', 'disu', 'cell2d', 'cell2d', 'icvert') based on shape "ncvert".
# Running simulation for  PO  ...
# WARNING: 2024-07-17 16:38:18,180: geological_model.py:609 -- deprecated method. Model data can now be set using the data attribute
# Period =  Steady
# Model success =  True
# run_time =  11.400475
# {'upper': 0, 'upper_unconformity': 1, 'lower': 2}
# Creating lithology and discretisation arrays for  PO  ...
# C:\Users\19904604\Anaconda3\envs\loop3denvu\lib\site-packages\LoopStructural\modelling\core\geological_model.py:647: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = cm.get_cmap(cmap, n_units)
# Time taken =  1.613932
# Creating property arrays for  PO  ...
# Time taken =  0.008136
# Adding flow packages to  PO  ...
# Time taken =  0.58417
# Writing simulation and gwf for  PO  ...
# PO
# WARNING: Unable to resolve dimension of ('gwf6', 'disu', 'cell2d', 'cell2d', 'icvert') based on shape "ncvert".
# Running simulation for  PO  ...
# WARNING: 2024-07-17 16:38:31,250: geological_model.py:609 -- deprecated method. Model data can now be set using the data attribute
# Period =  Steady
# Model success =  True
# run_time =  10.846182
# {'upper': 0, 'upper_unconformity': 1, 'lower': 2}
# Creating lithology and discretisation arrays for  PO  ...
# C:\Users\19904604\Anaconda3\envs\loop3denvu\lib\site-packages\LoopStructural\modelling\core\geological_model.py:647: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = cm.get_cmap(cmap, n_units)
# Time taken =  1.651006
# Creating property arrays for  PO  ...
# Time taken =  0.010127
# Adding flow packages to  PO  ...
# Time taken =  0.530337
# Writing simulation and gwf for  PO  ...
# PO
# WARNING: Unable to resolve dimension of ('gwf6', 'disu', 'cell2d', 'cell2d', 'icvert') based on shape "ncvert".
# Running simulation for  PO  ...
# WARNING: 2024-07-17 16:38:45,507: geological_model.py:609 -- deprecated method. Model data can now be set using the data attribute
# Period =  Steady
# Model success =  True
# run_time =  12.02898
# {'upper': 0, 'upper_unconformity': 1, 'lower': 2}
# Creating lithology and discretisation arrays for  PO  ...
# C:\Users\19904604\Anaconda3\envs\loop3denvu\lib\site-packages\LoopStructural\modelling\core\geological_model.py:647: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = cm.get_cmap(cmap, n_units)
# Time taken =  1.774558
# Creating property arrays for  PO  ...
# Time taken =  0.010145
# Adding flow packages to  PO  ...
# Time taken =  0.590401
# Writing simulation and gwf for  PO  ...
# PO
# WARNING: Unable to resolve dimension of ('gwf6', 'disu', 'cell2d', 'cell2d', 'icvert') based on shape "ncvert".
# Running simulation for  PO  ...
# WARNING: 2024-07-17 16:38:59,447: geological_model.py:609 -- deprecated method. Model data can now be set using the data attribute
# Period =  Steady
# Model success =  True
# run_time =  11.515437
# {'upper': 0, 'upper_unconformity': 1, 'lower': 2}
# Creating lithology and discretisation arrays for  PO  ...
# C:\Users\19904604\Anaconda3\envs\loop3denvu\lib\site-packages\LoopStructural\modelling\core\geological_model.py:647: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = cm.get_cmap(cmap, n_units)
# Time taken =  1.738222
# Creating property arrays for  PO  ...
# Time taken =  0.008094
# Adding flow packages to  PO  ...
# Time taken =  0.534543
# Writing simulation and gwf for  PO  ...
# PO
# WARNING: Unable to resolve dimension of ('gwf6', 'disu', 'cell2d', 'cell2d', 'icvert') based on shape "ncvert".
# Running simulation for  PO  ...
# WARNING: 2024-07-17 16:39:12,101: geological_model.py:609 -- deprecated method. Model data can now be set using the data attribute
# Period =  Steady
# Model success =  True
# run_time =  10.363092
# {'upper': 0, 'upper_unconformity': 1, 'lower': 2}
# Creating lithology and discretisation arrays for  PO  ...
# C:\Users\19904604\Anaconda3\envs\loop3denvu\lib\site-packages\LoopStructural\modelling\core\geological_model.py:647: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = cm.get_cmap(cmap, n_units)
# Time taken =  1.496634
# Creating property arrays for  PO  ...
# Time taken =  0.010139
# Adding flow packages to  PO  ...
# Time taken =  0.539351
# Writing simulation and gwf for  PO  ...
# PO
# WARNING: Unable to resolve dimension of ('gwf6', 'disu', 'cell2d', 'cell2d', 'icvert') based on shape "ncvert".
# Running simulation for  PO  ...
# WARNING: 2024-07-17 16:39:24,806: geological_model.py:609 -- deprecated method. Model data can now be set using the data attribute
# Period =  Steady
# Model success =  True
# run_time =  10.61116
# {'upper': 0, 'upper_unconformity': 1, 'lower': 2}
# Creating lithology and discretisation arrays for  PO  ...
# C:\Users\19904604\Anaconda3\envs\loop3denvu\lib\site-packages\LoopStructural\modelling\core\geological_model.py:647: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = cm.get_cmap(cmap, n_units)
# Time taken =  1.628978
# Creating property arrays for  PO  ...
# Time taken =  0.008075
# Adding flow packages to  PO  ...
# Time taken =  0.696997
# Writing simulation and gwf for  PO  ...
# PO
# WARNING: Unable to resolve dimension of ('gwf6', 'disu', 'cell2d', 'cell2d', 'icvert') based on shape "ncvert".
# Running simulation for  PO  ...
# WARNING: 2024-07-17 16:39:39,087: geological_model.py:609 -- deprecated method. Model data can now be set using the data attribute
# Period =  Steady
# Model success =  True
# run_time =  11.912486
# {'upper': 0, 'upper_unconformity': 1, 'lower': 2}
# Creating lithology and discretisation arrays for  PO  ...
# C:\Users\19904604\Anaconda3\envs\loop3denvu\lib\site-packages\LoopStructural\modelling\core\geological_model.py:647: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = cm.get_cmap(cmap, n_units)
# Time taken =  1.674963
# Creating property arrays for  PO  ...
# Time taken =  0.0
# Adding flow packages to  PO  ...
# Time taken =  0.622181
# Writing simulation and gwf for  PO  ...
# PO
# WARNING: Unable to resolve dimension of ('gwf6', 'disu', 'cell2d', 'cell2d', 'icvert') based on shape "ncvert".
# Running simulation for  PO  ...
# WARNING: 2024-07-17 16:39:53,208: geological_model.py:609 -- deprecated method. Model data can now be set using the data attribute
# Period =  Steady
# Model success =  True
# run_time =  11.806306
# {'upper': 0, 'upper_unconformity': 1, 'lower': 2}
# Creating lithology and discretisation arrays for  PO  ...
# C:\Users\19904604\Anaconda3\envs\loop3denvu\lib\site-packages\LoopStructural\modelling\core\geological_model.py:647: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = cm.get_cmap(cmap, n_units)
# Time taken =  1.808393
# Creating property arrays for  PO  ...
# Time taken =  0.010219
# Adding flow packages to  PO  ...
# Time taken =  0.808144
# Writing simulation and gwf for  PO  ...
# PO
# WARNING: Unable to resolve dimension of ('gwf6', 'disu', 'cell2d', 'cell2d', 'icvert') based on shape "ncvert".
# Running simulation for  PO  ...
# WARNING: 2024-07-17 16:40:08,107: geological_model.py:609 -- deprecated method. Model data can now be set using the data attribute
# Period =  Steady
# Model success =  True
# run_time =  12.239112
# {'upper': 0, 'upper_unconformity': 1, 'lower': 2}
# Creating lithology and discretisation arrays for  PO  ...
# C:\Users\19904604\Anaconda3\envs\loop3denvu\lib\site-packages\LoopStructural\modelling\core\geological_model.py:647: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = cm.get_cmap(cmap, n_units)
# Time taken =  1.481273
# Creating property arrays for  PO  ...
# Time taken =  0.01024
# Adding flow packages to  PO  ...
# Time taken =  0.754592
# Writing simulation and gwf for  PO  ...
# PO
# WARNING: Unable to resolve dimension of ('gwf6', 'disu', 'cell2d', 'cell2d', 'icvert') based on shape "ncvert".
# Running simulation for  PO  ...
# WARNING: 2024-07-17 16:40:20,712: geological_model.py:609 -- deprecated method. Model data can now be set using the data attribute
# Period =  Steady
# Model success =  True
# run_time =  10.332822
# {'upper': 0, 'upper_unconformity': 1, 'lower': 2}
# Creating lithology and discretisation arrays for  PO  ...
# C:\Users\19904604\Anaconda3\envs\loop3denvu\lib\site-packages\LoopStructural\modelling\core\geological_model.py:647: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = cm.get_cmap(cmap, n_units)
# Time taken =  1.541841
# Creating property arrays for  PO  ...
# Time taken =  0.008099
# Adding flow packages to  PO  ...
# Time taken =  0.534448
# Writing simulation and gwf for  PO  ...
# PO
# WARNING: Unable to resolve dimension of ('gwf6', 'disu', 'cell2d', 'cell2d', 'icvert') based on shape "ncvert".
# Running simulation for  PO  ...
# WARNING: 2024-07-17 16:40:34,197: geological_model.py:609 -- deprecated method. Model data can now be set using the data attribute
# Period =  Steady
# Model success =  True
# run_time =  11.374841
# {'upper': 0, 'upper_unconformity': 1, 'lower': 2}
# Creating lithology and discretisation arrays for  PO  ...
# C:\Users\19904604\Anaconda3\envs\loop3denvu\lib\site-packages\LoopStructural\modelling\core\geological_model.py:647: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = cm.get_cmap(cmap, n_units)
# Time taken =  1.641259
# Creating property arrays for  PO  ...
# Time taken =  0.010179
# Adding flow packages to  PO  ...
# Time taken =  0.540214
# Writing simulation and gwf for  PO  ...
# PO
# WARNING: Unable to resolve dimension of ('gwf6', 'disu', 'cell2d', 'cell2d', 'icvert') based on shape "ncvert".
# Running simulation for  PO  ...
# WARNING: 2024-07-17 16:40:48,077: geological_model.py:609 -- deprecated method. Model data can now be set using the data attribute
# Period =  Steady
# Model success =  True
# run_time =  11.657437
# {'upper': 0, 'upper_unconformity': 1, 'lower': 2}
# Creating lithology and discretisation arrays for  PO  ...
# C:\Users\19904604\Anaconda3\envs\loop3denvu\lib\site-packages\LoopStructural\modelling\core\geological_model.py:647: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = cm.get_cmap(cmap, n_units)
# Time taken =  1.503144
# Creating property arrays for  PO  ...
# Time taken =  0.008141
# Adding flow packages to  PO  ...
# Time taken =  0.646904
# Writing simulation and gwf for  PO  ...
# PO
# WARNING: Unable to resolve dimension of ('gwf6', 'disu', 'cell2d', 'cell2d', 'icvert') based on shape "ncvert".
# Running simulation for  PO  ...
# WARNING: 2024-07-17 16:41:00,793: geological_model.py:609 -- deprecated method. Model data can now be set using the data attribute
# Period =  Steady
# Model success =  True
# run_time =  10.532224
# {'upper': 0, 'upper_unconformity': 1, 'lower': 2}
# Creating lithology and discretisation arrays for  PO  ...
# C:\Users\19904604\Anaconda3\envs\loop3denvu\lib\site-packages\LoopStructural\modelling\core\geological_model.py:647: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = cm.get_cmap(cmap, n_units)
# Time taken =  1.525468
# Creating property arrays for  PO  ...
# Time taken =  0.0
# Adding flow packages to  PO  ...
# Time taken =  0.539953
# Writing simulation and gwf for  PO  ...
# PO
# WARNING: Unable to resolve dimension of ('gwf6', 'disu', 'cell2d', 'cell2d', 'icvert') based on shape "ncvert".
# Running simulation for  PO  ...
# WARNING: 2024-07-17 16:41:12,957: geological_model.py:609 -- deprecated method. Model data can now be set using the data attribute
# Period =  Steady
# Model success =  True
# run_time =  10.064777
# {'upper': 0, 'upper_unconformity': 1, 'lower': 2}
# Creating lithology and discretisation arrays for  PO  ...
# C:\Users\19904604\Anaconda3\envs\loop3denvu\lib\site-packages\LoopStructural\modelling\core\geological_model.py:647: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = cm.get_cmap(cmap, n_units)
# Time taken =  1.717177
# Creating property arrays for  PO  ...
# Time taken =  0.00813
# Adding flow packages to  PO  ...
# Time taken =  0.534707
# Writing simulation and gwf for  PO  ...
# PO
# WARNING: Unable to resolve dimension of ('gwf6', 'disu', 'cell2d', 'cell2d', 'icvert') based on shape "ncvert".
# Running simulation for  PO  ...
# WARNING: 2024-07-17 16:41:25,643: geological_model.py:609 -- deprecated method. Model data can now be set using the data attribute
# Period =  Steady
# Model success =  True
# run_time =  10.399882
# {'upper': 0, 'upper_unconformity': 1, 'lower': 2}
# Creating lithology and discretisation arrays for  PO  ...
# C:\Users\19904604\Anaconda3\envs\loop3denvu\lib\site-packages\LoopStructural\modelling\core\geological_model.py:647: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = cm.get_cmap(cmap, n_units)
# Time taken =  1.886202
# Creating property arrays for  PO  ...
# Time taken =  0.008065
# Adding flow packages to  PO  ...
# Time taken =  0.530692
# Writing simulation and gwf for  PO  ...
# PO
# WARNING: Unable to resolve dimension of ('gwf6', 'disu', 'cell2d', 'cell2d', 'icvert') based on shape "ncvert".
# Running simulation for  PO  ...
# WARNING: 2024-07-17 16:41:38,836: geological_model.py:609 -- deprecated method. Model data can now be set using the data attribute
# Period =  Steady
# Model success =  True
# run_time =  10.722044
# {'upper': 0, 'upper_unconformity': 1, 'lower': 2}
# Creating lithology and discretisation arrays for  PO  ...
# C:\Users\19904604\Anaconda3\envs\loop3denvu\lib\site-packages\LoopStructural\modelling\core\geological_model.py:647: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = cm.get_cmap(cmap, n_units)
# Time taken =  1.655202
# Creating property arrays for  PO  ...
# Time taken =  0.01018
# Adding flow packages to  PO  ...
# Time taken =  0.530496
# Writing simulation and gwf for  PO  ...
# PO
# WARNING: Unable to resolve dimension of ('gwf6', 'disu', 'cell2d', 'cell2d', 'icvert') based on shape "ncvert".
# Running simulation for  PO  ...
# WARNING: 2024-07-17 16:41:51,323: geological_model.py:609 -- deprecated method. Model data can now be set using the data attribute
# Period =  Steady
# Model success =  True
# run_time =  10.281005
# {'upper': 0, 'upper_unconformity': 1, 'lower': 2}
# Creating lithology and discretisation arrays for  PO  ...
# C:\Users\19904604\Anaconda3\envs\loop3denvu\lib\site-packages\LoopStructural\modelling\core\geological_model.py:647: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = cm.get_cmap(cmap, n_units)
# Time taken =  1.532015
# Creating property arrays for  PO  ...
# Time taken =  0.010183
# Adding flow packages to  PO  ...
# Time taken =  0.540085
# Writing simulation and gwf for  PO  ...
# PO
# WARNING: Unable to resolve dimension of ('gwf6', 'disu', 'cell2d', 'cell2d', 'icvert') based on shape "ncvert".
# Running simulation for  PO  ...
# WARNING: 2024-07-17 16:42:03,133: geological_model.py:609 -- deprecated method. Model data can now be set using the data attribute
# Period =  Steady
# Model success =  True
# run_time =  9.685999
# {'upper': 0, 'upper_unconformity': 1, 'lower': 2}
# Creating lithology and discretisation arrays for  PO  ...
# C:\Users\19904604\Anaconda3\envs\loop3denvu\lib\site-packages\LoopStructural\modelling\core\geological_model.py:647: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = cm.get_cmap(cmap, n_units)
# Time taken =  1.745858
# Creating property arrays for  PO  ...
# Time taken =  0.008065
# Adding flow packages to  PO  ...
# Time taken =  0.54835
# Writing simulation and gwf for  PO  ...
# PO
# WARNING: Unable to resolve dimension of ('gwf6', 'disu', 'cell2d', 'cell2d', 'icvert') based on shape "ncvert".
# Running simulation for  PO  ...
# WARNING: 2024-07-17 16:42:15,231: geological_model.py:609 -- deprecated method. Model data can now be set using the data attribute
# Period =  Steady
# Model success =  True
# run_time =  9.759879
# {'upper': 0, 'upper_unconformity': 1, 'lower': 2}
# Creating lithology and discretisation arrays for  PO  ...
# C:\Users\19904604\Anaconda3\envs\loop3denvu\lib\site-packages\LoopStructural\modelling\core\geological_model.py:647: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = cm.get_cmap(cmap, n_units)
# Time taken =  1.536908
# Creating property arrays for  PO  ...
# Time taken =  0.010292
# Adding flow packages to  PO  ...
# Time taken =  0.563276
# Writing simulation and gwf for  PO  ...
# PO
# WARNING: Unable to resolve dimension of ('gwf6', 'disu', 'cell2d', 'cell2d', 'icvert') based on shape "ncvert".
# Running simulation for  PO  ...
# WARNING: 2024-07-17 16:42:28,163: geological_model.py:609 -- deprecated method. Model data can now be set using the data attribute
# Period =  Steady
# Model success =  True
# run_time =  10.795545
# {'upper': 0, 'upper_unconformity': 1, 'lower': 2}
# Creating lithology and discretisation arrays for  PO  ...
# C:\Users\19904604\Anaconda3\envs\loop3denvu\lib\site-packages\LoopStructural\modelling\core\geological_model.py:647: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = cm.get_cmap(cmap, n_units)
# Time taken =  1.545597
# Creating property arrays for  PO  ...
# Time taken =  0.01024
# Adding flow packages to  PO  ...
# Time taken =  0.669126
# Writing simulation and gwf for  PO  ...
# PO
# WARNING: Unable to resolve dimension of ('gwf6', 'disu', 'cell2d', 'cell2d', 'icvert') based on shape "ncvert".
# Running simulation for  PO  ...
# WARNING: 2024-07-17 16:42:40,604: geological_model.py:609 -- deprecated method. Model data can now be set using the data attribute
# Period =  Steady
# Model success =  True
# run_time =  10.190392
# {'upper': 0, 'upper_unconformity': 1, 'lower': 2}
# Creating lithology and discretisation arrays for  PO  ...
# C:\Users\19904604\Anaconda3\envs\loop3denvu\lib\site-packages\LoopStructural\modelling\core\geological_model.py:647: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = cm.get_cmap(cmap, n_units)
# Time taken =  1.670925
# Creating property arrays for  PO  ...
# Time taken =  0.002129
# Adding flow packages to  PO  ...
# Time taken =  0.560826
# Writing simulation and gwf for  PO  ...
# PO
# WARNING: Unable to resolve dimension of ('gwf6', 'disu', 'cell2d', 'cell2d', 'icvert') based on shape "ncvert".
# Running simulation for  PO  ...
# WARNING: 2024-07-17 16:42:53,569: geological_model.py:609 -- deprecated method. Model data can now be set using the data attribute
# Period =  Steady
# Model success =  True
# run_time =  10.705365
# {'upper': 0, 'upper_unconformity': 1, 'lower': 2}
# Creating lithology and discretisation arrays for  PO  ...
# C:\Users\19904604\Anaconda3\envs\loop3denvu\lib\site-packages\LoopStructural\modelling\core\geological_model.py:647: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = cm.get_cmap(cmap, n_units)
# Time taken =  1.629586
# Creating property arrays for  PO  ...
# Time taken =  0.008031
# Adding flow packages to  PO  ...
# Time taken =  0.581678
# Writing simulation and gwf for  PO  ...
# PO
# WARNING: Unable to resolve dimension of ('gwf6', 'disu', 'cell2d', 'cell2d', 'icvert') based on shape "ncvert".
# Running simulation for  PO  ...
# WARNING: 2024-07-17 16:43:06,174: geological_model.py:609 -- deprecated method. Model data can now be set using the data attribute
# Period =  Steady
# Model success =  True
# run_time =  10.360095
# ...
# WARNING: 2024-07-17 16:50:24,155: geological_model.py:609 -- deprecated method. Model data can now be set using the data attribute
# Period =  Steady
# Model success =  True
# run_time =  9.328842
# {'upper': 0, 'upper_unconformity': 1, 'lower': 2}
# Creating lithology and discretisation arrays for  PO  ...
# C:\Users\19904604\Anaconda3\envs\loop3denvu\lib\site-packages\LoopStructural\modelling\core\geological_model.py:647: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = cm.get_cmap(cmap, n_units)
# Time taken =  1.632922
# Creating property arrays for  PO  ...
# Time taken =  0.010177
# Adding flow packages to  PO  ...
# Time taken =  0.538191
# Writing simulation and gwf for  PO  ...
# PO
# WARNING: Unable to resolve dimension of ('gwf6', 'disu', 'cell2d', 'cell2d', 'icvert') based on shape "ncvert".
# Running simulation for  PO  ...
# WARNING: 2024-07-17 16:50:35,938: geological_model.py:609 -- deprecated method. Model data can now be set using the data attribute
# Period =  Steady
# Model success =  True
# run_time =  9.573346
# {'upper': 0, 'upper_unconformity': 1, 'lower': 2}
# Creating lithology and discretisation arrays for  PO  ...
# C:\Users\19904604\Anaconda3\envs\loop3denvu\lib\site-packages\LoopStructural\modelling\core\geological_model.py:647: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = cm.get_cmap(cmap, n_units)
# Time taken =  1.552878
# Creating property arrays for  PO  ...
# Time taken =  0.010208
# Adding flow packages to  PO  ...
# Time taken =  0.790156
# Writing simulation and gwf for  PO  ...
# PO
# WARNING: Unable to resolve dimension of ('gwf6', 'disu', 'cell2d', 'cell2d', 'icvert') based on shape "ncvert".
# Running simulation for  PO  ...
# WARNING: 2024-07-17 16:50:47,190: geological_model.py:609 -- deprecated method. Model data can now be set using the data attribute
# Period =  Steady
# Model success =  True
# run_time =  8.873126
# {'upper': 0, 'upper_unconformity': 1, 'lower': 2}
# Creating lithology and discretisation arrays for  PO  ...
# C:\Users\19904604\Anaconda3\envs\loop3denvu\lib\site-packages\LoopStructural\modelling\core\geological_model.py:647: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = cm.get_cmap(cmap, n_units)
# Time taken =  1.637544
# Creating property arrays for  PO  ...
# Time taken =  0.010178
# Adding flow packages to  PO  ...
# Time taken =  0.54793
# Writing simulation and gwf for  PO  ...
# PO
# WARNING: Unable to resolve dimension of ('gwf6', 'disu', 'cell2d', 'cell2d', 'icvert') based on shape "ncvert".
# Running simulation for  PO  ...
# WARNING: 2024-07-17 16:50:59,878: geological_model.py:609 -- deprecated method. Model data can now be set using the data attribute
# Period =  Steady
# Model success =  True
# run_time =  10.460125
# {'upper': 0, 'upper_unconformity': 1, 'lower': 2}
# Creating lithology and discretisation arrays for  PO  ...
# C:\Users\19904604\Anaconda3\envs\loop3denvu\lib\site-packages\LoopStructural\modelling\core\geological_model.py:647: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = cm.get_cmap(cmap, n_units)
# Time taken =  1.804384
# Creating property arrays for  PO  ...
# Time taken =  0.008026
# Adding flow packages to  PO  ...
# Time taken =  0.776488
# Writing simulation and gwf for  PO  ...
# PO
# WARNING: Unable to resolve dimension of ('gwf6', 'disu', 'cell2d', 'cell2d', 'icvert') based on shape "ncvert".
# Running simulation for  PO  ...
# WARNING: 2024-07-17 16:51:11,482: geological_model.py:609 -- deprecated method. Model data can now be set using the data attribute
# Period =  Steady
# Model success =  True
# run_time =  8.992778
# {'upper': 0, 'upper_unconformity': 1, 'lower': 2}
# Creating lithology and discretisation arrays for  PO  ...
# C:\Users\19904604\Anaconda3\envs\loop3denvu\lib\site-packages\LoopStructural\modelling\core\geological_model.py:647: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = cm.get_cmap(cmap, n_units)
# Time taken =  1.654253
# Creating property arrays for  PO  ...
# Time taken =  0.008086
# Adding flow packages to  PO  ...
# Time taken =  0.613187
# Writing simulation and gwf for  PO  ...
# PO
# WARNING: Unable to resolve dimension of ('gwf6', 'disu', 'cell2d', 'cell2d', 'icvert') based on shape "ncvert".
# Running simulation for  PO  ...
# WARNING: 2024-07-17 16:51:22,564: geological_model.py:609 -- deprecated method. Model data can now be set using the data attribute
# Period =  Steady
# Model success =  True
# run_time =  8.778348
# {'upper': 0, 'upper_unconformity': 1, 'lower': 2}
# Creating lithology and discretisation arrays for  PO  ...
# C:\Users\19904604\Anaconda3\envs\loop3denvu\lib\site-packages\LoopStructural\modelling\core\geological_model.py:647: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = cm.get_cmap(cmap, n_units)
# Time taken =  1.653395
# Creating property arrays for  PO  ...
# Time taken =  0.002063
# Adding flow packages to  PO  ...
# Time taken =  0.541175
# Writing simulation and gwf for  PO  ...
# PO
# WARNING: Unable to resolve dimension of ('gwf6', 'disu', 'cell2d', 'cell2d', 'icvert') based on shape "ncvert".
# Running simulation for  PO  ...
# WARNING: 2024-07-17 16:51:33,726: geological_model.py:609 -- deprecated method. Model data can now be set using the data attribute
# Period =  Steady
# Model success =  True
# run_time =  8.94724
# {'upper': 0, 'upper_unconformity': 1, 'lower': 2}
# Creating lithology and discretisation arrays for  PO  ...
# C:\Users\19904604\Anaconda3\envs\loop3denvu\lib\site-packages\LoopStructural\modelling\core\geological_model.py:647: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = cm.get_cmap(cmap, n_units)
# Time taken =  1.844684
# Creating property arrays for  PO  ...
# Time taken =  0.008087
# Adding flow packages to  PO  ...
# Time taken =  0.594242
# Writing simulation and gwf for  PO  ...
# PO
# WARNING: Unable to resolve dimension of ('gwf6', 'disu', 'cell2d', 'cell2d', 'icvert') based on shape "ncvert".
# Running simulation for  PO  ...
# WARNING: 2024-07-17 16:51:45,147: geological_model.py:609 -- deprecated method. Model data can now be set using the data attribute
# Period =  Steady
# Model success =  True
# run_time =  8.940378
# {'upper': 0, 'upper_unconformity': 1, 'lower': 2}
# Creating lithology and discretisation arrays for  PO  ...
# C:\Users\19904604\Anaconda3\envs\loop3denvu\lib\site-packages\LoopStructural\modelling\core\geological_model.py:647: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = cm.get_cmap(cmap, n_units)
# Time taken =  1.818963
# Creating property arrays for  PO  ...
# Time taken =  0.002137
# Adding flow packages to  PO  ...
# Time taken =  0.587339
# Writing simulation and gwf for  PO  ...
# PO
# WARNING: Unable to resolve dimension of ('gwf6', 'disu', 'cell2d', 'cell2d', 'icvert') based on shape "ncvert".
# Running simulation for  PO  ...
# WARNING: 2024-07-17 16:51:56,767: geological_model.py:609 -- deprecated method. Model data can now be set using the data attribute
# Period =  Steady
# Model success =  True
# run_time =  9.19061
# {'upper': 0, 'upper_unconformity': 1, 'lower': 2}
# Creating lithology and discretisation arrays for  PO  ...
# C:\Users\19904604\Anaconda3\envs\loop3denvu\lib\site-packages\LoopStructural\modelling\core\geological_model.py:647: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = cm.get_cmap(cmap, n_units)
# Time taken =  1.657565
# Creating property arrays for  PO  ...
# Time taken =  0.01015
# Adding flow packages to  PO  ...
# Time taken =  0.562095
# Writing simulation and gwf for  PO  ...
# PO
# WARNING: Unable to resolve dimension of ('gwf6', 'disu', 'cell2d', 'cell2d', 'icvert') based on shape "ncvert".
# Running simulation for  PO  ...
# WARNING: 2024-07-17 16:52:07,909: geological_model.py:609 -- deprecated method. Model data can now be set using the data attribute
# Period =  Steady
# Model success =  True
# run_time =  8.87621
# {'upper': 0, 'upper_unconformity': 1, 'lower': 2}
# Creating lithology and discretisation arrays for  PO  ...
# C:\Users\19904604\Anaconda3\envs\loop3denvu\lib\site-packages\LoopStructural\modelling\core\geological_model.py:647: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = cm.get_cmap(cmap, n_units)
# Time taken =  1.61361
# Creating property arrays for  PO  ...
# Time taken =  0.00213
# Adding flow packages to  PO  ...
# Time taken =  0.67311
# Writing simulation and gwf for  PO  ...
# PO
# WARNING: Unable to resolve dimension of ('gwf6', 'disu', 'cell2d', 'cell2d', 'icvert') based on shape "ncvert".
# Running simulation for  PO  ...
# WARNING: 2024-07-17 16:52:19,920: geological_model.py:609 -- deprecated method. Model data can now be set using the data attribute
# Period =  Steady
# Model success =  True
# run_time =  9.697016
# {'upper': 0, 'upper_unconformity': 1, 'lower': 2}
# Creating lithology and discretisation arrays for  PO  ...
# C:\Users\19904604\Anaconda3\envs\loop3denvu\lib\site-packages\LoopStructural\modelling\core\geological_model.py:647: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = cm.get_cmap(cmap, n_units)
# Time taken =  1.861669
# Creating property arrays for  PO  ...
# Time taken =  0.0
# Adding flow packages to  PO  ...
# Time taken =  0.612659
# Writing simulation and gwf for  PO  ...
# PO
# WARNING: Unable to resolve dimension of ('gwf6', 'disu', 'cell2d', 'cell2d', 'icvert') based on shape "ncvert".
# Running simulation for  PO  ...
# WARNING: 2024-07-17 16:52:31,586: geological_model.py:609 -- deprecated method. Model data can now be set using the data attribute
# Period =  Steady
# Model success =  True
# run_time =  9.165623
# {'upper': 0, 'upper_unconformity': 1, 'lower': 2}
# Creating lithology and discretisation arrays for  PO  ...
# C:\Users\19904604\Anaconda3\envs\loop3denvu\lib\site-packages\LoopStructural\modelling\core\geological_model.py:647: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = cm.get_cmap(cmap, n_units)
# Time taken =  1.763548
# Creating property arrays for  PO  ...
# Time taken =  0.010087
# Adding flow packages to  PO  ...
# Time taken =  0.613972
# Writing simulation and gwf for  PO  ...
# PO
# WARNING: Unable to resolve dimension of ('gwf6', 'disu', 'cell2d', 'cell2d', 'icvert') based on shape "ncvert".
# Running simulation for  PO  ...
# WARNING: 2024-07-17 16:52:43,022: geological_model.py:609 -- deprecated method. Model data can now be set using the data attribute
# Period =  Steady
# Model success =  True
# run_time =  9.020892
# {'upper': 0, 'upper_unconformity': 1, 'lower': 2}
# Creating lithology and discretisation arrays for  PO  ...
# C:\Users\19904604\Anaconda3\envs\loop3denvu\lib\site-packages\LoopStructural\modelling\core\geological_model.py:647: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = cm.get_cmap(cmap, n_units)
# Time taken =  1.764666
# Creating property arrays for  PO  ...
# Time taken =  0.0
# Adding flow packages to  PO  ...
# Time taken =  0.67399
# Writing simulation and gwf for  PO  ...
# PO
# WARNING: Unable to resolve dimension of ('gwf6', 'disu', 'cell2d', 'cell2d', 'icvert') based on shape "ncvert".
# Running simulation for  PO  ...
# WARNING: 2024-07-17 16:52:54,634: geological_model.py:609 -- deprecated method. Model data can now be set using the data attribute
# Period =  Steady
# Model success =  True
# run_time =  9.142915
# {'upper': 0, 'upper_unconformity': 1, 'lower': 2}
# Creating lithology and discretisation arrays for  PO  ...
# C:\Users\19904604\Anaconda3\envs\loop3denvu\lib\site-packages\LoopStructural\modelling\core\geological_model.py:647: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = cm.get_cmap(cmap, n_units)
# Time taken =  1.690054
# Creating property arrays for  PO  ...
# Time taken =  0.002064
# Adding flow packages to  PO  ...
# Time taken =  0.580104
# Writing simulation and gwf for  PO  ...
# PO
# WARNING: Unable to resolve dimension of ('gwf6', 'disu', 'cell2d', 'cell2d', 'icvert') based on shape "ncvert".
# Running simulation for  PO  ...
# WARNING: 2024-07-17 16:53:05,556: geological_model.py:609 -- deprecated method. Model data can now be set using the data attribute
# Period =  Steady
# Model success =  True
# run_time =  8.62358
# {'upper': 0, 'upper_unconformity': 1, 'lower': 2}
# Creating lithology and discretisation arrays for  PO  ...
# C:\Users\19904604\Anaconda3\envs\loop3denvu\lib\site-packages\LoopStructural\modelling\core\geological_model.py:647: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = cm.get_cmap(cmap, n_units)
# Time taken =  1.58104
# Creating property arrays for  PO  ...
# Time taken =  0.002079
# Adding flow packages to  PO  ...
# Time taken =  0.582211
# Writing simulation and gwf for  PO  ...
# PO
# WARNING: Unable to resolve dimension of ('gwf6', 'disu', 'cell2d', 'cell2d', 'icvert') based on shape "ncvert".
# Running simulation for  PO  ...
# WARNING: 2024-07-17 16:53:16,594: geological_model.py:609 -- deprecated method. Model data can now be set using the data attribute
# Period =  Steady
# Model success =  True
# run_time =  8.836901
# {'upper': 0, 'upper_unconformity': 1, 'lower': 2}
# Creating lithology and discretisation arrays for  PO  ...
# C:\Users\19904604\Anaconda3\envs\loop3denvu\lib\site-packages\LoopStructural\modelling\core\geological_model.py:647: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = cm.get_cmap(cmap, n_units)
# Time taken =  1.754771
# Creating property arrays for  PO  ...
# Time taken =  0.00214
# Adding flow packages to  PO  ...
# Time taken =  0.682825
# Writing simulation and gwf for  PO  ...
# PO
# WARNING: Unable to resolve dimension of ('gwf6', 'disu', 'cell2d', 'cell2d', 'icvert') based on shape "ncvert".
# Running simulation for  PO  ...
# Period =  Steady
# Model success =  True
# run_time =  8.462233

# %%
layer = 2

stacked = []
for n in range(100):
    heads_disv = -1e30 * np.ones_like(M.idomain, dtype=float) 
    for i, h in enumerate(heads_PO[n][0][0]):
        if math.isnan(h) == False: 
            heads_disv[M.cellid_disu==i] = h        
    stacked.append(heads_disv[layer])
var_PO = np.var(np.array(stacked), axis = 0)

# %% [markdown]
# ### Fault - 100 realisations

# %%
P.cell2dvor, P.xcycvor, P.verticesvor, P.vor, vornodes = createcell2d(P, grid = 'vor', fault = True)  
P.hk = [1, 2, 0.01, 5] 
P.vk = [i/10 for i in P.hk]

options = np.linspace(0, 320, 100) # Fault displacement

data = pd.read_excel("../data/loop_showcase_data.xls",sheet_name = "fault_example")
strat = pd.read_excel("../data/loop_showcase_data.xls",sheet_name = "strat")

P.control_points = ([])
P.fault_max_disp = 100.    # Was 200
P.minor_axis = 1000        # Fault_influence - orthogonal to fault
P.fault_center = [P.fx1 + (P.fx2 - P.fx1)/2, P.fy1 + (P.fy2 - P.fy1)/2, -400]
P.fault_slip_vector=[0,0,1]
        
heads_FD = []
for i in range(len(options)):

    N = Model('FD', P, plan = 'vor', transect = 'con') # Create flow model  
    P.fault_max_disp = options[i] /2
    P.data, P.strat = prepare_geomodel_loopshowcase(P, data, strat, include_fault = True)   # Prepare geomodel inputs
    P.geomodel = create_geomodel_loopshowcase(P, include_fault = True) # Make geomodel
    N.create_lith_dis_arrays(P)                                 # Create lith and dis arrays
    N.create_prop_arrays(P)                                     # Create K arrays
    N.create_flow_package_arrays(P)                             # Create flow packages
    N.gwf, N.head_ss, N.obs_ss, N.runtime_ss = N.write_run_model(P, period = 'Steady', ic_array = P.strt)   
    heads_FD.append(N.head_ss)
# Out:
# WARNING: 2024-07-18 09:51:49,346: geological_model.py:609 -- deprecated method. Model data can now be set using the data attribute
# WARNING: 2024-07-18 09:51:49,362: geological_model.py:1359 -- Fault displacement is 0
# WARNING: 2024-07-18 09:51:49,369: _fault_builder.py:208 -- There is no slip vector data for the fault, using vertical slip vector
#                           projected onto fault surface estimating from fault normal
# WARNING: 2024-07-18 09:51:49,385: _fault_builder.py:239 -- Fault major axis using map length: 3640.0549446402592
# C:\Users\19904604\Anaconda3\envs\loop3denvu\lib\site-packages\LoopStructural\modelling\core\geological_model.py:647: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = cm.get_cmap(cmap, n_units)
# Fault included!
# {'upper': 0, 'upper_unconformity': 1, 'Fault': 2, 'lower': 3}
# Creating lithology and discretisation arrays for  FD  ...
# Time taken =  1.888385
# Creating property arrays for  FD  ...
# Time taken =  0.0101
# Adding flow packages to  FD  ...
# Time taken =  0.637007
# Writing simulation and gwf for  FD  ...
# FD
# WARNING: Unable to resolve dimension of ('gwf6', 'disu', 'cell2d', 'cell2d', 'icvert') based on shape "ncvert".
# Running simulation for  FD  ...
# WARNING: 2024-07-18 09:52:05,298: geological_model.py:609 -- deprecated method. Model data can now be set using the data attribute
# WARNING: 2024-07-18 09:52:05,331: _fault_builder.py:208 -- There is no slip vector data for the fault, using vertical slip vector
#                           projected onto fault surface estimating from fault normal
# WARNING: 2024-07-18 09:52:05,338: _fault_builder.py:239 -- Fault major axis using map length: 3640.0549446402592
# Period =  Steady
# Model success =  True
# run_time =  13.289452
# Fault included!
# {'upper': 0, 'upper_unconformity': 1, 'Fault': 2, 'lower': 3}
# Creating lithology and discretisation arrays for  FD  ...
# C:\Users\19904604\Anaconda3\envs\loop3denvu\lib\site-packages\LoopStructural\modelling\core\geological_model.py:647: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = cm.get_cmap(cmap, n_units)
# Time taken =  18.53884
# Creating property arrays for  FD  ...
# Time taken =  0.010656
# Adding flow packages to  FD  ...
# Time taken =  0.721457
# Writing simulation and gwf for  FD  ...
# FD
# WARNING: Unable to resolve dimension of ('gwf6', 'disu', 'cell2d', 'cell2d', 'icvert') based on shape "ncvert".
# Running simulation for  FD  ...
# WARNING: 2024-07-18 09:52:39,381: geological_model.py:609 -- deprecated method. Model data can now be set using the data attribute
# WARNING: 2024-07-18 09:52:39,401: _fault_builder.py:208 -- There is no slip vector data for the fault, using vertical slip vector
#                           projected onto fault surface estimating from fault normal
# WARNING: 2024-07-18 09:52:39,401: _fault_builder.py:239 -- Fault major axis using map length: 3640.0549446402592
# Period =  Steady
# Model success =  True
# run_time =  14.669877
# Fault included!
# {'upper': 0, 'upper_unconformity': 1, 'Fault': 2, 'lower': 3}
# Creating lithology and discretisation arrays for  FD  ...
# C:\Users\19904604\Anaconda3\envs\loop3denvu\lib\site-packages\LoopStructural\modelling\core\geological_model.py:647: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = cm.get_cmap(cmap, n_units)
# Time taken =  18.309822
# Creating property arrays for  FD  ...
# Time taken =  0.008082
# Adding flow packages to  FD  ...
# Time taken =  0.677337
# Writing simulation and gwf for  FD  ...
# FD
# WARNING: Unable to resolve dimension of ('gwf6', 'disu', 'cell2d', 'cell2d', 'icvert') based on shape "ncvert".
# Running simulation for  FD  ...
# WARNING: 2024-07-18 09:53:12,692: geological_model.py:609 -- deprecated method. Model data can now be set using the data attribute
# WARNING: 2024-07-18 09:53:12,723: _fault_builder.py:208 -- There is no slip vector data for the fault, using vertical slip vector
#                           projected onto fault surface estimating from fault normal
# WARNING: 2024-07-18 09:53:12,730: _fault_builder.py:239 -- Fault major axis using map length: 3640.0549446402592
# Period =  Steady
# Model success =  True
# run_time =  14.190273
# Fault included!
# {'upper': 0, 'upper_unconformity': 1, 'Fault': 2, 'lower': 3}
# Creating lithology and discretisation arrays for  FD  ...
# C:\Users\19904604\Anaconda3\envs\loop3denvu\lib\site-packages\LoopStructural\modelling\core\geological_model.py:647: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = cm.get_cmap(cmap, n_units)
# Time taken =  18.932979
# Creating property arrays for  FD  ...
# Time taken =  0.01023
# Adding flow packages to  FD  ...
# Time taken =  0.796242
# Writing simulation and gwf for  FD  ...
# FD
# WARNING: Unable to resolve dimension of ('gwf6', 'disu', 'cell2d', 'cell2d', 'icvert') based on shape "ncvert".
# Running simulation for  FD  ...
# WARNING: 2024-07-18 09:53:46,980: geological_model.py:609 -- deprecated method. Model data can now be set using the data attribute
# WARNING: 2024-07-18 09:53:47,011: _fault_builder.py:208 -- There is no slip vector data for the fault, using vertical slip vector
#                           projected onto fault surface estimating from fault normal
# WARNING: 2024-07-18 09:53:47,011: _fault_builder.py:239 -- Fault major axis using map length: 3640.0549446402592
# Period =  Steady
# Model success =  True
# run_time =  14.422606
# Fault included!
# {'upper': 0, 'upper_unconformity': 1, 'Fault': 2, 'lower': 3}
# Creating lithology and discretisation arrays for  FD  ...
# C:\Users\19904604\Anaconda3\envs\loop3denvu\lib\site-packages\LoopStructural\modelling\core\geological_model.py:647: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = cm.get_cmap(cmap, n_units)
# Time taken =  19.37107
# Creating property arrays for  FD  ...
# Time taken =  0.01013
# Adding flow packages to  FD  ...
# Time taken =  0.684189
# Writing simulation and gwf for  FD  ...
# FD
# WARNING: Unable to resolve dimension of ('gwf6', 'disu', 'cell2d', 'cell2d', 'icvert') based on shape "ncvert".
# Running simulation for  FD  ...
# WARNING: 2024-07-18 09:54:21,491: geological_model.py:609 -- deprecated method. Model data can now be set using the data attribute
# WARNING: 2024-07-18 09:54:21,514: _fault_builder.py:208 -- There is no slip vector data for the fault, using vertical slip vector
#                           projected onto fault surface estimating from fault normal
# WARNING: 2024-07-18 09:54:21,514: _fault_builder.py:239 -- Fault major axis using map length: 3640.0549446402592
# Period =  Steady
# Model success =  True
# run_time =  14.310489
# Fault included!
# {'upper': 0, 'upper_unconformity': 1, 'Fault': 2, 'lower': 3}
# Creating lithology and discretisation arrays for  FD  ...
# C:\Users\19904604\Anaconda3\envs\loop3denvu\lib\site-packages\LoopStructural\modelling\core\geological_model.py:647: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = cm.get_cmap(cmap, n_units)
# Time taken =  18.948355
# Creating property arrays for  FD  ...
# Time taken =  0.010162
# Adding flow packages to  FD  ...
# Time taken =  0.727327
# Writing simulation and gwf for  FD  ...
# FD
# WARNING: Unable to resolve dimension of ('gwf6', 'disu', 'cell2d', 'cell2d', 'icvert') based on shape "ncvert".
# Running simulation for  FD  ...
# WARNING: 2024-07-18 09:54:57,447: geological_model.py:609 -- deprecated method. Model data can now be set using the data attribute
# WARNING: 2024-07-18 09:54:57,469: _fault_builder.py:208 -- There is no slip vector data for the fault, using vertical slip vector
#                           projected onto fault surface estimating from fault normal
# WARNING: 2024-07-18 09:54:57,485: _fault_builder.py:239 -- Fault major axis using map length: 3640.0549446402592
# Period =  Steady
# Model success =  True
# run_time =  16.130582
# Fault included!
# {'upper': 0, 'upper_unconformity': 1, 'Fault': 2, 'lower': 3}
# Creating lithology and discretisation arrays for  FD  ...
# C:\Users\19904604\Anaconda3\envs\loop3denvu\lib\site-packages\LoopStructural\modelling\core\geological_model.py:647: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = cm.get_cmap(cmap, n_units)
# Time taken =  19.686358
# Creating property arrays for  FD  ...
# Time taken =  0.006511
# Adding flow packages to  FD  ...
# Time taken =  0.777339
# Writing simulation and gwf for  FD  ...
# FD
# WARNING: Unable to resolve dimension of ('gwf6', 'disu', 'cell2d', 'cell2d', 'icvert') based on shape "ncvert".
# Running simulation for  FD  ...
# WARNING: 2024-07-18 09:55:32,794: geological_model.py:609 -- deprecated method. Model data can now be set using the data attribute
# WARNING: 2024-07-18 09:55:32,826: _fault_builder.py:208 -- There is no slip vector data for the fault, using vertical slip vector
#                           projected onto fault surface estimating from fault normal
# WARNING: 2024-07-18 09:55:32,832: _fault_builder.py:239 -- Fault major axis using map length: 3640.0549446402592
# Period =  Steady
# Model success =  True
# run_time =  14.735096
# Fault included!
# {'upper': 0, 'upper_unconformity': 1, 'Fault': 2, 'lower': 3}
# Creating lithology and discretisation arrays for  FD  ...
# C:\Users\19904604\Anaconda3\envs\loop3denvu\lib\site-packages\LoopStructural\modelling\core\geological_model.py:647: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = cm.get_cmap(cmap, n_units)
# Time taken =  19.576062
# Creating property arrays for  FD  ...
# Time taken =  0.010243
# Adding flow packages to  FD  ...
# Time taken =  0.684853
# Writing simulation and gwf for  FD  ...
# FD
# WARNING: Unable to resolve dimension of ('gwf6', 'disu', 'cell2d', 'cell2d', 'icvert') based on shape "ncvert".
# Running simulation for  FD  ...
# WARNING: 2024-07-18 09:56:08,479: geological_model.py:609 -- deprecated method. Model data can now be set using the data attribute
# WARNING: 2024-07-18 09:56:08,500: _fault_builder.py:208 -- There is no slip vector data for the fault, using vertical slip vector
#                           projected onto fault surface estimating from fault normal
# WARNING: 2024-07-18 09:56:08,510: _fault_builder.py:239 -- Fault major axis using map length: 3640.0549446402592
# Period =  Steady
# Model success =  True
# run_time =  15.278468
# Fault included!
# {'upper': 0, 'upper_unconformity': 1, 'Fault': 2, 'lower': 3}
# Creating lithology and discretisation arrays for  FD  ...
# C:\Users\19904604\Anaconda3\envs\loop3denvu\lib\site-packages\LoopStructural\modelling\core\geological_model.py:647: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = cm.get_cmap(cmap, n_units)
# Time taken =  19.024069
# Creating property arrays for  FD  ...
# Time taken =  0.010183
# Adding flow packages to  FD  ...
# Time taken =  0.69317
# Writing simulation and gwf for  FD  ...
# FD
# WARNING: Unable to resolve dimension of ('gwf6', 'disu', 'cell2d', 'cell2d', 'icvert') based on shape "ncvert".
# Running simulation for  FD  ...
# WARNING: 2024-07-18 09:56:44,244: geological_model.py:609 -- deprecated method. Model data can now be set using the data attribute
# WARNING: 2024-07-18 09:56:44,267: _fault_builder.py:208 -- There is no slip vector data for the fault, using vertical slip vector
#                           projected onto fault surface estimating from fault normal
# WARNING: 2024-07-18 09:56:44,282: _fault_builder.py:239 -- Fault major axis using map length: 3640.0549446402592
# Period =  Steady
# Model success =  True
# run_time =  15.898628
# Fault included!
# {'upper': 0, 'upper_unconformity': 1, 'Fault': 2, 'lower': 3}
# Creating lithology and discretisation arrays for  FD  ...
# C:\Users\19904604\Anaconda3\envs\loop3denvu\lib\site-packages\LoopStructural\modelling\core\geological_model.py:647: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = cm.get_cmap(cmap, n_units)
# Time taken =  19.038791
# Creating property arrays for  FD  ...
# Time taken =  0.010156
# Adding flow packages to  FD  ...
# Time taken =  1.04825
# Writing simulation and gwf for  FD  ...
# FD
# WARNING: Unable to resolve dimension of ('gwf6', 'disu', 'cell2d', 'cell2d', 'icvert') based on shape "ncvert".
# Running simulation for  FD  ...
# WARNING: 2024-07-18 09:57:20,553: geological_model.py:609 -- deprecated method. Model data can now be set using the data attribute
# WARNING: 2024-07-18 09:57:20,590: _fault_builder.py:208 -- There is no slip vector data for the fault, using vertical slip vector
#                           projected onto fault surface estimating from fault normal
# WARNING: 2024-07-18 09:57:20,590: _fault_builder.py:239 -- Fault major axis using map length: 3640.0549446402592
# Period =  Steady
# Model success =  True
# run_time =  16.079386
# Fault included!
# {'upper': 0, 'upper_unconformity': 1, 'Fault': 2, 'lower': 3}
# Creating lithology and discretisation arrays for  FD  ...
# C:\Users\19904604\Anaconda3\envs\loop3denvu\lib\site-packages\LoopStructural\modelling\core\geological_model.py:647: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = cm.get_cmap(cmap, n_units)
# Time taken =  19.267981
# Creating property arrays for  FD  ...
# Time taken =  0.010214
# Adding flow packages to  FD  ...
# Time taken =  0.723269
# Writing simulation and gwf for  FD  ...
# FD
# WARNING: Unable to resolve dimension of ('gwf6', 'disu', 'cell2d', 'cell2d', 'icvert') based on shape "ncvert".
# Running simulation for  FD  ...
# WARNING: 2024-07-18 09:57:56,826: geological_model.py:609 -- deprecated method. Model data can now be set using the data attribute
# WARNING: 2024-07-18 09:57:56,848: _fault_builder.py:208 -- There is no slip vector data for the fault, using vertical slip vector
#                           projected onto fault surface estimating from fault normal
# WARNING: 2024-07-18 09:57:56,864: _fault_builder.py:239 -- Fault major axis using map length: 3640.0549446402592
# Period =  Steady
# Model success =  True
# run_time =  16.114755
# Fault included!
# {'upper': 0, 'upper_unconformity': 1, 'Fault': 2, 'lower': 3}
# Creating lithology and discretisation arrays for  FD  ...
# C:\Users\19904604\Anaconda3\envs\loop3denvu\lib\site-packages\LoopStructural\modelling\core\geological_model.py:647: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = cm.get_cmap(cmap, n_units)
# Time taken =  19.631748
# Creating property arrays for  FD  ...
# Time taken =  0.010259
# Adding flow packages to  FD  ...
# Time taken =  0.744716
# Writing simulation and gwf for  FD  ...
# FD
# WARNING: Unable to resolve dimension of ('gwf6', 'disu', 'cell2d', 'cell2d', 'icvert') based on shape "ncvert".
# Running simulation for  FD  ...
# WARNING: 2024-07-18 09:58:32,823: geological_model.py:609 -- deprecated method. Model data can now be set using the data attribute
# WARNING: 2024-07-18 09:58:32,851: _fault_builder.py:208 -- There is no slip vector data for the fault, using vertical slip vector
#                           projected onto fault surface estimating from fault normal
# WARNING: 2024-07-18 09:58:32,853: _fault_builder.py:239 -- Fault major axis using map length: 3640.0549446402592
# Period =  Steady
# Model success =  True
# run_time =  15.482811
# Fault included!
# {'upper': 0, 'upper_unconformity': 1, 'Fault': 2, 'lower': 3}
# Creating lithology and discretisation arrays for  FD  ...
# C:\Users\19904604\Anaconda3\envs\loop3denvu\lib\site-packages\LoopStructural\modelling\core\geological_model.py:647: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = cm.get_cmap(cmap, n_units)
# Time taken =  18.810147
# Creating property arrays for  FD  ...
# Time taken =  0.002141
# Adding flow packages to  FD  ...
# Time taken =  0.699616
# Writing simulation and gwf for  FD  ...
# FD
# WARNING: Unable to resolve dimension of ('gwf6', 'disu', 'cell2d', 'cell2d', 'icvert') based on shape "ncvert".
# Running simulation for  FD  ...
# WARNING: 2024-07-18 09:59:09,270: geological_model.py:609 -- deprecated method. Model data can now be set using the data attribute
# WARNING: 2024-07-18 09:59:09,301: _fault_builder.py:208 -- There is no slip vector data for the fault, using vertical slip vector
#                           projected onto fault surface estimating from fault normal
# WARNING: 2024-07-18 09:59:09,301: _fault_builder.py:239 -- Fault major axis using map length: 3640.0549446402592
# Period =  Steady
# Model success =  True
# run_time =  16.762994
# Fault included!
# {'upper': 0, 'upper_unconformity': 1, 'Fault': 2, 'lower': 3}
# Creating lithology and discretisation arrays for  FD  ...
# C:\Users\19904604\Anaconda3\envs\loop3denvu\lib\site-packages\LoopStructural\modelling\core\geological_model.py:647: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = cm.get_cmap(cmap, n_units)
# Time taken =  19.062761
# Creating property arrays for  FD  ...
# Time taken =  0.010217
# Adding flow packages to  FD  ...
# Time taken =  0.741818
# Writing simulation and gwf for  FD  ...
# FD
# WARNING: Unable to resolve dimension of ('gwf6', 'disu', 'cell2d', 'cell2d', 'icvert') based on shape "ncvert".
# Running simulation for  FD  ...
# WARNING: 2024-07-18 09:59:44,786: geological_model.py:609 -- deprecated method. Model data can now be set using the data attribute
# WARNING: 2024-07-18 09:59:44,817: _fault_builder.py:208 -- There is no slip vector data for the fault, using vertical slip vector
#                           projected onto fault surface estimating from fault normal
# WARNING: 2024-07-18 09:59:44,817: _fault_builder.py:239 -- Fault major axis using map length: 3640.0549446402592
# Period =  Steady
# Model success =  True
# run_time =  15.569682
# Fault included!
# {'upper': 0, 'upper_unconformity': 1, 'Fault': 2, 'lower': 3}
# Creating lithology and discretisation arrays for  FD  ...
# C:\Users\19904604\Anaconda3\envs\loop3denvu\lib\site-packages\LoopStructural\modelling\core\geological_model.py:647: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = cm.get_cmap(cmap, n_units)
# Time taken =  21.31694
# Creating property arrays for  FD  ...
# Time taken =  0.015591
# Adding flow packages to  FD  ...
# Time taken =  0.928303
# Writing simulation and gwf for  FD  ...
# FD
# WARNING: Unable to resolve dimension of ('gwf6', 'disu', 'cell2d', 'cell2d', 'icvert') based on shape "ncvert".
# Running simulation for  FD  ...
# WARNING: 2024-07-18 10:00:24,598: geological_model.py:609 -- deprecated method. Model data can now be set using the data attribute
# WARNING: 2024-07-18 10:00:24,636: _fault_builder.py:208 -- There is no slip vector data for the fault, using vertical slip vector
#                           projected onto fault surface estimating from fault normal
# WARNING: 2024-07-18 10:00:24,636: _fault_builder.py:239 -- Fault major axis using map length: 3640.0549446402592
# Period =  Steady
# Model success =  True
# run_time =  17.425528
# Fault included!
# {'upper': 0, 'upper_unconformity': 1, 'Fault': 2, 'lower': 3}
# Creating lithology and discretisation arrays for  FD  ...
# C:\Users\19904604\Anaconda3\envs\loop3denvu\lib\site-packages\LoopStructural\modelling\core\geological_model.py:647: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = cm.get_cmap(cmap, n_units)
# Time taken =  21.309395
# Creating property arrays for  FD  ...
# Time taken =  0.008066
# Adding flow packages to  FD  ...
# Time taken =  0.781091
# Writing simulation and gwf for  FD  ...
# FD
# WARNING: Unable to resolve dimension of ('gwf6', 'disu', 'cell2d', 'cell2d', 'icvert') based on shape "ncvert".
# Running simulation for  FD  ...
# WARNING: 2024-07-18 10:01:03,298: geological_model.py:609 -- deprecated method. Model data can now be set using the data attribute
# WARNING: 2024-07-18 10:01:03,316: _fault_builder.py:208 -- There is no slip vector data for the fault, using vertical slip vector
#                           projected onto fault surface estimating from fault normal
# WARNING: 2024-07-18 10:01:03,332: _fault_builder.py:239 -- Fault major axis using map length: 3640.0549446402592
# Period =  Steady
# Model success =  True
# run_time =  16.437408
# Fault included!
# {'upper': 0, 'upper_unconformity': 1, 'Fault': 2, 'lower': 3}
# Creating lithology and discretisation arrays for  FD  ...
# C:\Users\19904604\Anaconda3\envs\loop3denvu\lib\site-packages\LoopStructural\modelling\core\geological_model.py:647: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = cm.get_cmap(cmap, n_units)
# Time taken =  21.223938
# Creating property arrays for  FD  ...
# Time taken =  0.008079
# Adding flow packages to  FD  ...
# Time taken =  0.767551
# Writing simulation and gwf for  FD  ...
# FD
# WARNING: Unable to resolve dimension of ('gwf6', 'disu', 'cell2d', 'cell2d', 'icvert') based on shape "ncvert".
# Running simulation for  FD  ...
# WARNING: 2024-07-18 10:01:41,277: geological_model.py:609 -- deprecated method. Model data can now be set using the data attribute
# WARNING: 2024-07-18 10:01:41,307: _fault_builder.py:208 -- There is no slip vector data for the fault, using vertical slip vector
#                           projected onto fault surface estimating from fault normal
# WARNING: 2024-07-18 10:01:41,307: _fault_builder.py:239 -- Fault major axis using map length: 3640.0549446402592
# Period =  Steady
# Model success =  True
# run_time =  15.830777
# Fault included!
# {'upper': 0, 'upper_unconformity': 1, 'Fault': 2, 'lower': 3}
# Creating lithology and discretisation arrays for  FD  ...
# C:\Users\19904604\Anaconda3\envs\loop3denvu\lib\site-packages\LoopStructural\modelling\core\geological_model.py:647: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = cm.get_cmap(cmap, n_units)
# Time taken =  21.565249
# Creating property arrays for  FD  ...
# Time taken =  0.010003
# Adding flow packages to  FD  ...
# Time taken =  0.747141
# Writing simulation and gwf for  FD  ...
# FD
# WARNING: Unable to resolve dimension of ('gwf6', 'disu', 'cell2d', 'cell2d', 'icvert') based on shape "ncvert".
# Running simulation for  FD  ...
# WARNING: 2024-07-18 10:02:19,391: geological_model.py:609 -- deprecated method. Model data can now be set using the data attribute
# WARNING: 2024-07-18 10:02:19,407: _fault_builder.py:208 -- There is no slip vector data for the fault, using vertical slip vector
#                           projected onto fault surface estimating from fault normal
# WARNING: 2024-07-18 10:02:19,422: _fault_builder.py:239 -- Fault major axis using map length: 3640.0549446402592
# Period =  Steady
# Model success =  True
# run_time =  15.640809
# Fault included!
# {'upper': 0, 'upper_unconformity': 1, 'Fault': 2, 'lower': 3}
# Creating lithology and discretisation arrays for  FD  ...
# C:\Users\19904604\Anaconda3\envs\loop3denvu\lib\site-packages\LoopStructural\modelling\core\geological_model.py:647: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = cm.get_cmap(cmap, n_units)
# Time taken =  19.239339
# Creating property arrays for  FD  ...
# Time taken =  0.010214
# Adding flow packages to  FD  ...
# Time taken =  0.661572
# Writing simulation and gwf for  FD  ...
# FD
# WARNING: Unable to resolve dimension of ('gwf6', 'disu', 'cell2d', 'cell2d', 'icvert') based on shape "ncvert".
# Running simulation for  FD  ...
# WARNING: 2024-07-18 10:02:54,619: geological_model.py:609 -- deprecated method. Model data can now be set using the data attribute
# WARNING: 2024-07-18 10:02:54,657: _fault_builder.py:208 -- There is no slip vector data for the fault, using vertical slip vector
#                           projected onto fault surface estimating from fault normal
# WARNING: 2024-07-18 10:02:54,657: _fault_builder.py:239 -- Fault major axis using map length: 3640.0549446402592
# Period =  Steady
# Model success =  True
# run_time =  15.169284
# Fault included!
# {'upper': 0, 'upper_unconformity': 1, 'Fault': 2, 'lower': 3}
# Creating lithology and discretisation arrays for  FD  ...
# C:\Users\19904604\Anaconda3\envs\loop3denvu\lib\site-packages\LoopStructural\modelling\core\geological_model.py:647: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = cm.get_cmap(cmap, n_units)
# Time taken =  19.450287
# Creating property arrays for  FD  ...
# Time taken =  0.010219
# Adding flow packages to  FD  ...
# Time taken =  0.872104
# Writing simulation and gwf for  FD  ...
# FD
# WARNING: Unable to resolve dimension of ('gwf6', 'disu', 'cell2d', 'cell2d', 'icvert') based on shape "ncvert".
# Running simulation for  FD  ...
# WARNING: 2024-07-18 10:03:30,494: geological_model.py:609 -- deprecated method. Model data can now be set using the data attribute
# WARNING: 2024-07-18 10:03:30,525: _fault_builder.py:208 -- There is no slip vector data for the fault, using vertical slip vector
#                           projected onto fault surface estimating from fault normal
# WARNING: 2024-07-18 10:03:30,531: _fault_builder.py:239 -- Fault major axis using map length: 3640.0549446402592
# Period =  Steady
# Model success =  True
# run_time =  15.400521
# Fault included!
# {'upper': 0, 'upper_unconformity': 1, 'Fault': 2, 'lower': 3}
# Creating lithology and discretisation arrays for  FD  ...
# C:\Users\19904604\Anaconda3\envs\loop3denvu\lib\site-packages\LoopStructural\modelling\core\geological_model.py:647: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = cm.get_cmap(cmap, n_units)
# Time taken =  18.580471
# Creating property arrays for  FD  ...
# Time taken =  0.01009
# Adding flow packages to  FD  ...
# Time taken =  0.71451
# Writing simulation and gwf for  FD  ...
# FD
# WARNING: Unable to resolve dimension of ('gwf6', 'disu', 'cell2d', 'cell2d', 'icvert') based on shape "ncvert".
# Running simulation for  FD  ...
# WARNING: 2024-07-18 10:04:04,895: geological_model.py:609 -- deprecated method. Model data can now be set using the data attribute
# WARNING: 2024-07-18 10:04:04,927: _fault_builder.py:208 -- There is no slip vector data for the fault, using vertical slip vector
#                           projected onto fault surface estimating from fault normal
# WARNING: 2024-07-18 10:04:04,927: _fault_builder.py:239 -- Fault major axis using map length: 3640.0549446402592
# Period =  Steady
# Model success =  True
# run_time =  14.970843
# Fault included!
# {'upper': 0, 'upper_unconformity': 1, 'Fault': 2, 'lower': 3}
# Creating lithology and discretisation arrays for  FD  ...
# C:\Users\19904604\Anaconda3\envs\loop3denvu\lib\site-packages\LoopStructural\modelling\core\geological_model.py:647: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = cm.get_cmap(cmap, n_units)
# Time taken =  19.583196
# Creating property arrays for  FD  ...
# Time taken =  0.008109
# Adding flow packages to  FD  ...
# Time taken =  0.667629
# Writing simulation and gwf for  FD  ...
# FD
# WARNING: Unable to resolve dimension of ('gwf6', 'disu', 'cell2d', 'cell2d', 'icvert') based on shape "ncvert".
# Running simulation for  FD  ...
# WARNING: 2024-07-18 10:04:41,290: geological_model.py:609 -- deprecated method. Model data can now be set using the data attribute
# WARNING: 2024-07-18 10:04:41,324: _fault_builder.py:208 -- There is no slip vector data for the fault, using vertical slip vector
#                           projected onto fault surface estimating from fault normal
# WARNING: 2024-07-18 10:04:41,324: _fault_builder.py:239 -- Fault major axis using map length: 3640.0549446402592
# Period =  Steady
# Model success =  True
# run_time =  15.996671
# Fault included!
# {'upper': 0, 'upper_unconformity': 1, 'Fault': 2, 'lower': 3}
# Creating lithology and discretisation arrays for  FD  ...
# C:\Users\19904604\Anaconda3\envs\loop3denvu\lib\site-packages\LoopStructural\modelling\core\geological_model.py:647: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = cm.get_cmap(cmap, n_units)
# Time taken =  19.519477
# Creating property arrays for  FD  ...
# Time taken =  0.001013
# Adding flow packages to  FD  ...
# Time taken =  0.698092
# Writing simulation and gwf for  FD  ...
# FD
# WARNING: Unable to resolve dimension of ('gwf6', 'disu', 'cell2d', 'cell2d', 'icvert') based on shape "ncvert".
# Running simulation for  FD  ...
# WARNING: 2024-07-18 10:05:17,619: geological_model.py:609 -- deprecated method. Model data can now be set using the data attribute
# WARNING: 2024-07-18 10:05:17,635: _fault_builder.py:208 -- There is no slip vector data for the fault, using vertical slip vector
#                           projected onto fault surface estimating from fault normal
# WARNING: 2024-07-18 10:05:17,635: _fault_builder.py:239 -- Fault major axis using map length: 3640.0549446402592
# Period =  Steady
# Model success =  True
# run_time =  15.974505
# Fault included!
# {'upper': 0, 'upper_unconformity': 1, 'Fault': 2, 'lower': 3}
# Creating lithology and discretisation arrays for  FD  ...
# C:\Users\19904604\Anaconda3\envs\loop3denvu\lib\site-packages\LoopStructural\modelling\core\geological_model.py:647: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = cm.get_cmap(cmap, n_units)
# Time taken =  20.03324
# Creating property arrays for  FD  ...
# Time taken =  0.010095
# Adding flow packages to  FD  ...
# Time taken =  0.690019
# Writing simulation and gwf for  FD  ...
# FD
# WARNING: Unable to resolve dimension of ('gwf6', 'disu', 'cell2d', 'cell2d', 'icvert') based on shape "ncvert".
# Running simulation for  FD  ...
# WARNING: 2024-07-18 10:05:54,609: geological_model.py:609 -- deprecated method. Model data can now be set using the data attribute
# WARNING: 2024-07-18 10:05:54,640: _fault_builder.py:208 -- There is no slip vector data for the fault, using vertical slip vector
#                           projected onto fault surface estimating from fault normal
# WARNING: 2024-07-18 10:05:54,640: _fault_builder.py:239 -- Fault major axis using map length: 3640.0549446402592
# Period =  Steady
# Model success =  True
# run_time =  16.136101
# Fault included!
# {'upper': 0, 'upper_unconformity': 1, 'Fault': 2, 'lower': 3}
# Creating lithology and discretisation arrays for  FD  ...
# C:\Users\19904604\Anaconda3\envs\loop3denvu\lib\site-packages\LoopStructural\modelling\core\geological_model.py:647: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = cm.get_cmap(cmap, n_units)
# Time taken =  19.422916
# Creating property arrays for  FD  ...
# Time taken =  0.010271
# Adding flow packages to  FD  ...
# Time taken =  0.816358
# Writing simulation and gwf for  FD  ...
# FD
# WARNING: Unable to resolve dimension of ('gwf6', 'disu', 'cell2d', 'cell2d', 'icvert') based on shape "ncvert".
# Running simulation for  FD  ...
# WARNING: 2024-07-18 10:06:30,825: geological_model.py:609 -- deprecated method. Model data can now be set using the data attribute
# WARNING: 2024-07-18 10:06:30,841: _fault_builder.py:208 -- There is no slip vector data for the fault, using vertical slip vector
#                           projected onto fault surface estimating from fault normal
# WARNING: 2024-07-18 10:06:30,856: _fault_builder.py:239 -- Fault major axis using map length: 3640.0549446402592
# Period =  Steady
# Model success =  True
# run_time =  15.81739
# Fault included!
# {'upper': 0, 'upper_unconformity': 1, 'Fault': 2, 'lower': 3}
# Creating lithology and discretisation arrays for  FD  ...
# C:\Users\19904604\Anaconda3\envs\loop3denvu\lib\site-packages\LoopStructural\modelling\core\geological_model.py:647: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = cm.get_cmap(cmap, n_units)
# Time taken =  22.215433
# Creating property arrays for  FD  ...
# Time taken =  0.010114
# Adding flow packages to  FD  ...
# Time taken =  0.682392
# Writing simulation and gwf for  FD  ...
# FD
# WARNING: Unable to resolve dimension of ('gwf6', 'disu', 'cell2d', 'cell2d', 'icvert') based on shape "ncvert".
# Running simulation for  FD  ...
# WARNING: 2024-07-18 10:07:11,302: geological_model.py:609 -- deprecated method. Model data can now be set using the data attribute
# WARNING: 2024-07-18 10:07:11,324: _fault_builder.py:208 -- There is no slip vector data for the fault, using vertical slip vector
#                           projected onto fault surface estimating from fault normal
# WARNING: 2024-07-18 10:07:11,324: _fault_builder.py:239 -- Fault major axis using map length: 3640.0549446402592
# Period =  Steady
# Model success =  True
# run_time =  17.436997
# Fault included!
# {'upper': 0, 'upper_unconformity': 1, 'Fault': 2, 'lower': 3}
# Creating lithology and discretisation arrays for  FD  ...
# C:\Users\19904604\Anaconda3\envs\loop3denvu\lib\site-packages\LoopStructural\modelling\core\geological_model.py:647: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = cm.get_cmap(cmap, n_units)
# Time taken =  20.623308
# Creating property arrays for  FD  ...
# Time taken =  0.0
# Adding flow packages to  FD  ...
# Time taken =  0.787758
# Writing simulation and gwf for  FD  ...
# FD
# WARNING: Unable to resolve dimension of ('gwf6', 'disu', 'cell2d', 'cell2d', 'icvert') based on shape "ncvert".
# Running simulation for  FD  ...
# WARNING: 2024-07-18 10:07:54,341: geological_model.py:609 -- deprecated method. Model data can now be set using the data attribute
# WARNING: 2024-07-18 10:07:54,389: _fault_builder.py:208 -- There is no slip vector data for the fault, using vertical slip vector
#                           projected onto fault surface estimating from fault normal
# Period =  Steady
# Model success =  True
# run_time =  21.427099
# Fault included!
# WARNING: 2024-07-18 10:07:54,395: _fault_builder.py:239 -- Fault major axis using map length: 3640.0549446402592
# C:\Users\19904604\Anaconda3\envs\loop3denvu\lib\site-packages\LoopStructural\modelling\core\geological_model.py:647: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = cm.get_cmap(cmap, n_units)
# {'upper': 0, 'upper_unconformity': 1, 'Fault': 2, 'lower': 3}
# Creating lithology and discretisation arrays for  FD  ...
# Time taken =  22.613187
# Creating property arrays for  FD  ...
# Time taken =  0.008066
# Adding flow packages to  FD  ...
# Time taken =  0.837717
# Writing simulation and gwf for  FD  ...
# FD
# WARNING: Unable to resolve dimension of ('gwf6', 'disu', 'cell2d', 'cell2d', 'icvert') based on shape "ncvert".
# Running simulation for  FD  ...
# WARNING: 2024-07-18 10:08:38,227: geological_model.py:609 -- deprecated method. Model data can now be set using the data attribute
# WARNING: 2024-07-18 10:08:38,259: _fault_builder.py:208 -- There is no slip vector data for the fault, using vertical slip vector
#                           projected onto fault surface estimating from fault normal
# WARNING: 2024-07-18 10:08:38,265: _fault_builder.py:239 -- Fault major axis using map length: 3640.0549446402592
# Period =  Steady
# Model success =  True
# run_time =  20.246559
# Fault included!
# {'upper': 0, 'upper_unconformity': 1, 'Fault': 2, 'lower': 3}
# Creating lithology and discretisation arrays for  FD  ...
# C:\Users\19904604\Anaconda3\envs\loop3denvu\lib\site-packages\LoopStructural\modelling\core\geological_model.py:647: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = cm.get_cmap(cmap, n_units)
# Time taken =  18.087271
# Creating property arrays for  FD  ...
# Time taken =  0.010263
# Adding flow packages to  FD  ...
# Time taken =  0.661251
# Writing simulation and gwf for  FD  ...
# FD
# WARNING: Unable to resolve dimension of ('gwf6', 'disu', 'cell2d', 'cell2d', 'icvert') based on shape "ncvert".
# Running simulation for  FD  ...
# WARNING: 2024-07-18 10:09:12,745: geological_model.py:609 -- deprecated method. Model data can now be set using the data attribute
# WARNING: 2024-07-18 10:09:12,783: _fault_builder.py:208 -- There is no slip vector data for the fault, using vertical slip vector
#                           projected onto fault surface estimating from fault normal
# WARNING: 2024-07-18 10:09:12,783: _fault_builder.py:239 -- Fault major axis using map length: 3640.0549446402592
# Period =  Steady
# Model success =  True
# run_time =  15.632696
# Fault included!
# {'upper': 0, 'upper_unconformity': 1, 'Fault': 2, 'lower': 3}
# Creating lithology and discretisation arrays for  FD  ...
# C:\Users\19904604\Anaconda3\envs\loop3denvu\lib\site-packages\LoopStructural\modelling\core\geological_model.py:647: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = cm.get_cmap(cmap, n_units)
# Time taken =  18.22365
# Creating property arrays for  FD  ...
# Time taken =  0.008059
# Adding flow packages to  FD  ...
# Time taken =  0.862397
# Writing simulation and gwf for  FD  ...
# FD
# WARNING: Unable to resolve dimension of ('gwf6', 'disu', 'cell2d', 'cell2d', 'icvert') based on shape "ncvert".
# Running simulation for  FD  ...
# WARNING: 2024-07-18 10:09:47,884: geological_model.py:609 -- deprecated method. Model data can now be set using the data attribute
# WARNING: 2024-07-18 10:09:47,904: _fault_builder.py:208 -- There is no slip vector data for the fault, using vertical slip vector
#                           projected onto fault surface estimating from fault normal
# WARNING: 2024-07-18 10:09:47,912: _fault_builder.py:239 -- Fault major axis using map length: 3640.0549446402592
# Period =  Steady
# Model success =  True
# run_time =  15.91753
# Fault included!
# {'upper': 0, 'upper_unconformity': 1, 'Fault': 2, 'lower': 3}
# Creating lithology and discretisation arrays for  FD  ...
# C:\Users\19904604\Anaconda3\envs\loop3denvu\lib\site-packages\LoopStructural\modelling\core\geological_model.py:647: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = cm.get_cmap(cmap, n_units)
# Time taken =  20.859832
# Creating property arrays for  FD  ...
# Time taken =  0.010106
# Adding flow packages to  FD  ...
# Time taken =  0.732229
# Writing simulation and gwf for  FD  ...
# FD
# WARNING: Unable to resolve dimension of ('gwf6', 'disu', 'cell2d', 'cell2d', 'icvert') based on shape "ncvert".
# Running simulation for  FD  ...
# WARNING: 2024-07-18 10:10:25,577: geological_model.py:609 -- deprecated method. Model data can now be set using the data attribute
# WARNING: 2024-07-18 10:10:25,607: _fault_builder.py:208 -- There is no slip vector data for the fault, using vertical slip vector
#                           projected onto fault surface estimating from fault normal
# WARNING: 2024-07-18 10:10:25,607: _fault_builder.py:239 -- Fault major axis using map length: 3640.0549446402592
# Period =  Steady
# Model success =  True
# run_time =  15.938804
# Fault included!
# {'upper': 0, 'upper_unconformity': 1, 'Fault': 2, 'lower': 3}
# Creating lithology and discretisation arrays for  FD  ...
# C:\Users\19904604\Anaconda3\envs\loop3denvu\lib\site-packages\LoopStructural\modelling\core\geological_model.py:647: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = cm.get_cmap(cmap, n_units)
# Time taken =  21.005951
# Creating property arrays for  FD  ...
# Time taken =  0.008106
# Adding flow packages to  FD  ...
# Time taken =  0.830795
# Writing simulation and gwf for  FD  ...
# FD
# WARNING: Unable to resolve dimension of ('gwf6', 'disu', 'cell2d', 'cell2d', 'icvert') based on shape "ncvert".
# Running simulation for  FD  ...
# WARNING: 2024-07-18 10:11:02,482: geological_model.py:609 -- deprecated method. Model data can now be set using the data attribute
# WARNING: 2024-07-18 10:11:02,506: _fault_builder.py:208 -- There is no slip vector data for the fault, using vertical slip vector
#                           projected onto fault surface estimating from fault normal
# WARNING: 2024-07-18 10:11:02,509: _fault_builder.py:239 -- Fault major axis using map length: 3640.0549446402592
# Period =  Steady
# Model success =  True
# run_time =  14.918857
# Fault included!
# {'upper': 0, 'upper_unconformity': 1, 'Fault': 2, 'lower': 3}
# Creating lithology and discretisation arrays for  FD  ...
# C:\Users\19904604\Anaconda3\envs\loop3denvu\lib\site-packages\LoopStructural\modelling\core\geological_model.py:647: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = cm.get_cmap(cmap, n_units)
# Time taken =  18.587772
# Creating property arrays for  FD  ...
# Time taken =  0.010121
# Adding flow packages to  FD  ...
# Time taken =  0.662298
# Writing simulation and gwf for  FD  ...
# FD
# WARNING: Unable to resolve dimension of ('gwf6', 'disu', 'cell2d', 'cell2d', 'icvert') based on shape "ncvert".
# Running simulation for  FD  ...
# WARNING: 2024-07-18 10:11:36,591: geological_model.py:609 -- deprecated method. Model data can now be set using the data attribute
# WARNING: 2024-07-18 10:11:36,613: _fault_builder.py:208 -- There is no slip vector data for the fault, using vertical slip vector
#                           projected onto fault surface estimating from fault normal
# WARNING: 2024-07-18 10:11:36,613: _fault_builder.py:239 -- Fault major axis using map length: 3640.0549446402592
# Period =  Steady
# Model success =  True
# run_time =  14.707901
# Fault included!
# {'upper': 0, 'upper_unconformity': 1, 'Fault': 2, 'lower': 3}
# Creating lithology and discretisation arrays for  FD  ...
# C:\Users\19904604\Anaconda3\envs\loop3denvu\lib\site-packages\LoopStructural\modelling\core\geological_model.py:647: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = cm.get_cmap(cmap, n_units)
# Time taken =  18.866052
# Creating property arrays for  FD  ...
# Time taken =  0.008122
# Adding flow packages to  FD  ...
# Time taken =  0.708554
# Writing simulation and gwf for  FD  ...
# FD
# WARNING: Unable to resolve dimension of ('gwf6', 'disu', 'cell2d', 'cell2d', 'icvert') based on shape "ncvert".
# Running simulation for  FD  ...
# WARNING: 2024-07-18 10:12:11,788: geological_model.py:609 -- deprecated method. Model data can now be set using the data attribute
# WARNING: 2024-07-18 10:12:11,811: _fault_builder.py:208 -- There is no slip vector data for the fault, using vertical slip vector
#                           projected onto fault surface estimating from fault normal
# WARNING: 2024-07-18 10:12:11,811: _fault_builder.py:239 -- Fault major axis using map length: 3640.0549446402592
# Period =  Steady
# Model success =  True
# run_time =  15.473603
# Fault included!
# {'upper': 0, 'upper_unconformity': 1, 'Fault': 2, 'lower': 3}
# Creating lithology and discretisation arrays for  FD  ...
# C:\Users\19904604\Anaconda3\envs\loop3denvu\lib\site-packages\LoopStructural\modelling\core\geological_model.py:647: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = cm.get_cmap(cmap, n_units)
# Time taken =  18.716525
# Creating property arrays for  FD  ...
# Time taken =  0.0
# Adding flow packages to  FD  ...
# Time taken =  0.791699
# Writing simulation and gwf for  FD  ...
# FD
# WARNING: Unable to resolve dimension of ('gwf6', 'disu', 'cell2d', 'cell2d', 'icvert') based on shape "ncvert".
# Running simulation for  FD  ...
# WARNING: 2024-07-18 10:12:47,823: geological_model.py:609 -- deprecated method. Model data can now be set using the data attribute
# WARNING: 2024-07-18 10:12:47,845: _fault_builder.py:208 -- There is no slip vector data for the fault, using vertical slip vector
#                           projected onto fault surface estimating from fault normal
# WARNING: 2024-07-18 10:12:47,845: _fault_builder.py:239 -- Fault major axis using map length: 3640.0549446402592
# Period =  Steady
# Model success =  True
# run_time =  16.384219
# Fault included!
# {'upper': 0, 'upper_unconformity': 1, 'Fault': 2, 'lower': 3}
# ...
# WARNING: 2024-07-18 10:47:15,317: _fault_builder.py:239 -- Fault major axis using map length: 3640.0549446402592
# Period =  Steady
# Model success =  True
# run_time =  18.745463
# Fault included!
# {'upper': 0, 'upper_unconformity': 1, 'Fault': 2, 'lower': 3}
# Creating lithology and discretisation arrays for  FD  ...
# C:\Users\19904604\Anaconda3\envs\loop3denvu\lib\site-packages\LoopStructural\modelling\core\geological_model.py:647: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = cm.get_cmap(cmap, n_units)
# Time taken =  19.10811
# Creating property arrays for  FD  ...
# Time taken =  0.010226
# Adding flow packages to  FD  ...
# Time taken =  0.724404
# Writing simulation and gwf for  FD  ...
# FD
# WARNING: Unable to resolve dimension of ('gwf6', 'disu', 'cell2d', 'cell2d', 'icvert') based on shape "ncvert".
# Running simulation for  FD  ...
# WARNING: 2024-07-18 10:47:52,406: geological_model.py:609 -- deprecated method. Model data can now be set using the data attribute
# WARNING: 2024-07-18 10:47:52,428: _fault_builder.py:208 -- There is no slip vector data for the fault, using vertical slip vector
#                           projected onto fault surface estimating from fault normal
# WARNING: 2024-07-18 10:47:52,428: _fault_builder.py:239 -- Fault major axis using map length: 3640.0549446402592
# Period =  Steady
# Model success =  True
# run_time =  17.136139
# Fault included!
# {'upper': 0, 'upper_unconformity': 1, 'Fault': 2, 'lower': 3}
# Creating lithology and discretisation arrays for  FD  ...
# C:\Users\19904604\Anaconda3\envs\loop3denvu\lib\site-packages\LoopStructural\modelling\core\geological_model.py:647: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = cm.get_cmap(cmap, n_units)
# Time taken =  19.67895
# Creating property arrays for  FD  ...
# Time taken =  0.01027
# Adding flow packages to  FD  ...
# Time taken =  0.693167
# Writing simulation and gwf for  FD  ...
# FD
# WARNING: Unable to resolve dimension of ('gwf6', 'disu', 'cell2d', 'cell2d', 'icvert') based on shape "ncvert".
# Running simulation for  FD  ...
# WARNING: 2024-07-18 10:48:28,840: geological_model.py:609 -- deprecated method. Model data can now be set using the data attribute
# WARNING: 2024-07-18 10:48:28,862: _fault_builder.py:208 -- There is no slip vector data for the fault, using vertical slip vector
#                           projected onto fault surface estimating from fault normal
# WARNING: 2024-07-18 10:48:28,862: _fault_builder.py:239 -- Fault major axis using map length: 3640.0549446402592
# Period =  Steady
# Model success =  True
# run_time =  15.917927
# Fault included!
# {'upper': 0, 'upper_unconformity': 1, 'Fault': 2, 'lower': 3}
# Creating lithology and discretisation arrays for  FD  ...
# C:\Users\19904604\Anaconda3\envs\loop3denvu\lib\site-packages\LoopStructural\modelling\core\geological_model.py:647: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = cm.get_cmap(cmap, n_units)
# Time taken =  18.786183
# Creating property arrays for  FD  ...
# Time taken =  0.010262
# Adding flow packages to  FD  ...
# Time taken =  0.720395
# Writing simulation and gwf for  FD  ...
# FD
# WARNING: Unable to resolve dimension of ('gwf6', 'disu', 'cell2d', 'cell2d', 'icvert') based on shape "ncvert".
# Running simulation for  FD  ...
# WARNING: 2024-07-18 10:49:04,892: geological_model.py:609 -- deprecated method. Model data can now be set using the data attribute
# WARNING: 2024-07-18 10:49:04,914: _fault_builder.py:208 -- There is no slip vector data for the fault, using vertical slip vector
#                           projected onto fault surface estimating from fault normal
# WARNING: 2024-07-18 10:49:04,929: _fault_builder.py:239 -- Fault major axis using map length: 3640.0549446402592
# Period =  Steady
# Model success =  True
# run_time =  16.418464
# Fault included!
# {'upper': 0, 'upper_unconformity': 1, 'Fault': 2, 'lower': 3}
# Creating lithology and discretisation arrays for  FD  ...
# C:\Users\19904604\Anaconda3\envs\loop3denvu\lib\site-packages\LoopStructural\modelling\core\geological_model.py:647: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = cm.get_cmap(cmap, n_units)
# Time taken =  19.966332
# Creating property arrays for  FD  ...
# Time taken =  0.010128
# Adding flow packages to  FD  ...
# Time taken =  0.98905
# Writing simulation and gwf for  FD  ...
# FD
# WARNING: Unable to resolve dimension of ('gwf6', 'disu', 'cell2d', 'cell2d', 'icvert') based on shape "ncvert".
# Running simulation for  FD  ...
# WARNING: 2024-07-18 10:49:42,716: geological_model.py:609 -- deprecated method. Model data can now be set using the data attribute
# WARNING: 2024-07-18 10:49:42,747: _fault_builder.py:208 -- There is no slip vector data for the fault, using vertical slip vector
#                           projected onto fault surface estimating from fault normal
# WARNING: 2024-07-18 10:49:42,747: _fault_builder.py:239 -- Fault major axis using map length: 3640.0549446402592
# Period =  Steady
# Model success =  True
# run_time =  16.732826
# Fault included!
# {'upper': 0, 'upper_unconformity': 1, 'Fault': 2, 'lower': 3}
# Creating lithology and discretisation arrays for  FD  ...
# C:\Users\19904604\Anaconda3\envs\loop3denvu\lib\site-packages\LoopStructural\modelling\core\geological_model.py:647: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = cm.get_cmap(cmap, n_units)
# Time taken =  19.516899
# Creating property arrays for  FD  ...
# Time taken =  0.008106
# Adding flow packages to  FD  ...
# Time taken =  0.674722
# Writing simulation and gwf for  FD  ...
# FD
# WARNING: Unable to resolve dimension of ('gwf6', 'disu', 'cell2d', 'cell2d', 'icvert') based on shape "ncvert".
# Running simulation for  FD  ...
# WARNING: 2024-07-18 10:50:19,288: geological_model.py:609 -- deprecated method. Model data can now be set using the data attribute
# WARNING: 2024-07-18 10:50:19,326: _fault_builder.py:208 -- There is no slip vector data for the fault, using vertical slip vector
#                           projected onto fault surface estimating from fault normal
# WARNING: 2024-07-18 10:50:19,326: _fault_builder.py:239 -- Fault major axis using map length: 3640.0549446402592
# Period =  Steady
# Model success =  True
# run_time =  16.244438
# Fault included!
# {'upper': 0, 'upper_unconformity': 1, 'Fault': 2, 'lower': 3}
# Creating lithology and discretisation arrays for  FD  ...
# C:\Users\19904604\Anaconda3\envs\loop3denvu\lib\site-packages\LoopStructural\modelling\core\geological_model.py:647: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = cm.get_cmap(cmap, n_units)
# Time taken =  20.165133
# Creating property arrays for  FD  ...
# Time taken =  0.015591
# Adding flow packages to  FD  ...
# Time taken =  0.996295
# Writing simulation and gwf for  FD  ...
# FD
# WARNING: Unable to resolve dimension of ('gwf6', 'disu', 'cell2d', 'cell2d', 'icvert') based on shape "ncvert".
# Running simulation for  FD  ...
# WARNING: 2024-07-18 10:51:02,306: geological_model.py:609 -- deprecated method. Model data can now be set using the data attribute
# WARNING: 2024-07-18 10:51:02,330: _fault_builder.py:208 -- There is no slip vector data for the fault, using vertical slip vector
#                           projected onto fault surface estimating from fault normal
# WARNING: 2024-07-18 10:51:02,332: _fault_builder.py:239 -- Fault major axis using map length: 3640.0549446402592
# Period =  Steady
# Model success =  True
# run_time =  21.690422
# Fault included!
# {'upper': 0, 'upper_unconformity': 1, 'Fault': 2, 'lower': 3}
# Creating lithology and discretisation arrays for  FD  ...
# C:\Users\19904604\Anaconda3\envs\loop3denvu\lib\site-packages\LoopStructural\modelling\core\geological_model.py:647: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = cm.get_cmap(cmap, n_units)
# Time taken =  19.713502
# Creating property arrays for  FD  ...
# Time taken =  0.01025
# Adding flow packages to  FD  ...
# Time taken =  0.677202
# Writing simulation and gwf for  FD  ...
# FD
# WARNING: Unable to resolve dimension of ('gwf6', 'disu', 'cell2d', 'cell2d', 'icvert') based on shape "ncvert".
# Running simulation for  FD  ...
# WARNING: 2024-07-18 10:51:40,517: geological_model.py:609 -- deprecated method. Model data can now be set using the data attribute
# WARNING: 2024-07-18 10:51:40,554: _fault_builder.py:208 -- There is no slip vector data for the fault, using vertical slip vector
#                           projected onto fault surface estimating from fault normal
# WARNING: 2024-07-18 10:51:40,554: _fault_builder.py:239 -- Fault major axis using map length: 3640.0549446402592
# Period =  Steady
# Model success =  True
# run_time =  17.685466
# Fault included!
# {'upper': 0, 'upper_unconformity': 1, 'Fault': 2, 'lower': 3}
# Creating lithology and discretisation arrays for  FD  ...
# C:\Users\19904604\Anaconda3\envs\loop3denvu\lib\site-packages\LoopStructural\modelling\core\geological_model.py:647: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = cm.get_cmap(cmap, n_units)
# Time taken =  20.361004
# Creating property arrays for  FD  ...
# Time taken =  0.010188
# Adding flow packages to  FD  ...
# Time taken =  0.765049
# Writing simulation and gwf for  FD  ...
# FD
# WARNING: Unable to resolve dimension of ('gwf6', 'disu', 'cell2d', 'cell2d', 'icvert') based on shape "ncvert".
# Running simulation for  FD  ...
# WARNING: 2024-07-18 10:52:21,259: geological_model.py:609 -- deprecated method. Model data can now be set using the data attribute
# WARNING: 2024-07-18 10:52:21,290: _fault_builder.py:208 -- There is no slip vector data for the fault, using vertical slip vector
#                           projected onto fault surface estimating from fault normal
# WARNING: 2024-07-18 10:52:21,290: _fault_builder.py:239 -- Fault major axis using map length: 3640.0549446402592
# Period =  Steady
# Model success =  True
# run_time =  19.463956
# Fault included!
# {'upper': 0, 'upper_unconformity': 1, 'Fault': 2, 'lower': 3}
# Creating lithology and discretisation arrays for  FD  ...
# C:\Users\19904604\Anaconda3\envs\loop3denvu\lib\site-packages\LoopStructural\modelling\core\geological_model.py:647: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = cm.get_cmap(cmap, n_units)
# Time taken =  19.694865
# Creating property arrays for  FD  ...
# Time taken =  0.010228
# Adding flow packages to  FD  ...
# Time taken =  0.674449
# Writing simulation and gwf for  FD  ...
# FD
# WARNING: Unable to resolve dimension of ('gwf6', 'disu', 'cell2d', 'cell2d', 'icvert') based on shape "ncvert".
# Running simulation for  FD  ...
# WARNING: 2024-07-18 10:52:59,088: geological_model.py:609 -- deprecated method. Model data can now be set using the data attribute
# WARNING: 2024-07-18 10:52:59,120: _fault_builder.py:208 -- There is no slip vector data for the fault, using vertical slip vector
#                           projected onto fault surface estimating from fault normal
# WARNING: 2024-07-18 10:52:59,120: _fault_builder.py:239 -- Fault major axis using map length: 3640.0549446402592
# Period =  Steady
# Model success =  True
# run_time =  17.324339
# Fault included!
# {'upper': 0, 'upper_unconformity': 1, 'Fault': 2, 'lower': 3}
# Creating lithology and discretisation arrays for  FD  ...
# C:\Users\19904604\Anaconda3\envs\loop3denvu\lib\site-packages\LoopStructural\modelling\core\geological_model.py:647: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = cm.get_cmap(cmap, n_units)
# Time taken =  18.368452
# Creating property arrays for  FD  ...
# Time taken =  0.010196
# Adding flow packages to  FD  ...
# Time taken =  0.672962
# Writing simulation and gwf for  FD  ...
# FD
# WARNING: Unable to resolve dimension of ('gwf6', 'disu', 'cell2d', 'cell2d', 'icvert') based on shape "ncvert".
# Running simulation for  FD  ...
# WARNING: 2024-07-18 10:53:33,758: geological_model.py:609 -- deprecated method. Model data can now be set using the data attribute
# WARNING: 2024-07-18 10:53:33,789: _fault_builder.py:208 -- There is no slip vector data for the fault, using vertical slip vector
#                           projected onto fault surface estimating from fault normal
# WARNING: 2024-07-18 10:53:33,789: _fault_builder.py:239 -- Fault major axis using map length: 3640.0549446402592
# Period =  Steady
# Model success =  True
# run_time =  15.491712
# Fault included!
# {'upper': 0, 'upper_unconformity': 1, 'Fault': 2, 'lower': 3}
# Creating lithology and discretisation arrays for  FD  ...
# C:\Users\19904604\Anaconda3\envs\loop3denvu\lib\site-packages\LoopStructural\modelling\core\geological_model.py:647: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = cm.get_cmap(cmap, n_units)
# Time taken =  18.066562
# Creating property arrays for  FD  ...
# Time taken =  0.008113
# Adding flow packages to  FD  ...
# Time taken =  0.674353
# Writing simulation and gwf for  FD  ...
# FD
# WARNING: Unable to resolve dimension of ('gwf6', 'disu', 'cell2d', 'cell2d', 'icvert') based on shape "ncvert".
# Running simulation for  FD  ...
# WARNING: 2024-07-18 10:54:09,214: geological_model.py:609 -- deprecated method. Model data can now be set using the data attribute
# WARNING: 2024-07-18 10:54:09,245: _fault_builder.py:208 -- There is no slip vector data for the fault, using vertical slip vector
#                           projected onto fault surface estimating from fault normal
# WARNING: 2024-07-18 10:54:09,252: _fault_builder.py:239 -- Fault major axis using map length: 3640.0549446402592
# Period =  Steady
# Model success =  True
# run_time =  16.578898
# Fault included!
# {'upper': 0, 'upper_unconformity': 1, 'Fault': 2, 'lower': 3}
# Creating lithology and discretisation arrays for  FD  ...
# C:\Users\19904604\Anaconda3\envs\loop3denvu\lib\site-packages\LoopStructural\modelling\core\geological_model.py:647: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = cm.get_cmap(cmap, n_units)
# Time taken =  17.835179
# Creating property arrays for  FD  ...
# Time taken =  0.0
# Adding flow packages to  FD  ...
# Time taken =  0.686532
# Writing simulation and gwf for  FD  ...
# FD
# WARNING: Unable to resolve dimension of ('gwf6', 'disu', 'cell2d', 'cell2d', 'icvert') based on shape "ncvert".
# Running simulation for  FD  ...
# Period =  Steady
# Model success =  True
# run_time =  16.728353

# %%
# FAULT
stacked = []
for n in range(100):
    heads_disv = -1e30 * np.ones_like(N.idomain, dtype=float) 
    for i, h in enumerate(heads_FD[n][0][0]):
        if math.isnan(h) == False: 
            heads_disv[N.cellid_disu==i] = h        
    stacked.append(heads_disv[layer])
var_FD = np.var(np.array(stacked), axis = 0)

# %%
def figure6(P, var_PO, var_FD):
    
    fig = plt.figure(figsize=(12,5))
    fig.suptitle('Variance in head due to alternative structural models')
    ax = plt.subplot(1, 2, 1, aspect='equal')
    #P.vor.plot(ax=ax, edgecolor='black', lw = 0.2)
    pmv = flopy.plot.PlotMapView(model=M.gwf)
    pmv.plot_grid(edgecolor='black', lw = 0.2)
    A = pmv.plot_array(var_PO, cmap = 'Spectral', alpha = 0.6)#vmin = vmin, vmax = vmax, 
    ax.set_xlabel('X (m)')
    ax.set_ylabel('Y (m)')
    ax.set_title('Pinchout Scenario')
    plt.colorbar(A, ax=ax, shrink = 0.4)
    
    ax = plt.subplot(1, 2, 2, aspect='equal')
    #P.vor.plot(ax=ax, edgecolor='black', lw = 0.2)
    grid = N.gwf.modelgrid
    pmv = flopy.plot.PlotMapView(model=N.gwf)
    pmv.plot_grid(edgecolor='black', lw = 0.2)
    B = pmv.plot_array(var_FD, cmap = 'Spectral', alpha = 0.6)#vmin = vmin, vmax = vmax, 
    
    ax.set_xlabel('X (m)')
    ax.set_yticks([])
    ax.set_yticklabels([])
    ax.set_title('Fault Scenario')
    plt.colorbar(B, ax=ax, shrink = 0.4)
    
    plt.subplots_adjust(wspace=0.05, hspace=0.1)    
    plt.tight_layout()  
    plt.show()   
    fig.savefig('../figures/fig6.tif', dpi=300)

figure6(P, var_PO, var_FD)
